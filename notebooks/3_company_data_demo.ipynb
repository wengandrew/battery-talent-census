# %% [markdown]
# # 3. Summarize and visualize info from company questions
#
# December 22, 2024
#
# This notebook summarizes and visualizes the company questions responses (from currently and previously respondents).

# %% [markdown]
# ## Setup
#
# To learn more, see notebook #1

# %%
import os

# Set working directory to root of project
current_folder = os.path.basename(os.getcwd())
if current_folder == 'notebooks':
    root_path = os.path.dirname(os.path.abspath(''))
    os.chdir(root_path)

from pprint import pprint
from src.plotter import Plotter
from src.respondent import Respondent
from src.analyst import Analyst
import src.utils as utils

from IPython import get_ipython

# Automatically reload all modules every time a line of code is executed
get_ipython().run_line_magic('load_ext', 'autoreload')
get_ipython().run_line_magic('autoreload', '2')

# %%
analyst = Analyst()
analyst.load_data()
analyst.build_respondents_list()

# %% [markdown]
# # Summarize data from professional workers

# %%
# Initialize plotter
plotter = Plotter()

# %% [markdown]
# ## Salary

# %%
res_company_salary = analyst.summarize_company_salary()
pprint(res_company_salary)
# Out:
# {'salary_base_list': array([1.25000e+05, 1.25000e+05, 1.45000e+05, 1.40000e+05, 1.65000e+05,
#        4.90000e+04, 8.80000e+04, 1.34000e+05, 1.80000e+05, 2.20000e+06,
#        3.60000e+05, 1.30000e+05, 1.80000e+05, 1.59000e+05,         nan,
#        1.21000e+05, 7.50000e+04, 8.00000e+04,         nan, 4.00000e+04,
#        1.75000e+05, 9.50000e+04, 1.95000e+05, 9.00000e+04, 1.55000e+05,
#        1.20000e+05, 2.00000e+05, 1.00000e+05, 3.75000e+05, 1.35000e+05,
#        8.85000e+04, 1.00000e+05, 1.70000e+05,         nan, 6.00000e+05,
#        2.15000e+05, 8.00000e+04, 5.70000e+04, 9.60000e+05, 1.00000e+05,
#        9.70000e+04, 1.30000e+05, 1.55000e+05, 5.30000e+04, 1.20000e+05,
#        3.10000e+05, 1.00000e+02, 1.70000e+05, 8.00000e+04, 8.20000e+04,
#        1.20000e+05, 1.80000e+05, 1.50000e+06, 2.20000e+05, 1.41000e+05,
#        8.70000e+04, 7.19940e+05, 1.82000e+05, 9.50000e+04, 9.00000e+04,
#        1.60000e+05,         nan, 1.28000e+05, 6.10000e+05, 8.40000e+04,
#        9.00000e+04, 1.60000e+05, 1.47000e+05, 1.84000e+05, 8.00000e+04,
#        1.15000e+05, 1.60000e+05, 4.00000e+04, 1.87000e+05, 2.20000e+05,
#        1.75000e+05, 1.20000e+06, 2.15000e+05, 1.20000e+05, 6.60000e+04,
#        2.00000e+05, 4.62000e+05, 1.85000e+05, 1.60000e+05, 1.14000e+05,
#        1.00000e+05, 1.96000e+05, 1.25000e+05, 3.00000e+05, 1.40000e+05,
#        1.45000e+05, 1.78000e+05, 2.15000e+05, 3.00000e+04, 1.55000e+05,
#        5.65000e+04, 1.00000e+05, 1.30000e+05,         nan, 1.50000e+05,
#        1.00000e+05, 4.33000e+04, 8.50000e+04, 2.00000e+05, 1.10000e+05,
#        1.85000e+05,         nan, 1.50000e+05, 1.60000e+05, 7.50000e+04,
#        1.42000e+05, 8.50000e+04, 0.00000e+00, 0.00000e+00, 6.50000e+04,
#        5.00000e+04, 2.80000e+06, 5.90000e+04, 2.00000e+00, 9.30000e+04,
#        1.63000e+05, 1.26000e+05, 1.65000e+05, 3.20000e+05, 1.10000e+05,
#        1.20000e+05,         nan, 3.00000e+05, 1.00000e+06, 1.00000e+05,
#        9.80000e+04, 1.07000e+05, 1.05000e+05, 1.40000e+05, 2.20000e+05,
#        1.05000e+05, 1.20000e+05,         nan, 1.30000e+06, 1.10000e+05,
#        4.00000e+05, 2.00000e+05, 1.50000e+06, 1.30000e+05, 3.50000e+04,
#                nan, 6.80000e+04, 7.50000e+04, 9.00000e+04, 1.00000e+05,
#        3.20000e+08, 5.10000e+04, 5.00000e+04, 1.50000e+05, 1.92000e+05,
#        1.21000e+05, 9.50000e+04, 4.50000e+04, 1.34000e+05,         nan]),
#  'salary_base_median': np.float64(130000.0),
#  'salary_base_std': np.float64(263054387.7582982),
#  'salary_comp_types': {'401K Match': 1,
#                        '401k company match': 1,
#                        '40€ tax free vouchers': 1,
#                        'Accommodation': 1,
#                        'Acquisition bonus': 1,
#                        'Advisory roles': 1,
#                        'Bonuses (based on company performance)': 282,
#                        'Bonuses (based on individual performance)': 279,
#                        'Bonuses (based on retention)': 40,
#                        'Bonuses on festivals': 1,
#                        'Cell phone': 1,
#                        'Childcare expense reimbursement': 29,
#                        'Commissions': 29,
#                        'Company Car': 1,
#                        'Company car': 1,
#                        'Distribution - I own the company.': 1,
#                        'Education or tuition reimbursement': 58,
#                        'Equity (stock': 259,
#                        'Expert tax relief': 1,
#                        'Food/groceries stipend': 1,
#                        'German IG Metall collective bargaining benefits': 1,
#                        'HRA': 1,
#                        'Health and dental': 1,
#                        'Health and wellness stipends': 140,
#                        'Health insurance': 1,
#                        'Healthcare': 1,
#                        'Healthcare plan': 1,
#                        'Holiday compensation': 1,
#                        'Housing': 2,
#                        "I am self-employed and I'm not able to provide these for myself...yet.": 1,
#                        'Leaves': 1,
#                        'Life insurance': 1,
#                        'NONE': 1,
#                        'Na': 1,
#                        'Nil': 1,
#                        'No': 2,
#                        'No Answer': 1,
#                        'No additional Compensation': 1,
#                        'No additional compensation': 1,
#                        'Nothing': 4,
#                        'Patent incentive': 1,
#                        'Pension': 3,
#                        'Random bonus that comes in with no basis': 1,
#                        'Small increase based on performance': 1,
#                        'Transit reimbursement': 1,
#                        'Transport compensation': 1,
#                        'Transportation': 1,
#                        '_tot_': 581,
#                        'cofeteria': 1,
#                        'company car': 1,
#                        'entertaiment': 1,
#                        'etc.)': 259,
#                        'eventually retirement matching': 1,
#                        'free EV charging': 1,
#                        'health/dependent care flexible spending accounts': 1,
#                        'living cost allowance': 1,
#                        'mobile phone compensation': 1,
#                        'no compensation': 1,
#                        'none': 4,
#                        'nothing': 2,
#                        'options': 259,
#                        'private health insurance and pension': 1,
#                        'training fund and pension': 1},
#  'salary_num_bonuses': {'0': 295, '1': 278, '2': 30, '3+': 23, '_tot_': 626},
#  'salary_num_raises': {'0': 243, '1': 372, '2': 30, '3+': 10, '_tot_': 655}}

# %%
plotter.make_bar_plot_from_dict(
    utils.sort_dict(res_company_salary['salary_num_raises'], by='keys', reverse=False),
    title='How many times have you received a base salary increase \nover the past 12 months of employment?',
    saveas='company_salary_num_raises.png'
)

plotter.make_bar_plot_from_dict(
    utils.sort_dict(res_company_salary['salary_num_bonuses'], by='keys', reverse=False),
    title='How many times have you received a bonus \nover the past 12 months of employment?',
    saveas='company_salary_num_bonuses.png'
)

plotter.make_bar_plot_from_dict(
    res_company_salary['salary_comp_types'],
    title='Beyond base salary, what additional compensation types \ndo you receive?',
    saveas='company_salary_comp_types.png',
    exclusions=['options', 'etc.)'],
    replacements={'Equity (stock' : 'Equity (stock options, etc.)'},
    sorted=True
)

# %% [markdown]
# ## Company Info

# %%
res_company_info = analyst.summarize_company_info()
pprint(res_company_info)
# Out:
# {'company_country': {'Argentina': 2,
#                      'Australia': 7,
#                      'Belgium': 8,
#                      'Canada': 23,
#                      'Chile': 1,
#                      'China': 11,
#                      'Czech Republic': 1,
#                      'Denmark': 3,
#                      'Estonia': 1,
#                      'Finland': 3,
#                      'France': 18,
#                      'Germany': 41,
#                      'Hungary': 1,
#                      'India': 40,
#                      'Indonesia': 2,
#                      'Iran': 3,
#                      'Ireland {Republic}': 2,
#                      'Israel': 4,
#                      'Italy': 13,
#                      'Japan': 3,
#                      'Kenya': 1,
#                      'Korea South': 3,
#                      'Luxembourg': 1,
#                      'Malaysia': 3,
#                      'Mexico': 3,
#                      'Morocco': 1,
#                      'Netherlands': 11,
#                      'Nigeria': 3,
#                      'Norway': 10,
#                      'Poland': 2,
#                      'Portugal': 6,
#                      'Serbia': 1,
#                      'Singapore': 2,
#                      'South Africa': 1,
#                      'Spain': 7,
#                      'Sweden': 24,
#                      'Switzerland': 6,
#                      'Taiwan': 2,
#                      'Turkey': 7,
#                      'United Arab Emirates': 1,
#                      'United Kingdom': 52,
#                      'United States': 329,
#                      'Vietnam': 1,
#                      'Zambia': 1,
#                      '_tot_': 665},
#  'company_headcount': {'1,001-5,000': 63,
#                        '1-10': 65,
#                        '10,001-25,000': 23,
#                        '100,000+': 57,
#                        '101-250': 74,
#                        '11-50': 116,
#                        '25,001-50,000': 20,
#                        '251-500': 60,
#                        '5,001-10,000': 46,
#                        '50,001-100,000': 14,
#                        '501-1,000': 44,
#                        '51-100': 77,
#                        '_tot_': 659},
#  'company_stage': {'Established (significant market presence)': 195,
#                    'Mid-sized (stable growth)': 68,
#                    'Pre-startup (planning)': 20,
#                    'Scale-up (rapid growth)': 174,
#                    'Startup (early growth)': 201,
#                    '_tot_': 658},
#  'company_state': {'Alabama': 1,
#                    'Arizona': 5,
#                    'California': 133,
#                    'Colorado': 12,
#                    'Connecticut': 2,
#                    'District': 1,
#                    'District of Columbia': 2,
#                    'Florida': 1,
#                    'Georgia': 3,
#                    'Illinois': 7,
#                    'Indiana': 6,
#                    'Kentucky': 2,
#                    'Louisiana': 2,
#                    'Maryland': 4,
#                    'Massachusetts': 29,
#                    'Michigan': 35,
#                    'Minnesota': 6,
#                    'Missouri': 2,
#                    'Montana': 1,
#                    'Nevada': 4,
#                    'New Jersey': 3,
#                    'New York': 12,
#                    'North Carolina': 6,
#                    'Ohio': 1,
#                    'Oklahoma': 1,
#                    'Oregon': 2,
#                    'Pennsylvania': 7,
#                    'Rhode Island': 1,
#                    'Tennessee': 2,
#                    'Texas': 13,
#                    'Virginia': 3,
#                    'Washington': 8,
#                    '_tot_': 317},
#  'company_team_count': {'1-10': 424,
#                         '101+': 13,
#                         '11-20': 125,
#                         '21-50': 61,
#                         '51-100': 13,
#                         '_tot_': 636},
#  'company_value_chain': {'Automation components': 1,
#                          'Battery R&D': 1,
#                          'Battery manufacturing': 1,
#                          'Cell production': 210,
#                          'Chemical supplier': 1,
#                          'Component/precursor production': 145,
#                          'Construction': 1,
#                          'Consulting': 103,
#                          'Contract Research': 1,
#                          'Data': 1,
#                          'Department of Energy': 1,
#                          'Distribution': 1,
#                          'Distributor and sales': 1,
#                          'Education': 2,
#                          'Electrolyte': 1,
#                          'Electrolyte and Cell R&D': 1,
#                          'Energy infrastructure': 48,
#                          'Equipment manufacturing': 77,
#                          'GOVERNMENT/INTERNATIONAL ORGANIZATION': 1,
#                          'Government funded research': 1,
#                          'Independent power producers': 1,
#                          'Innovation': 1,
#                          'Investment': 1,
#                          'Mineral Exploration and Geoscience': 1,
#                          'Mining': 14,
#                          'Module/pack production': 128,
#                          'Non-Profit': 1,
#                          'Nonprofit': 2,
#                          'Not a battery company': 1,
#                          'OEM': 1,
#                          'Packaging': 1,
#                          'Product integration (electronics)': 49,
#                          'Product integration (stationary storage)': 74,
#                          'Product integration (vehicles': 113,
#                          'Project development': 1,
#                          'ProtoType': 1,
#                          'QA/QC': 1,
#                          'Quality Inspection Equipment': 1,
#                          'R&D': 11,
#                          'R&D and Prototyping': 1,
#                          'Recruitment': 1,
#                          'Recycling': 40,
#                          'Refining': 21,
#                          'Research': 4,
#                          'Research Center': 1,
#                          'Research Institution': 1,
#                          'Research and Coalition Lead': 1,
#                          'Research and development': 1,
#                          'Semiconductor suppliers': 1,
#                          'Software': 81,
#                          'Testing & R&D': 1,
#                          'Testing. Should be a category people... Always overlooked until you need us': 1,
#                          'Utility': 1,
#                          'Vehicle maintenance': 1,
#                          'Venture Capital': 1,
#                          '_tot_': 648,
#                          'car retail': 1,
#                          'development and design': 1,
#                          'education': 1,
#                          'engineering design': 1,
#                          'green chemicals': 1,
#                          'mobility)': 113,
#                          'not for profit trade association': 1,
#                          'research': 2,
#                          'seal': 1,
#                          'with a chemistry resambling that of lithium batteries': 1},
#  'num_days_in_office_list': array([  4.,   3.,   5.,   4.,   5.,   5.,   5.,   2.,   0.,   6.,   6.,
#          5.,   3.,   5.,   5.,   0.,   5.,   5.,   4.,  nan,   5.,   0.,
#          1.,   5.,   5.,   4.,   1.,   0.,   5.,   5.,   5.,   4.,   5.,
#          5.,   5.,   5.,   0.,  45.,   5.,   3.,   5.,   2.,   0.,   5.,
#          5.,   6.,   6.,   5.,   6.,   0.,   5.,   0.,   5.,   5.,   3.,
#          5.,   5.,  32.,   0.,   0.,   0.,   5.,   5.,   5.,   5.,   0.,
#         1., 11.,  2.,  2.,  2.,  2.,  1.,  1.,  2.,  1.,  1.,  5.,  3.,
#         6.,  1.,  1.,  1.,  4., 10., 10.,  2.,  4.,  4.,  1.,  2.,  3.,
#        31., 14.,  2., 11.,  3.,  1., 27.,  4.,  3.,  1.,  5.,  2.,  4.,
#         1.,  1., 13.,  2.,  3.,  2.,  4.,  4.,  1.,  7.,  1., 15.,  2.,
#         4.,  4.,  3.,  1.,  3.,  1.,  6.,  3.,  3.,  1.,  1.,  3.,  5.,
#         1.,  4.,  6.,  4., 13.,  3.,  5.,  3.,  4.,  1.,  3.,  1.,  2.,
#         2.,  3.,  1.,  2., 20.,  3., 14., 30.,  1.,  1.,  6.,  2., 33.,
#         3., 17., 15.,  3.,  1.,  5.,  5.,  8.,  1.,  2.,  3.,  3.,  1.,
#         3.,  1.,  1.,  1.,  3.,  1.,  1.,  2.,  2.,  4.,  2.,  3.,  5.,
#         2.,  7.,  5.,  1.,  1.,  2.,  1.,  1.,  7., 24.,  2.,  2.,  2.,
#        12., 15.]),
#  'num_years_with_company_median': np.float64(2.0)}

# %%
plotter.make_bar_plot_from_dict(res_company_info['company_value_chain'],
                                title='Where does the company fall on the battery value chain?',
                                saveas='company_value_chain.png',
                                num_elements=15,
                                exclusions=['mobility)'],
                                sorted=True,
                                replacements={'Product integration (vehicles' : 'Product integration (vehicles)'})

# %% [markdown]
# ## Role

# %%
res_company_role = analyst.summarize_company_role()
pprint(res_company_role)
# Out:
# {'role_level': {'Career': 112,
#                 'Developing': 61,
#                 'Director/VP': 65,
#                 'Entry': 26,
#                 'Executive': 44,
#                 'Expert': 91,
#                 'Manager': 92,
#                 'Senior': 167,
#                 '_tot_': 658},
#  'role_prev_industries': {'No': 217,
#                           'Yes, in a different role': 187,
#                           'Yes, in a similar role': 254,
#                           '_tot_': 658},
#  'role_prev_role_list': ['Distinguished Member of Technical Staff, Design for '
#                          'Reliability',
#                          'Administrative Assistant',
#                          'product manger',
#                          'Machine Design Engineer',
#                          'Mechanical Engineer - Turbine Airfoils',
#                          'Investment Analyst',
#                          'Product development - body exterior',
#                          'Director of R&D',
#                          'Simulation engineer',
#                          'Automotive engineering for autonomous vehicles',
#                          'Senior Scientist',
#                          'project manager',
#                          'Instrumentation Engineer',
#                          'Patent Analyst',
#                          'Electrical Grid engineer',
#                          'Software Engineer',
#                          'Applications Engineer',
#                          'Scientist',
#                          'R&D in polymers industry',
#                          'Electronics manufacturing industry',
#                          'Senior Sourcing Manager',
#                          'Business Development Manager',
#                          'Senior Engineer',
#                          'Senior Materials Engineer',
#                          'Chemicals',
#                          'Laboratory Scientist',
#                          'engineer',
#                          'Metrology engineer',
#                          'solar expert',
#                          'Materials Scientist',
#                          'Automotive supplier analyst',
#                          'Science education and outreach',
#                          'Software engineer',
#                          'Intern for fuel cell manufacturing, graduate student',
#                          'I had many roles',
#                          'R&D',
#                          'Technical Lead Engineer',
#                          'Product Management',
#                          'Drone',
#                          'Pharmaceutical',
#                          'Consultant',
#                          'Teacher',
#                          'Total quality management',
#                          'Engineer',
#                          'Software development engineer',
#                          'Climate Communication Specialist',
#                          'Consultant',
#                          'Head of b2g',
#                          'Strategy Consultant',
#                          'Postdoctoral Research Associate',
#                          'CAM manufacturing R&D',
#                          'Electrical Engineer',
#                          'Lab technician',
#                          'Design Engineer',
#                          'Engineering Consulting',
#                          'Chartered Accountant Analyst',
#                          'Solar Industry',
#                          'Researcher',
#                          'research engineer',
#                          'Chemist',
#                          'Pulsed Plasma chemical vapor deposition on goose '
#                          'down feathers for Patagonia. manufacturing engineer, '
#                          'Semiconductor equipment, artificial heart valves, '
#                          'rock concert lighting, CNC machining.',
#                          'Wind industry',
#                          'Warehouse Technician',
#                          'Telecom Consultant',
#                          'Electrochemical expert',
#                          'Assistant Professor',
#                          'Project Manager, Software Developer',
#                          'Water chemistry',
#                          'inside sales',
#                          'Battery Engineer',
#                          'production engineer',
#                          'Manufacturing Engineer',
#                          'Research Scientist',
#                          'Researcher',
#                          'Research Scientist',
#                          'Mechanical Engineering',
#                          'Fire Officer',
#                          'Sr. Technical Lead (Development)',
#                          'Materials',
#                          'Battery Engineer',
#                          'Automotive design and Validation engineer',
#                          'Senior Graduate Student Researcher (Engineer & '
#                          'Consultant) / PhD student in Taiwan',
#                          'Quality and Campaign Prevention Supervisor',
#                          'University researcher',
#                          'Sr Product specialist',
#                          'Product Line Manager',
#                          'Maintenance Engineer',
#                          'wave energy developer',
#                          'Technical Sales Manager',
#                          'Technical Applications Engineer/ R&D Chemist',
#                          'Sales',
#                          'Defence',
#                          'IC verification',
#                          'Battery and Power systems analyst',
#                          'Process Engineer',
#                          'Consultant; Engineer',
#                          'semiconductor process engineer',
#                          'Climate Change Officer in local government',
#                          'IT Management and PM Management',
#                          'Principal Scientist',
#                          'Biologist',
#                          'Corrosion engineer',
#                          'COO battery co in China, GM battery co in Canada, GM '
#                          'critical communications co in Canada',
#                          'North American Manager',
#                          'R&D at battery startup',
#                          'Manufacturing',
#                          'Research Scientist, Process Engineer',
#                          'Project management, Investor, BD',
#                          'Researcher and Data Scientist',
#                          'Sales and Marketing of Electronic Test equipment',
#                          'Maintenance engineer',
#                          'Industrial Design',
#                          'University lecturer and researcher',
#                          'Aircraft Maintenance Engineer',
#                          'Oil & lubricants scientist',
#                          'Data anotator',
#                          'Account Manager, Product Manager, Project Manager, '
#                          'Process Engineer',
#                          'Sales Manager',
#                          'Product Support Engineer',
#                          'General Manager',
#                          'CEO',
#                          'Process Engineer',
#                          'Researcher',
#                          'Staff Cell Engineer',
#                          'Program Manager',
#                          'Consultant',
#                          'Technology specialist Sodium Chlorate',
#                          'RUBBER COMPANY',
#                          'researcher / manager in a non-profit',
#                          'Automotive',
#                          'Consultant',
#                          'Key Account Manager',
#                          'R&D',
#                          'Practise Manager Project Services',
#                          'Fixed-term researcher',
#                          'Engineer in electronics',
#                          'Metals',
#                          'Major Account Executive',
#                          'project leader',
#                          'Key Account Manager',
#                          'Performance engineer in gas turbines',
#                          '3D printing internship',
#                          'Associate Professor',
#                          'lubricants',
#                          'Product Line Manager',
#                          'Marketing',
#                          'Senior Scientist',
#                          'R&D Engineer',
#                          'Innovation manager',
#                          'Mechanical Design Engineering',
#                          'R&D technical analyst, Project leader',
#                          'Test Engineer',
#                          'Soldier',
#                          'academic and industrial R&D in the field of '
#                          'catalysis',
#                          'Construction',
#                          'Business development manager',
#                          'Educator',
#                          'Project Managament in the automotive industry',
#                          'Composite Materials Engineer',
#                          'Project Manager',
#                          'Contact cleaning equipment',
#                          'Process Engineer in pharmaceuticals',
#                          'Senior Researcher',
#                          'Builder',
#                          'Director of Sales & Marketing for Specialty Papers '
#                          'Division of GP',
#                          'Chemical Process Engineer',
#                          'ICT Test Enginner; project engineer',
#                          'VP Business Development and Technical Manager',
#                          'R&D Engineer, Solid Oxide Fuel Cells',
#                          'designer',
#                          'M&A',
#                          'Battery Test Engineer',
#                          'Technical Manager in medical devices. Manager of '
#                          'Space projects in earth obervation. Senior DSP '
#                          'design in semiconductor industry. Signal Processing '
#                          'and Communications Engineer',
#                          'Repair and maintenance supervisor',
#                          'R&D personal care',
#                          'Marketing Manager',
#                          'Consulting'],
#  'role_role': {'Advisory': 1,
#                'Analysis': 1,
#                'Communications': 1,
#                'Consultation': 1,
#                'Data Analysis': 2,
#                'Diagnosis and repair': 1,
#                'Education/Training': 1,
#                'Engineering and design': 355,
#                'Environment': 1,
#                'Facilities': 40,
#                'Finance': 52,
#                'FuSa Analysis': 1,
#                'FuSa Audits & Assessment': 1,
#                'FuSa Concepts': 1,
#                'Fundraising': 2,
#                'Geoscience technical and field work': 1,
#                'IT infrastructure': 22,
#                'Investor': 47,
#                'Legal': 37,
#                'Managing people': 207,
#                'Managing projects or programs': 289,
#                'Manufacturing and production': 107,
#                'Marketing': 107,
#                'New product introduction (NPI)': 158,
#                'Product design': 153,
#                'Quality': 121,
#                'R+D': 1,
#                'Recruiting': 79,
#                'Recruitment': 1,
#                'Research and development': 364,
#                'Safety & Compliance': 1,
#                'Safety Architecture & Design Definition': 1,
#                'Safety Case creation': 1,
#                'Safety and Training': 1,
#                'Sales and services': 122,
#                'Software development': 68,
#                'Software integration': 47,
#                'Stakeholder Technical Management': 1,
#                'Strategy and planning': 205,
#                'Supply chain': 90,
#                'TECHNOLOGY MONITORING': 1,
#                'Technical writing for industry publications': 1,
#                'Testing and validation': 229,
#                '_tot_': 660,
#                'administration': 1,
#                'costing': 1,
#                'market research': 1,
#                'partnerships': 1,
#                'public policy': 1,
#                'teaching': 1},
#  'role_title_list': ['Manager, R&D',
#                      'Design for Reliability',
#                      'Manager',
#                      'battery design release engineer',
#                      'Senior Battery Engineer',
#                      'Production Team Member',
#                      'post doctoral research associate',
#                      'Principal Engineer',
#                      'Asst. General Manager',
#                      'Research assistant',
#                      'Manager, Strategy and Corporate Development',
#                      'Content Manager',
#                      'Operations Supervisor',
#                      'Sales Director',
#                      'Engineering Consultant',
#                      'Associate Scientist',
#                      'Development Engineer',
#                      'BATTERY FIELD SYSTEMS ENGINEER',
#                      'Manager Consultant',
#                      'Principal Engineer',
#                      'Director',
#                      'Business development manager',
#                      'Electrolyte Scientist',
#                      'Senior Engineer',
#                      'Chief Technology Officer',
#                      'Director',
#                      'Staff Engineer',
#                      'Scientist',
#                      'Engineer',
#                      'Senior engineer',
#                      'System engineer',
#                      'Business development',
#                      'Algorithms engineer',
#                      'Commercial',
#                      'Director of R&D',
#                      'Senior Scientist',
#                      'Senior Application Engineer',
#                      'sales engineer',
#                      'Senior Engineer',
#                      'industrial engineer',
#                      'Senior Material Engineer',
#                      'Business Development',
#                      'Founder',
#                      'VP of Engineering',
#                      'Head of Growth Marketing',
#                      'Research Engineer',
#                      'CEO',
#                      'Principal Process Engineer',
#                      'Battery Materials Development Researcher',
#                      'Hybrid/BESS energy analyst',
#                      'Senior Software Engineer',
#                      'Product Manager',
#                      'Business Development Director',
#                      'VP R&D',
#                      'test engineer',
#                      'Hardware Developer',
#                      'CEO',
#                      'Manager',
#                      'Senior R&D Scientist',
#                      'Engineering Manager',
#                      'Senior Consultant',
#                      'Technical Solution Engineer',
#                      'CTO',
#                      'Staff Engineer',
#                      'CEO',
#                      'Lead Battery Scientist',
#                      'Deputy manager Battery operations',
#                      'Senior Director of Procurement',
#                      'Director of Member Success',
#                      'Manager',
#                      'Engineer',
#                      'Test & Validation Engineer',
#                      'Materials Engineer',
#                      'Technical Program Manager',
#                      'Field Application Engineer',
#                      'Senior Fellow',
#                      'Senior battery technology scientist',
#                      'post doc',
#                      'Lead Engineer',
#                      'Sr. Staff Engineer',
#                      'Process engineer',
#                      'Director of Marketing & Communications',
#                      'Battery algorithm development',
#                      'co-CEO',
#                      'ceo',
#                      'Senior scientist',
#                      'Battery Research Scientist',
#                      'Staff Software Engineer',
#                      'Energy market specialist',
#                      'Smts',
#                      'mechanical design engineer',
#                      'Research Associate',
#                      'Principal',
#                      'President and CTO',
#                      'Senior Product Scientist',
#                      'Director of Business Development',
#                      'Battery Simulation Engineer',
#                      'Director of Operations',
#                      'MD',
#                      'battery engineer',
#                      'Electrochemical Engineer',
#                      'Senior ATE System Technical Manager',
#                      'Research scientist',
#                      'Senior Vice President and Co-Founder',
#                      'Director of Research',
#                      'Sr. Director of R&D',
#                      'Test Engineer',
#                      'Engineering Manager',
#                      'Technical Marketing Consultant',
#                      'Senior Engineer',
#                      'Senior researcher',
#                      'Senior mechanical engineer',
#                      'Battery Engineer',
#                      'Principal',
#                      'Lead Polymer Scientist',
#                      'Principal Scientist',
#                      'Founder',
#                      'SCIENTIST',
#                      'Assistant Manager',
#                      'Staff R&D Scientist',
#                      'Advisor',
#                      'Engineer',
#                      'Production incharge',
#                      'Senior Engineer, R&D Operations',
#                      'R&D Manager',
#                      'ASSISTANT ENGINEER DESIGN',
#                      'Principal Engineer',
#                      'technical expert',
#                      'Director of Product Management',
#                      'Director, Product Management',
#                      'Head of Costing',
#                      'battery system department Manager',
#                      'Senior Simulation Engineer',
#                      'Service Operations coordinator',
#                      'Cell Design Engineer',
#                      'Executive Director',
#                      'Senior Engineer II',
#                      'Industrial Research Analyst',
#                      'Instructor',
#                      'Lead Chemist- Lab Manager',
#                      'Staff Engineer',
#                      'Director of Engineering',
#                      'R&D Engineer',
#                      'Development Engineer',
#                      'Senior product manager',
#                      'R&D scientist',
#                      'Construction director',
#                      'Senior cell development engineer',
#                      'Project Engineer',
#                      'Battery engineering specialist',
#                      'Head of division',
#                      'Skills director',
#                      'Development Engineer',
#                      'Manager',
#                      'Battery Process Engineer',
#                      'Analyst',
#                      'Global Sales Manager - Technical Sales Engineer',
#                      'Senior manager, business development',
#                      'Battery safety lead engineer',
#                      'project manager',
#                      'Head of Battery Engineering',
#                      'Sr. Technical Project Manager, Battery Engineering',
#                      'Technica Fellow - Principal Controls Engineer',
#                      'Cell Design Engineer',
#                      'Marketing Intelligence Manager',
#                      'Manager',
#                      'scientist',
#                      'Test manager',
#                      'Cell Process Development',
#                      'Business Development Manager',
#                      'Chief Product Officer',
#                      'Battery management systems',
#                      'Project Engineer',
#                      'Project Manager',
#                      'Corporate Development Analyst',
#                      'Product Stewardship Specialist',
#                      'Project Engineer',
#                      'Key Account Manager',
#                      'Techonlogy Manager',
#                      'EUROPEAN SALES DIRECTOR',
#                      'Sales Manager',
#                      'Engineer',
#                      'technical leader',
#                      'Senior Executive',
#                      'Sales Operations Director',
#                      'Materials Scientist',
#                      'Li-ION HV Battery Pack Process and Production Leader',
#                      'Scientist/Project Manager',
#                      'Development of new materials for electrodes of Li-ion '
#                      'batteries',
#                      'CEO',
#                      'project development',
#                      'R&D Scientist',
#                      'Application Scientist',
#                      'System Engineer',
#                      'technical fellow',
#                      'Consultant',
#                      'Manufacturing Engineer',
#                      'Research technician',
#                      'Senior Research Scientist -II - LFP',
#                      'Principal Analyst',
#                      'Business development manager',
#                      'Process Engineer',
#                      'Senior Research Scientist',
#                      'Senior Engineer',
#                      'Staff Battery Cell Design Engineer',
#                      'Energy Storage Unit Manager',
#                      'Logistics technical specialist',
#                      'BESS Product manager',
#                      'Quality control lead',
#                      'Energy Trainer',
#                      'Lead Engineer',
#                      'Senior Battery Scientist',
#                      'Product Owner',
#                      'BDM battery/epower',
#                      'Sales Engineer',
#                      'Business Development',
#                      'Senior Scientist',
#                      'Senior Program Manager',
#                      'general manager costing department',
#                      'Business Development',
#                      'Research Engineer - Testing and Validation',
#                      'Business Development Manager',
#                      'Embedded Hardware Engineer',
#                      'Scientist',
#                      'Business development',
#                      'Senior algorithms engineer',
#                      'Senior Project Lead Engineer',
#                      'Director',
#                      'Manager New Analytical Techniques',
#                      'Research Engineer',
#                      'Research Scientist',
#                      'R&D Engineer',
#                      'Battery Project Engineer',
#                      'Technical Principal',
#                      'Senior Materials Scientist',
#                      'Chief Engineer',
#                      'Sr. Engineering Manager',
#                      'Manufacturing associate',
#                      'Associate Scientist',
#                      'Principal',
#                      'Advanced failure analysis engineer',
#                      'Battery Engineer',
#                      'Battery Engineer - Formation & Test',
#                      'Senior Engineer',
#                      'Consultant Engineer & Trainer',
#                      'Principal Functional Safety Engineer II',
#                      'Staff Product Manager',
#                      'EHS Manager',
#                      'Battery Modeling Engineer',
#                      'Program Manager, Battery',
#                      'Senior sales manager',
#                      'VP - Research',
#                      'Product and Process development Lead - Battery '
#                      'Manufacturing',
#                      'Sr. Manager, Battery Supplier Development and Quality',
#                      'Battery RnD Engineer',
#                      'Solid State Battery Team Leader',
#                      'R&D',
#                      'Program Manager',
#                      'Product engineer - electrodes',
#                      'Sr mechanical engineer',
#                      'Project design engineer',
#                      'Education and Training Director',
#                      'Product Manager',
#                      'Senior Business Development Manager',
#                      'Sr engineer',
#                      'Electrical Engineer',
#                      'Senior Engineer',
#                      'Manager',
#                      'Business Development Manager',
#                      'Associate Professor',
#                      'Systems Engineer',
#                      'Contracts Leader',
#                      'VP Business Development',
#                      'CTO',
#                      'Reliability Engineer',
#                      'Field Application Engineer',
#                      'R&D Scientist',
#                      'Director of Technology',
#                      'Senior Manager, R&D',
#                      'President',
#                      'Lead Engineer BESS',
#                      'Sr Talent Acquisition Specialist',
#                      'Test and validation engineer',
#                      'Market Quality Specialist',
#                      'Senior Supplier Capacity Manager',
#                      'Senior Research Scientist',
#                      'Account manager',
#                      'Technology Planning Manager',
#                      'Thermal Battery Abuse Test Technician',
#                      'CTO',
#                      'System Architecture Engineer',
#                      'Business Development',
#                      'Sr. Scientist',
#                      'senior chemical engineer',
#                      'EHS & Compliance Manager',
#                      'Development Engineer',
#                      'Process Engineer III',
#                      'Researcher',
#                      'Project Manager for new factory build projects',
#                      'Development Engineer',
#                      'senior process development engineer',
#                      'Junior Data Scientist',
#                      'BMS Algorithm Developer',
#                      'Sn. Scientist',
#                      'After Sales Service Engineer',
#                      'Associate Process Engineer',
#                      'Principal engineer',
#                      'Lead Scientist',
#                      'Operations Manager',
#                      'VP R&D',
#                      'Lab Manager',
#                      'Director HR',
#                      'Chief Commercial Officer',
#                      'Director',
#                      'CEO, business development',
#                      'Marketing Communications Manager',
#                      'Advanced failure analysis engineer',
#                      'Assistant Professor',
#                      'Technical Sales Engineer 2',
#                      'Marketing',
#                      'Lead Engineer',
#                      'Sr Director Business Operations',
#                      'Principal Engineer product safety',
#                      'Business Development Manager',
#                      'Senior Engineer',
#                      'Lead Advisor',
#                      'Founder, CEO',
#                      'Senior Manager Battery Design Engineering',
#                      'Sr battery scientist',
#                      'Manager / Principle Scientist',
#                      'Senior Battery Lab Technician',
#                      'Program manager',
#                      'Senior Battery Systems Engineer',
#                      'Sr. BD manager',
#                      'Staff Performance Engineer',
#                      'Quality Manager',
#                      'Content Developer and Trainer',
#                      'Engineer',
#                      'Associate cell engineer',
#                      'GM Geology and Mining',
#                      'Manufacturing engineer',
#                      'sales coach',
#                      'Project Research Engineer',
#                      'Professor of Practice',
#                      'Assistant manager r&d',
#                      'R&D Engineer',
#                      'Coordinator in R&D',
#                      'researcher',
#                      'Shop lead',
#                      'Design',
#                      'CEO',
#                      'Battery Safety Specialist',
#                      'R&D Manager',
#                      'Process Development',
#                      'Global Commodity Lead',
#                      'COO',
#                      'analytical testing',
#                      'Principal engineer battery modelling',
#                      'Junior Battery Engineer',
#                      'Innovation Analyst',
#                      'Modelling Engineer',
#                      'Business Development Manager',
#                      'Team Lead',
#                      'Global Product Manager',
#                      'Managing Director',
#                      'Recruitment Consultant',
#                      'Head of battery test and diagnostics',
#                      'Manager R&D',
#                      'Major Project Director',
#                      'Senior Fellow',
#                      'Strategy Manager',
#                      'Formation Technology Leader',
#                      'Director -Co Founder',
#                      'Researcher',
#                      'Research Scientist',
#                      'Area Sales Manager',
#                      'Lead Engineer',
#                      'Consultant',
#                      'Production Engineer',
#                      'Battery engineer III',
#                      'Cell Engineer',
#                      'Staff Product Manager',
#                      'President',
#                      'CTO',
#                      'Senior strategist',
#                      'Corporate Development',
#                      'Development Engineer',
#                      'SCIENTIFIC OFFICER',
#                      'CTO',
#                      'Process Engineering',
#                      'Senior Researcher',
#                      'Senior Specialist Engineer',
#                      'Battery materials engineer',
#                      'Research Associate',
#                      'Senior researcher',
#                      'Manager Technology',
#                      'Managing Director',
#                      'Global Director Talent Acquisition & Talent Integration',
#                      'Sr. Controls Engineer',
#                      'Staff Engineer',
#                      'Senior Engineer',
#                      'Geology Consultant & Founder',
#                      'Procurement Manager',
#                      'Battery Pack Lead DRE',
#                      'North American Sales Manager',
#                      'Marketing and Technical Service Manager',
#                      'Recruiting Consultant',
#                      'Sr Talent Acquisition Partner',
#                      'Co-Founder and Group Managing Director',
#                      'Engineering Manager- Fuel & New Energies',
#                      'Manager',
#                      'Data Analyst',
#                      'Technology & IP Analyst',
#                      'Senior Project manager',
#                      'battery modelling and simulation engineer',
#                      'project and global category buyer',
#                      'Battery development engineer',
#                      'Account Manager',
#                      'Sr. R&D Manager',
#                      'VP Business Development',
#                      'Scientist',
#                      'Marketing Director, Sales Manager',
#                      'senior- product establishment',
#                      'Research Associate',
#                      'Battery leader',
#                      'Battery Expert',
#                      'Junior Battery Engineer',
#                      'Finance director',
#                      'Senior Director Business Development',
#                      'Research Associate',
#                      'Project Manager',
#                      'project manager spezialiced',
#                      'Head of engineering',
#                      'Head of Product Management, VP Product',
#                      'Renewable Energy Consultant',
#                      'Managing director',
#                      'Project Manager and Senior Research and Development',
#                      'CTO',
#                      'Market Quality Specialist',
#                      'R&D Manager',
#                      'General Manager',
#                      'Material Engineering Technician',
#                      'Business Development',
#                      'Research Fellow',
#                      'Senior Business Development Manager',
#                      'Laboratory Instructor',
#                      'Senior research',
#                      'senior researcher',
#                      'Supervisor',
#                      'Intern',
#                      'Application Manager',
#                      'Manager process engineering',
#                      'professor',
#                      'Battery Mechanical Design Engineer',
#                      'Vehicle Engineer',
#                      'Business analyst',
#                      'Manager Material Science R&D',
#                      'Senior battery management system and general power '
#                      'electronic hardware design engineer',
#                      'Senior Battery System Engineer',
#                      'Partner',
#                      'Battery Consultant',
#                      'Head of partnerships, benchmark and public fundings',
#                      'Head of Battery Materials',
#                      'Managing Director',
#                      'Major Projects Director',
#                      'Lab Manager',
#                      'Leading the market development team in EMEA',
#                      'Team Leader',
#                      'cmo',
#                      'Senior Staff Field Applications Engineer',
#                      'Battery Algorithm',
#                      'Principal Scientist',
#                      'Sales Leader',
#                      'Director Business Development',
#                      'MD, CEMO',
#                      'Cell design engineer',
#                      'Business developer',
#                      'Sr Business Development Manager',
#                      'Electrical Systems Manager',
#                      'Battery Systems Engineer',
#                      'CTO',
#                      'Research scientist',
#                      'Product',
#                      'Product manager',
#                      'New process implementation engineer',
#                      'Founder, Chief Strategy Officer',
#                      'Account Manager',
#                      'Senior Mechanical Engineer',
#                      'Supply Chain Manager',
#                      'Director',
#                      'Sales Engineer',
#                      'Vice President',
#                      'VP R&D',
#                      'Director, Renewable Energy Solutions NA',
#                      'COO',
#                      'Staff Reliability Engineer',
#                      'Sr. Mechanical Engineer - Battery',
#                      'Materials Analyst',
#                      'Battery Data Analyst',
#                      'Team leader',
#                      'Software Engineer',
#                      'Testing Engineer',
#                      'Purchasing Manager',
#                      'R and D Project Chemist',
#                      'BD manager',
#                      'Battery Scientist II',
#                      'Business Development Manager',
#                      'Senior Research Scientist2',
#                      'Data Engineer',
#                      'Senior Test Engineer',
#                      'Cell Test Engineer',
#                      'Manager Quality Labs',
#                      'Research Scientist',
#                      'Test Engineer',
#                      'Sr materials engineer',
#                      'Battery Safety Engineer',
#                      'Sr scientist',
#                      'Founder',
#                      'Electrochemical Engineer',
#                      'Program Manager',
#                      'Test Manager',
#                      'Sales&Marketing',
#                      'Technology specialist',
#                      'Head of Engineering',
#                      'Solid State Battery Team Leader',
#                      'Senior Technical Manager, Charging Systems',
#                      'Senior Characterisation Engineer',
#                      'Principal',
#                      'Senior Data Scientist',
#                      'Ceo',
#                      'Head of Advanced Battery Separator Group',
#                      'Project Scientist',
#                      'Battery System Engineer',
#                      'Part Owner, business development, electrician',
#                      'Managing Director',
#                      'CTO',
#                      'Cell Manufacturing Engineer',
#                      'Associate Cell Engineer',
#                      'Research Engineer',
#                      'Process Engineer',
#                      'Senior test engineer',
#                      'Senior Director, BD',
#                      'Energy Solutions Application Engineer',
#                      'research scientist',
#                      'business head',
#                      'St. Cell Tech',
#                      'Cell & Process Engineer',
#                      'sales',
#                      'Staff Scientist',
#                      'R & D Manager',
#                      'Director',
#                      'Sales Manager',
#                      'Director R&D and Business Development',
#                      'Battery Test Operations Manager',
#                      'Head of Engineering',
#                      'R&D Team Leader',
#                      'Head of Business Development',
#                      'industrial product establishment',
#                      'Electrochemical Engineer',
#                      'Senior Mechanical Design Engineer',
#                      'no answer',
#                      'Chemist',
#                      'Research Engineer',
#                      'Principal Engineer',
#                      'Senior technical expert'],
#  'role_why_choose': {'Autonomy and independence': 156,
#                      'Career growth opportunities': 296,
#                      'Challenge and innovation': 396,
#                      'Competitive salary and benefits': 190,
#                      'Confidence in reported results': 1,
#                      'Desirable work location': 197,
#                      "Didn't have a choice. I love ev tech but very few jobs in recruiting. I'm lucky I have a job.": 1,
#                      'Due to there are less jobs': 1,
#                      'Employment': 2,
#                      'Entrepreneurship': 1,
#                      'Family reason': 1,
#                      'Female owned business': 1,
#                      'Founded the company': 1,
#                      'Founder': 1,
#                      'Had no choice. The site has been taken over': 1,
#                      'Hiring During COVID': 1,
#                      'Hybrid/remote work': 123,
#                      'I Co-founded the Company': 1,
#                      'I was previously unemployed': 1,
#                      'Job security': 99,
#                      'Laid off at a well paying start up company that makes electric trucks': 1,
#                      'Learning and skills development': 326,
#                      'Love for what I do': 1,
#                      'Love my job': 1,
#                      'Mentoring young professionals': 1,
#                      'My own company': 1,
#                      'Needed a job': 1,
#                      'New business line in existing co': 1,
#                      'New technology': 1,
#                      'OK salary': 1,
#                      'Own company': 1,
#                      'Passion': 1,
#                      'Passion for product': 1,
#                      'Really good benefits': 1,
#                      'Reputation in industry': 1,
#                      'Socially interesting environment': 1,
#                      'Sole director of own company': 1,
#                      'Sponsor work visa': 1,
#                      'Supportive team and environment': 200,
#                      'Sustainability and impact': 238,
#                      'This is my former company': 1,
#                      'To learn about funding early stage projects': 1,
#                      'Too old to get real job': 1,
#                      'Work-life balance': 189,
#                      '_tot_': 643,
#                      'development on earlier career': 1,
#                      'family heritage': 1,
#                      'hint. This current opportunity came in fast and was close to home': 1,
#                      'need of part time role': 1,
#                      'vans and SUVs.. hint': 1}}

# %%
plotter.make_bar_plot_from_dict(res_company_role['role_level'],
                                title='What is your current level?',
                                saveas='company_role_level.png'
)

plotter.make_bar_plot_from_dict(
    res_company_role['role_role'],
    title='What does your role involve?',
    saveas='company_role.png',
    num_elements=23,
    sorted=True
)

plotter.make_bar_plot_from_dict(
    res_company_role['role_why_choose'],
    title='Why did you choose your current role and company?',
    saveas='company_role_why_choose.png',
    num_elements=11,
    sorted=True
)

plotter.make_bar_plot_from_dict(
    utils.sort_dict(res_company_role['role_prev_industries'], by='keys', reverse=True),
    title='Have you previously worked in other industries?',
    saveas='company_role_previous_industries.png'
)

# %%
res_company_role['role_prev_role_list']
# Out:
# ['Distinguished Member of Technical Staff, Design for Reliability',
#  'Administrative Assistant',
#  'product manger',
#  'Machine Design Engineer',
#  'Mechanical Engineer - Turbine Airfoils',
#  'Investment Analyst',
#  'Product development - body exterior',
#  'Director of R&D',
#  'Simulation engineer',
#  'Automotive engineering for autonomous vehicles',
#  'Senior Scientist',
#  'project manager',
#  'Instrumentation Engineer',
#  'Patent Analyst',
#  'Electrical Grid engineer',
#  'Software Engineer',
#  'Applications Engineer',
#  'Scientist',
#  'R&D in polymers industry',
#  'Electronics manufacturing industry',
#  'Senior Sourcing Manager',
#  'Business Development Manager',
#  'Senior Engineer',
#  'Senior Materials Engineer',
#  'Chemicals',
#  'Laboratory Scientist',
#  'engineer',
#  'Metrology engineer',
#  'solar expert',
#  'Materials Scientist',
#  'Automotive supplier analyst',
#  'Science education and outreach',
#  'Software engineer',
#  'Intern for fuel cell manufacturing, graduate student',
#  'I had many roles',
#  'R&D',
#  'Technical Lead Engineer',
#  'Product Management',
#  'Drone',
#  'Pharmaceutical',
#  'Consultant',
#  'Teacher',
#  'Total quality management',
#  'Engineer',
#  'Software development engineer',
#  'Climate Communication Specialist',
#  'Consultant',
#  'Head of b2g',
#  'Strategy Consultant',
#  'Postdoctoral Research Associate',
#  'CAM manufacturing R&D',
#  'Electrical Engineer',
#  'Lab technician',
#  'Design Engineer',
#  'Engineering Consulting',
#  'Chartered Accountant Analyst',
#  'Solar Industry',
#  'Researcher',
#  'research engineer',
#  'Chemist',
#  'Pulsed Plasma chemical vapor deposition on goose down feathers for Patagonia. manufacturing engineer, Semiconductor equipment, artificial heart valves, rock concert lighting, CNC machining.',
#  'Wind industry',
#  'Warehouse Technician',
#  'Telecom Consultant',
#  'Electrochemical expert',
#  'Assistant Professor',
#  'Project Manager, Software Developer',
#  'Water chemistry',
#  'inside sales',
#  'Battery Engineer',
#  'production engineer',
#  'Manufacturing Engineer',
#  'Research Scientist',
#  'Researcher',
#  'Research Scientist',
#  'Mechanical Engineering',
#  'Fire Officer',
#  'Sr. Technical Lead (Development)',
#  'Materials',
#  'Battery Engineer',
#  'Automotive design and Validation engineer',
#  'Senior Graduate Student Researcher (Engineer & Consultant) / PhD student in Taiwan',
#  'Quality and Campaign Prevention Supervisor',
#  'University researcher',
#  'Sr Product specialist',
#  'Product Line Manager',
#  'Maintenance Engineer',
#  'wave energy developer',
#  'Technical Sales Manager',
#  'Technical Applications Engineer/ R&D Chemist',
#  'Sales',
#  'Defence',
#  'IC verification',
#  'Battery and Power systems analyst',
#  'Process Engineer',
#  'Consultant; Engineer',
#  'semiconductor process engineer',
#  'Climate Change Officer in local government',
#  'IT Management and PM Management',
#  'Principal Scientist',
#  'Biologist',
#  'Corrosion engineer',
#  'COO battery co in China, GM battery co in Canada, GM critical communications co in Canada',
#  'North American Manager',
#  'R&D at battery startup',
#  'Manufacturing',
#  'Research Scientist, Process Engineer',
#  'Project management, Investor, BD',
#  'Researcher and Data Scientist',
#  'Sales and Marketing of Electronic Test equipment',
#  'Maintenance engineer',
#  'Industrial Design',
#  'University lecturer and researcher',
#  'Aircraft Maintenance Engineer',
#  'Oil & lubricants scientist',
#  'Data anotator',
#  'Account Manager, Product Manager, Project Manager, Process Engineer',
#  'Sales Manager',
#  'Product Support Engineer',
#  'General Manager',
#  'CEO',
#  'Process Engineer',
#  'Researcher',
#  'Staff Cell Engineer',
#  'Program Manager',
#  'Consultant',
#  'Technology specialist Sodium Chlorate',
#  'RUBBER COMPANY',
#  'researcher / manager in a non-profit',
#  'Automotive',
#  'Consultant',
#  'Key Account Manager',
#  'R&D',
#  'Practise Manager Project Services',
#  'Fixed-term researcher',
#  'Engineer in electronics',
#  'Metals',
#  'Major Account Executive',
#  'project leader',
#  'Key Account Manager',
#  'Performance engineer in gas turbines',
#  '3D printing internship',
#  'Associate Professor',
#  'lubricants',
#  'Product Line Manager',
#  'Marketing',
#  'Senior Scientist',
#  'R&D Engineer',
#  'Innovation manager',
#  'Mechanical Design Engineering',
#  'R&D technical analyst, Project leader',
#  'Test Engineer',
#  'Soldier',
#  'academic and industrial R&D in the field of catalysis',
#  'Construction',
#  'Business development manager',
#  'Educator',
#  'Project Managament in the automotive industry',
#  'Composite Materials Engineer',
#  'Project Manager',
#  'Contact cleaning equipment',
#  'Process Engineer in pharmaceuticals',
#  'Senior Researcher',
#  'Builder',
#  'Director of Sales & Marketing for Specialty Papers Division of GP',
#  'Chemical Process Engineer',
#  'ICT Test Enginner; project engineer',
#  'VP Business Development and Technical Manager',
#  'R&D Engineer, Solid Oxide Fuel Cells',
#  'designer',
#  'M&A',
#  'Battery Test Engineer',
#  'Technical Manager in medical devices. Manager of Space projects in earth obervation. Senior DSP design in semiconductor industry. Signal Processing and Communications Engineer',
#  'Repair and maintenance supervisor',
#  'R&D personal care',
#  'Marketing Manager',
#  'Consulting']

# %% [markdown]
# ## Company Skills

# %%
res_company_skills = analyst.summarize_company_skills()
pprint(res_company_skills)
# Out:
# {'barriers_to_talent_list': ['Startups are fighting headwinds in terms of '
#                              'market and investment, startup culture is not '
#                              'always the most professional, incumbents are '
#                              'hard to displace',
#                              'Location   (Michigan? no!)',
#                              'Perception, Recruiters, Judgement',
#                              'location, the potential of company or program to '
#                              'succeed, team environment,',
#                              'Lack of training programs specifically for the '
#                              'battery industry, lack of awareness of the '
#                              'battery industry',
#                              'Lack of Specialised People; Large Growth in Job '
#                              'Demand; Cyclic Industry',
#                              'no knowledge of tech',
#                              'Lack of Innovative Thinking & Patience',
#                              'Unwillingness to consider transferable skills',
#                              'Not many people with such knowledge.',
#                              'competition from higher paying companies; '
#                              'physical location constraints',
#                              'not much battery manufacturing in the US; '
#                              'electrochemistry is hard unless you are formally '
#                              'trained in it',
#                              'Entreprise projects',
#                              'Not real qualified engineers on the battery '
#                              'technology and understanding of the systems',
#                              'Boring field',
#                              'Too much flux in start up companies related to '
#                              'battery industry',
#                              'Talents are abundant these days，positions are '
#                              'scarce',
#                              'Salary',
#                              'lack of trained professional',
#                              'lack of qualified workers',
#                              'Difficult skillset',
#                              'Increased Training, Better Career Opportunities, '
#                              'More employment benefits',
#                              'Not enough candidates; Not good reach; Not '
#                              'enough material to prepare',
#                              'Knowledge, relevant skills, competitive '
#                              'compensation',
#                              'availability of talent',
#                              'Cyclical growing and collapsing market',
#                              'Outreach',
#                              'Availability of talent ready to hit the ground '
#                              'running into a role (ie sufficient area '
#                              'knowledge)',
#                              'qualified and independent thinkers',
#                              'Compensation; location',
#                              'Compensation; Work Life Balance; Risk',
#                              'experience; discipline; degree',
#                              'no prior school or college education',
#                              'Salary ; benefits ; contract length',
#                              'risk/lack of security, compensation, lack of '
#                              'skilled talent',
#                              'Training experience and exposure',
#                              'Knowledge of the industry 1, Stage of market 2,',
#                              'Lack of schooling; industry knowledge',
#                              'Practical skills and understanding safety '
#                              'challenges',
#                              'Lack of job security. Competitive employment '
#                              'market. Lack of awareness to the indusrry',
#                              '1. Enough people coming through appropriate '
#                              'educational experience, 2. Citizenship, Visa’s '
#                              '3. Uneven funding',
#                              'compensation; good career path; location',
#                              "The hiring teams don't know what level of "
#                              "experience they're looking for. The interviews I "
#                              'gave in the Spring 2024 quarter- people in my '
#                              'hiring team were being laid off AS i was '
#                              'interviewing at the same time',
#                              'Education and training gaps, competition among '
#                              'industry, specialised knowledge',
#                              "We can't afford to hire",
#                              'Location, salary',
#                              'Overspecialized in degrees',
#                              'academic elitism and chronyism',
#                              'Compensation, Location',
#                              'Lack of resources for internal growth and '
#                              'development once hired, Inability for small '
#                              'startups to provide reasonable benefits, Lack of '
#                              'training in certain disciplines',
#                              'Availability of people',
#                              'Geographical concentration of certain talents',
#                              'location, limited pool of candidates, lack of '
#                              'cross functional skills',
#                              'Lack of industry knowledge, pay, candidates work '
#                              'ethic',
#                              'finding the right applicants, elitism & bias',
#                              'Electrical knowledge; Battery safety; Analytics '
#                              'thinking',
#                              'Lack of good talent, Salary budget',
#                              'Funding',
#                              'Compensation; requirement to travel',
#                              'not enough opportunities, companies are too few',
#                              '1) Lack of battery education',
#                              'Location; Lack of training programs; '
#                              'Compensation',
#                              'Funding in our case. Hard to hire talent too as '
#                              'a small company as talent is attracted to bigger '
#                              'companies.',
#                              'Employer unwillingness to compensate skilled '
#                              'candidates and train prospective candidates',
#                              'Lack of availability',
#                              'na',
#                              'Competition; Training; Location',
#                              'gap between industry & academia; lack of folks '
#                              'with both technical & business background; lack '
#                              'of focus on manufacturing prowess and '
#                              'scalability',
#                              'Barrier 1 - unwillingness to recognize battery '
#                              'experience outside chemistry of interest;',
#                              'skills, knowledge and communication skills',
#                              'Scarcity of professionals; Salary (country '
#                              'specific)',
#                              'Competitive Pay',
#                              'Low expertise in the field',
#                              'Lack of specialists, Salary expectations, '
#                              'Competition with big players',
#                              'nascent talent pool relying on transferable '
#                              'skills',
#                              'Skill; Knowledge of electrochemistry',
#                              'competitive salary,',
#                              'looking for prior battery experience instead of '
#                              'transferable skills',
#                              'Work experience, different scales in academic '
#                              'and industry, managerial skills',
#                              'depth in staff with experience 1, not enough '
#                              'STEM background 2, inflexibility 3',
#                              'Idk',
#                              'location; compensation',
#                              'Poor job descriptions; lack of battery '
#                              'fundamentals skills; knowledgeable balance '
#                              'between chemistry & engineering skills',
#                              'lack of qualified people; inability for start-up '
#                              'to pay competitive salaries; location',
#                              'industry knowledge',
#                              'market price;geographic location;skillset',
#                              'hands on experience; knowledge',
#                              'Lack of hands on practical experience in a lab; '
#                              'impractical spreadsheet math and planning',
#                              'The talents themselves',
#                              'visa sponsorship',
#                              'Money, and work-life balance... The lack of it '
#                              'that is, at a small companies and startups, '
#                              "kills recruitment if you don't offer large "
#                              'salaries and substantial benefits.',
#                              'hands on knowledge; quality assurance norms',
#                              'Geographic pay differences; centralized '
#                              'manufacturing/R&D requires skilled talent to '
#                              'move for the job',
#                              'limited number of educated individual',
#                              'Barrier 1: relevent battery skills and '
#                              'knowledge; barrier 2: huge hiring competition '
#                              'for a small talent pool; barrier 3: hiring and '
#                              'lay-off fluctuations within the industry',
#                              'Salary expectations; skills set; visa '
#                              'requirement',
#                              'Compensation package',
#                              'Connection, Communication, Competitive mMarkets',
#                              'Not competitive pay, high risk of layoffs, '
#                              'industry complexity',
#                              'available talent',
#                              'Lack of experienced candidates',
#                              '"Stable companies"; "stable industry"; '
#                              '"fragmented technical knowledge"',
#                              'Location, Compensation',
#                              'lack of quality students',
#                              'lack of on the job experience',
#                              'New field',
#                              'Cost',
#                              'Talent Scouting, Undervalued Role, Overhyped '
#                              'Expectations',
#                              'Politics in company,favorism, partiality',
#                              'Mismatch in expectations, companies being too '
#                              'greedy and elitist',
#                              'Battery industry experience',
#                              'ACADEMICS',
#                              'Small pool of experienced and competent '
#                              'engineers',
#                              'availability',
#                              'Compensation, scarcity of experienced talent',
#                              'location; compensation; missing of technical '
#                              'background',
#                              'Lack of Talent pool',
#                              'In my Country evert talented or experienced '
#                              'person left the Country',
#                              'Talent shortage',
#                              'strong semiconductor industry, lower priority '
#                              'due to weak battery industry in last decade',
#                              'Companies lacking competitive salaries, not '
#                              'enough kids going to trade schools and '
#                              'assumption most of these roles should be held by '
#                              'men',
#                              'Concrete experience (evidence of capability / '
#                              'demonstrable experience)',
#                              'high salary, lack of skilled people',
#                              'Package; Resource Support; Team Support',
#                              'No opinion',
#                              'New tech;',
#                              'Prior Knowledge',
#                              'Training, hands on developmental programs',
#                              'People not trained well, or not trained at all. '
#                              'People too narrow minded and not willing to '
#                              'learn.',
#                              '"Location;Competition for talent;Future '
#                              'perspective in relation to political and '
#                              'business commitment"',
#                              'Missing hands on experience',
#                              'salaries, relocation costs, opportunities for '
#                              'continuous improvement',
#                              'No local experienced people',
#                              'Compensation; work scope; maturity of the '
#                              'company',
#                              'Bad interviewing/ automated resume screening',
#                              'There’s a lot of ego. There’s a lot of '
#                              'discrimination against people who are not cis '
#                              'het males, there’s a lot of people who PhDs who '
#                              'have narrow expertise but lack the self '
#                              'awareness to admit they will always be learning '
#                              'something new,',
#                              'Lack of knowledge on the industry; lack of STEM '
#                              'professionals',
#                              'Lack of sufficient talent available',
#                              'Lack or people, lack of people with needed '
#                              'skills',
#                              'For technical roles unwillingness to consider '
#                              'related experience; work location; “battery '
#                              'bubble” and economic conditions',
#                              'Lack of industry experience; fledgling '
#                              'ecosystem; poor quality hiring agencies',
#                              'Shortage of candidates with academic preparation '
#                              'in chemical engineering.  Shortage of people '
#                              'with interest in marketing, who are also '
#                              'qualified in chemical engineering & economic '
#                              'analysis.',
#                              'Not enough candidates',
#                              'Companies looking for very specific skills and '
#                              'past experience in cell/battery, not realizing '
#                              'that many of the skills are transferable from '
#                              'other industries and battery/cell specific '
#                              'knowledge can be learnt on the job.',
#                              'Lack of established battery manufacturing '
#                              'industry',
#                              'Not as popular background to pull from compared '
#                              'to traditional areas',
#                              'Not being open minded enough to hire from '
#                              'adjacent industries',
#                              'lack of experience talent, from academia to '
#                              'industry, robotics scale-up manufacturing',
#                              'Lack of experienced candidates; Automotive '
#                              'companies suck up all the talent; New discipline '
#                              "that candidates don't actively consider",
#                              "don't know",
#                              'Lack of electrochemistry modules at university; '
#                              'Emerging industry lack of internships ;',
#                              'Salary',
#                              'Candidate supply and demand,',
#                              'location of office',
#                              'Experience',
#                              'Pipeline',
#                              'There is lack of skilled and qualified engineers '
#                              'and other roles in Poland.',
#                              'Not enough experienced people',
#                              'small talent pool; lack of gender diversity in '
#                              'the talent pool (need more female engineers)',
#                              'competitive landscape, location of office, fast '
#                              'growing industry without enough people with '
#                              'appropriate experience',
#                              'Existing preconceptions; "old boys club" '
#                              'mentality; New Chemistries vs Li-ion outlook',
#                              'Compensation; Education/Training',
#                              "Lack of marketing, lack of large 'well known' "
#                              'companies, global sentiment around the '
#                              "industry's role in the future",
#                              'poor education, lack of jobs, low pay',
#                              'Basic Foundation, Analytical skills',
#                              'Young sector in EU, fast expanding, resulting in '
#                              'large requirement on import of competences.',
#                              'Lack of industrial experience, Language Barieer, '
#                              'Non-competive Salary',
#                              'lots of open positions; too high salary '
#                              'expectation;',
#                              'Cost; Availability of experienced candidates',
#                              'lack of correct skills, personnel with not '
#                              'enough experience, lack of personnel with '
#                              'experience in instrument/machines operation',
#                              'Passport, lack of experts, lack of skilled '
#                              'managers to evaluate candidates and unrealistic '
#                              'expectations towards candidates.',
#                              'Pay, Location, knowledge base',
#                              'salary; salary+bonuses; bonuses+salary.',
#                              'Finding experienced people',
#                              'the knowledge of the selectors',
#                              'Salary, Location, resources',
#                              'Missing understanding in the management',
#                              'Lack of skilled engineers; Lack of experienced '
#                              'engineers; High competition between companies',
#                              "Visa's, experience, location",
#                              'Matching skillsets to needs.',
#                              'amount of technical skill needed; need for '
#                              'people to work with toxic materials and wear '
#                              'PPE; inflexibility in hiring/highly specific job '
#                              'requirements',
#                              'Immigration',
#                              'Lack of correct training provision; Lack of '
#                              'correct university courses; Lack of trained '
#                              'individuals',
#                              'adequate financing, Bay Area cost of living, Bay '
#                              'Area Poo & Filth',
#                              'flexibility; salary',
#                              'Awareness of industry; Market forecasts',
#                              'looking for all checkboxes to be filled rather '
#                              'than most, low salary offer',
#                              'compensation; location; willingness to train',
#                              'Lack of expertise; low salary; scarcity',
#                              'knowledge,',
#                              'barrier 1: lack of talents in the domain',
#                              'Pay, geography',
#                              'inconsistent market, under skilled workers,',
#                              'Lack of local talents; Difficulty in integrating '
#                              'multicultural team; Hiring right skillsets',
#                              'Toxic patriarchy:  Christopher Morris, Executive '
#                              'Director, Marketing and Business Development at '
#                              'Xerion Advanced Battery Corp. "Very few women '
#                              'elect/chose to pursue the battery science '
#                              'education fundamental to succeeding and '
#                              'advancing this industry. Lots of opportunities '
#                              'for motivated women...but they have to show up '
#                              'and put in the time and hard work" '
#                              'https://www.linkedin.com/posts/dknuckey_the-tesla-mafia-is-shaking-up-the-battery-activity-7039355064490090496-Mn0r?utm_source=share&utm_medium=member_desktop',
#                              'College education related to battery technology, '
#                              'compensation competition with big tech and '
#                              'pharma companies',
#                              'shareholders; lack of talent;',
#                              'Experience, Salary expectations, Market '
#                              'uncertainty',
#                              'Extreme specificity requirements',
#                              'competition with other more lucrative industries',
#                              'lack of pool of people with experience in '
#                              'battery industry',
#                              'Similar experience as per the project '
#                              'requirements',
#                              'Resume not reaching the hiring manager',
#                              'Compensation, Work Life Balance, Talent mismatch',
#                              'Visa issues',
#                              'Lack of experience',
#                              'Lack of domain specific training',
#                              'Competition; Compensation; Location',
#                              'Skills shortage',
#                              'Specialized knowledge scarcity; Rapid '
#                              'technological evolution; Cross-industry '
#                              'competition',
#                              'lack of experience, language(in north America), '
#                              'Less competitive wages',
#                              'Compensation',
#                              'remote work',
#                              'Work authorization; Compensation; Location',
#                              'Skills gap',
#                              'Experience; Narrow Focus',
#                              'Hiring rules',
#                              'limited carreer and salary development for '
#                              'technical experts',
#                              '1) manufacturing employers do not want to hire '
#                              'chemists/engineers with electrochemistry '
#                              'knowledge (prefer mechanical, industrial, or '
#                              'electrical engineers); 2) hiring managers are '
#                              'not able to recognize talent, or deficiencies in '
#                              'needed skill sets; 3) inexperienced candidates '
#                              'have no experience (academic, or practical) with '
#                              'electrochemical systems (experimental testing, '
#                              'data analysis, machine designing, &/or process '
#                              'development)',
#                              'Education; experience; antiquated business '
#                              'practices',
#                              'Outdated curriculums',
#                              'the breadth of info that batteries cover means '
#                              'that it is easy for someone to have one skill '
#                              'set but lack another skill which seems '
#                              'immediately adjacent',
#                              'Striking the balance between graduate entry and '
#                              'pay scales',
#                              'Low Salaries; right fitment of skills',
#                              'Skilled background',
#                              'Location of candidates to facility, finding '
#                              'candidates with battery knowledge',
#                              'Few of them exist, they are too expensive',
#                              'location',
#                              'pay , and importance of technical backgrounds',
#                              'Gen Z work ethic; Poor public schools; Social '
#                              'Safety nets',
#                              'Location of the Company and Talent in Battery '
#                              'industry',
#                              'understanding of exactly how battery is made and '
#                              'managed.',
#                              '"Working culture;Salary & compensation; company '
#                              'growing potential"',
#                              'Technical gap from academia and industry; visa '
#                              'requirements for international employment; '
#                              'mismanagement',
#                              'Small pool',
#                              'lack of both technical and practical knowledge',
#                              'Skills, experience, knowledge',
#                              'Small pool, high expected salaries',
#                              'Lack of experience/skills',
#                              'availability of labour, uncertainty of tenure, '
#                              'competition for trades',
#                              'Salary, experience, mindset',
#                              'Pay; Competition; Impression',
#                              'Salary negotiations, location constraints, work '
#                              'environment, reference culture',
#                              'lack of proper educational program in '
#                              'universities, lack of knowledge generally on the '
#                              'field',
#                              'Well rounded skillset, experience, '
#                              'electromechanical knowledge',
#                              'Language; Location; Compensation',
#                              'No good candidates',
#                              'Skills shortage; VISAs;',
#                              'Lack of previous experience, Perception of '
#                              'non-transferrable skills, Gatekeeping mentality '
#                              'within some companies',
#                              'Location; Job stability; Income',
#                              'lack of availability',
#                              'wages, lack of knowledge, desire for remote work',
#                              'Overly theoretical school programs,',
#                              'Lack of battery studies for college '
#                              'undergraduates',
#                              '[Lack of trained workforce][lack of training]',
#                              'Salary, Innovative Mindset, Material Science '
#                              'Innovations',
#                              'Hands on Experience; contextual experience; '
#                              'geographical pay standards',
#                              'Battery companies expect narrow expertise in '
#                              "batteries, I'm a generalist in power "
#                              'electronics.',
#                              'Salary, Talent Pool, Location',
#                              'Difficult to gain expertise, unattractive '
#                              'locations',
#                              'lack of prior experience that translates',
#                              'Lack of required skills set, poor battery '
#                              'education, slow EV adoption',
#                              'Fierce competition for talent; bloated claims by '
#                              'start-ups; focus on domain knowledge over soft '
#                              'skills',
#                              'There isn’t enough background knowledge in the '
#                              'talent pool, it needs developed',
#                              'limited local availability, high competition',
#                              'Tough job market, companies fluctuating in '
#                              'funding',
#                              'small industry (in NL); lack of experience',
#                              'Shitty HR filtering; Lack of knowledge; poor '
#                              'pay/benefits',
#                              'Lack of industry talent in USA; questionable '
#                              'market finance commitments making hiring picture '
#                              'difficult',
#                              'Low salaries',
#                              'flexibility',
#                              'Too much priority in hiring engineers without '
#                              'hiring enough internal infrastructure roles to '
#                              'support effectively.',
#                              'location; competitive benefits',
#                              'niche industry',
#                              'competition',
#                              'Not many large battery companies in the US, Lack '
#                              'of battery related education, Wide variety of '
#                              'technical skills needed',
#                              'Location, competition, career prospects',
#                              'Lack of direct background; lack of effective '
#                              'recruitment skills; lack of talent pool',
#                              'Matching compensation and knowledge',
#                              'Pay and future planning',
#                              'The need to relocate, finding the talent with '
#                              'exactly what you want',
#                              'Education; Experience;',
#                              'Skill gap, location',
#                              'Base Salary below or around average; hot market',
#                              'Skilled labour',
#                              'pay',
#                              'Availability outside California; willingness to '
#                              'move to NC; high salary expectations',
#                              'Location; Applicable Knowledge; Salary',
#                              'The field is still very young so many people in '
#                              "the industry don't have enough experience "
#                              'outside university',
#                              'not enough teaching of electrochmistry/batteries '
#                              'at universities',
#                              'lack of domestic education focused on battery '
#                              'industry',
#                              'Benifit; future plan; salary',
#                              'visas, salary, location',
#                              'Gender',
#                              'Inflexible hiring practices',
#                              "industry demand isn't there to create enough "
#                              'jobs, still a ways away',
#                              'Education; HV familiarity; chemical awareness',
#                              'base salary',
#                              'Rigid attention to job description; location of '
#                              'job; unreasonable expectations',
#                              'lack of skilled personnel, salaries offered by '
#                              'some companies, location',
#                              'Finding people with experience',
#                              'Location, Competition for technical talent',
#                              'Rapidly changing job functions; lack of formal '
#                              'education about batteries',
#                              'Limited availability of talent',
#                              'Limited talent pool, difficult of getting talent '
#                              'to change industries',
#                              'Budget',
#                              'US public school system, marijuana, entitlement '
#                              'mentality',
#                              'Salary',
#                              'Exposure to technology and common practices; '
#                              'Fundamental understanding of how batteries work; '
#                              'The difference between R&D/prototype design vs '
#                              'production design',
#                              'hard science + soft skills background is hard to '
#                              'find.. Competing with tech industry makes it '
#                              'hard to attract talent',
#                              'Networking',
#                              'Few people have the experience, or are willing '
#                              'to invest',
#                              'Lack of workforce trained with specific skill '
#                              'sets, lack of focus within relevant departments '
#                              'in higher education',
#                              'Job security',
#                              'Process engineer',
#                              'no one knows who needs which talent at one place',
#                              'Lack of skills, opportunity, training',
#                              'Too many academic electrochemists (physicists '
#                              'and chemists) with no engineering background or '
#                              'knowledge.',
#                              'Lack of multiple test considering his '
#                              'professional performance and his overall '
#                              'behaviour.',
#                              'Company and employee profile, vision, old HR '
#                              'strategy for new needs',
#                              '"assuming anyone living in africa is not '
#                              'skilled; location-far north; employment '
#                              'opportunities for spouses"',
#                              'Lack of good combination of engineering skills '
#                              'with people management',
#                              'Electrochemistry is far from electricity '
#                              'engineering',
#                              'sufficient number of people who have actually '
#                              'done it before. This skill is actually still '
#                              'limited to Asian companies even today.',
#                              'salary expectations, skills shortage, '
#                              'immigration barriers',
#                              'Lack of battery knowlege; lack of battery '
#                              'development experience',
#                              'Salary',
#                              'salary',
#                              'Location; Credentialism; HR',
#                              'Insufficient skilled people;working '
#                              'permit;ratherly newer field to work;',
#                              'Lack of talent',
#                              'SME size',
#                              'not enough people with right skills; other '
#                              'sectors pay better; relocation',
#                              'Less experience; less hands on experience',
#                              'Salary, poor employer branding, availability of '
#                              'skilled talents',
#                              'availablility of talent',
#                              'bias from recruiters',
#                              'low wage',
#                              'Academia and Industry differences',
#                              'Salary, Location, Products',
#                              'cultural barriers ; company knowledge',
#                              '“[low wages]”',
#                              'location constraints; talent shortage; work visa',
#                              "Lack of peers, new technology that doesn't "
#                              'exist, High cost of living in SF Bay Area',
#                              'Restricted capable pool of available resource',
#                              "Employer's lack of willingness to invest in "
#                              "qualified people; employer's lack of willingness "
#                              'to invest in tools and infrastructure; '
#                              'fundamental lack of capital',
#                              'Limited formal education',
#                              'Knowledge, Hands-on experience, Risk taking '
#                              'ability',
#                              'Availability',
#                              'Lack of Opportunities; Rivalry from Asian '
#                              'markets',
#                              'Limited pool of talent/experience',
#                              'Competitive compensation; work life balance',
#                              'Salary, company stability, company perspective',
#                              'Lack of battery related experience',
#                              'Pay; risk tolerance; trust in leadership',
#                              'salary expectations, skill mismatch, '
#                              'certifications',
#                              'Lack of practical manufacturing experience',
#                              'Lack of experienced people',
#                              'Experience, training, compensation',
#                              'education',
#                              'COMPANY INTERNAL RECRUITMENT PROCEDURES',
#                              'age discrimination',
#                              'Attracting talent and explaining knowledge '
#                              'transfer',
#                              'salary',
#                              ';',
#                              'Compensation; Unstable funding; Not enough '
#                              'skilled talents',
#                              'visa processes',
#                              'competitivity; salary; market stability',
#                              'salary',
#                              'unknown',
#                              'Small talent pool; lack of educational programs; '
#                              'a lot of competition',
#                              'Research opportunities in university are all '
#                              'chemistry based no manufacturing; people look '
#                              'down on manufacturing; locations most facilities '
#                              "need to be in aren't california",
#                              'no established workforce development',
#                              'Experience, Burnout, Compensation',
#                              'uncertainty (since the industry is newer vs '
#                              'others like oil/gas), no meaningful and '
#                              'accessible opportunities to get into the '
#                              'industry, and global political climate',
#                              'salary',
#                              'Barrier 1 - when a company sets expectations '
#                              'that’s aren’t achievable. Barrier 2 - lack of '
#                              'alignment from hiring decision makers around '
#                              'role responsibilities.  barrier 3 - lack of '
#                              'willingness to train (plenty of people who apply '
#                              'to jobs are 8/10 qualified but companies don’t '
#                              'want to take the risk to be able to train up the '
#                              'other 2/10 skills)',
#                              'Not enough local talent; talent is too spread '
#                              'out; we are still behind China for overall '
#                              'talent',
#                              'Unrealistic expectations from management; lack '
#                              'of funding; role too specific/broad',
#                              'competing for great people; instability in the '
#                              'industry',
#                              'Lack of Foundational knowledge about Battery',
#                              'salary; competence; experience',
#                              'lack of talents;',
#                              'geographical location; lack of clear roadmaps;',
#                              'lack of skilled people, visas, low salaries vs '
#                              'cost of life',
#                              'wide range of technology',
#                              'location; salary; carrier growth',
#                              'No workforce',
#                              'Pay scale;talent pool',
#                              'lack of experienced and skilled applicants',
#                              'Salary and expectations of employers that '
#                              'scientists should also know data science etc',
#                              'High Salaries, Few Battery Professionals, '
#                              'Startup Status',
#                              'working in dryroom;',
#                              'location',
#                              'availibility',
#                              'More onboarding knowledge needed; little support '
#                              'from public policy; public perception of safety',
#                              'Location',
#                              'Realistic hiring expectations from the team, '
#                              'organized recruiting process',
#                              'not enough experience in the work force',
#                              'Lack of battery knowhow, lack of hands-on '
#                              'experience, not interesting or competitive for '
#                              'software or mechanical engineers',
#                              'salary',
#                              'Lack of skilled workers',
#                              'Funding; availability of skilled worker; job '
#                              'experience',
#                              "Low salaries; headhunter's knowledge;",
#                              'other companies hired them',
#                              'Lack of skilled personnel, lack of battery '
#                              'education, poor renumeration',
#                              'Availability of skilled workers',
#                              '1. Voluntarism of the process (recruitment '
#                              'skills not suited for industry), 2. Suitable '
#                              'talent scarcity, 3. lack of golden middle for '
#                              'the mix structured approach / enterpreneurial '
#                              '(managed risk taking)',
#                              'Finding qualified people',
#                              'Finding them',
#                              'Salary; Project availability; Benefits',
#                              '"Low pay; No equity; transactional nature"',
#                              'Budget',
#                              'sponsership employment',
#                              '1. Competitive market 2. Skill mismatched 3. '
#                              'Hiring process',
#                              'Expertise; Hard-Working; Knowledgeable',
#                              'No pool for specialist having domain knowledge',
#                              '[employment laws];',
#                              'Skilled professional',
#                              'lack of skill',
#                              'Experience required',
#                              'competition, skills, niches',
#                              'Lil knowledge of HR on necessary skills; '
#                              'Structures driven by mechanical engineering; low '
#                              'starter income',
#                              'Lack of specialized education and training '
#                              'programs; Limited availability of experienced '
#                              'professionals; High competition for talent '
#                              'across industries.',
#                              'Education; Market uncertainty',
#                              'non availability of good people in the UK',
#                              'Location; Reputation; Visibility',
#                              'Not enough specific profiles (technician, '
#                              'engineer, doctor)',
#                              'Availability',
#                              'Lack of resource, industry challenges in Europe, '
#                              'slow EV take up in EU',
#                              'Perception of the Industry; Competition Across '
#                              'Industries; Talent Shortage',
#                              'Communication of the requirements',
#                              'uncertanty about financial survival of  '
#                              'companies, no stable financial environment',
#                              'Language, lack of industrial experience, '
#                              'non-competitive salaries',
#                              'Location, pay, competition',
#                              'Lack of domain expertise',
#                              '[bounce in the ev adoption, then in the battery '
#                              'industry outlook];[lack of training diversity]',
#                              'salary too low, no remote option, low autonomy',
#                              'Workforce Size and Experience; Location; Pay',
#                              "Generally, I don't think recent grads see "
#                              'battery research/production all that '
#                              'challenging.',
#                              'chaotic employment; impatient management; '
#                              'excessive travel',
#                              'lack of experience; historically batteries were '
#                              'not "sexy"; very few people were aware of the '
#                              'market',
#                              'Location, lack of industrial environment',
#                              'Yes',
#                              'Lack of experience',
#                              'Interest;  company stability',
#                              'lack of specific experience, poor compensation '
#                              'offers, poor training',
#                              'visa, underqualified candidate,',
#                              'No people, work in office',
#                              'Not enough skilled workers, outdated knowledge '
#                              'about battery industry lack of practical '
#                              'experience - only based on academic or doctoral '
#                              'program',
# ...
#                                  'Manufacturing;electrochemistry;analytical '
#                                  'instruments',
#                                  'strategic thinking; sales skills; listening',
#                                  'Communication',
#                                  'Flexibility, Desire to Learn, Networking',
#                                  'Experience, Knowledge, Technical proficiency',
#                                  'Electrochemical knowledge; being a quick '
#                                  'learner; communication',
#                                  'lifelong Learning attitude',
#                                  'Time management; open communication; basic '
#                                  'programming',
#                                  'Finance, accounting, tax',
#                                  'Willingness',
#                                  'XRD/crystallography, Python',
#                                  'communication, efficiency, attention to '
#                                  'detail',
#                                  'openess to ask questions',
#                                  'Generalist, Battery Knowledge (PhD), '
#                                  'hands-on engineering',
#                                  'Problem solving, Empathy, Public speacking, '
#                                  'strategy',
#                                  'Mindset/willingness to learn; critical '
#                                  'thinking and reasoning;',
#                                  'Endurance; teamwork; experience',
#                                  '[Leadership];[Knowledge];[Multitasking];[Communication];[Experience]',
#                                  'previous experience with electrochemistry',
#                                  'Industrial Automation, Battery energy '
#                                  'storage system integration, Microsoft excel',
#                                  'Solid state chemistry, people management',
#                                  '1. Ability to bread on experiences from '
#                                  'different industries, 2. Crisis management, '
#                                  '3. Curiosity',
#                                  'Adaptability, tenacity, continuously learner',
#                                  'Program management, technical, engineering',
#                                  'Critical thinking; Analytical; Persistent',
#                                  '"Adaptation; Research"',
#                                  'Research and Development; Technical; '
#                                  'Analytical',
#                                  'Management skills, patience, Projects- deep '
#                                  'handling',
#                                  '1. Hardworking 2. Experience 3. Management',
#                                  '[Excellent Quality]; [Support to Customers]; '
#                                  '[Hard-Working]',
#                                  'Hardworking',
#                                  '[hard-working]; [not giving up]; [patience]',
#                                  'Programming, Electronics',
#                                  'Fast learning, autonomy, curiosity',
#                                  'flexibility, curiosity, dedication',
#                                  'Logical thinking; quickness of mind; wide '
#                                  'professional knowledge incl. Business '
#                                  'science',
#                                  'Problem-solving; Teamwork; Time management',
#                                  'Problem solving; Mechanical mind; '
#                                  'Cross-functional knowledge',
#                                  'Automotive ecosystem understanding, business '
#                                  'acumen, networking',
#                                  'Flexibility; Open Mindness;',
#                                  'Sociability; Technical and scientific '
#                                  'mastery; Management; Strictness',
#                                  'Skill 1 - read a lot - learn quickly',
#                                  'grit, determination, big picture thinking, '
#                                  'optimism',
#                                  'Can do attitude, flexibility, experience',
#                                  'Communication; Project Management; Data '
#                                  'Analysis; Empathy; Proactivity; Teamwork; '
#                                  'Critical Thought; Materials Knowledge',
#                                  'Problem solving skills, Curiosity, Strategic '
#                                  'Thinking',
#                                  'product development; material knowledge; '
#                                  'sales knowledge; marketing; mentoring',
#                                  'Agility, Easy Learning skills, Social skills',
#                                  'Technical knowledge, hands-on experience, '
#                                  'materials science',
#                                  'Battery and energy industry expertise; being '
#                                  'a "full stack" marketer',
#                                  '[engineering][electronics][manufacturing '
#                                  'system]',
#                                  'problem solving, communication, perseverance',
#                                  'Adaptability; Fundamental Electrochemistry '
#                                  'Knowledge',
#                                  'multidisciplinary knowledge, willingness to '
#                                  'learn, creative thinking',
#                                  '"Engineering ; Technical ; Applications"',
#                                  'global contacts; process experience; '
#                                  'economics',
#                                  'critical thinking, wanting to learn, self '
#                                  'starter',
#                                  'Electrochemistry, communication',
#                                  'Quick learner Flexibility',
#                                  '1. Broad Technical Knowledge 2. Industrial '
#                                  'Industry Experience 3. VOC skills',
#                                  'Multitasking; adaptability; diplomacy',
#                                  'detailed mindset, data science, '
#                                  'communication',
#                                  'curiosity, adaptability, social skills',
#                                  'Asking questions; intellectual humility',
#                                  'knowledge, personality, academic history',
#                                  'Flexibility',
#                                  'Practical knowlwdge about battery '
#                                  'prosuction, teoretical knowledge about '
#                                  'li-ions battery,statistical skills',
#                                  '1. Knowledge 2. Risk Taking 3. Problem '
#                                  'Solving',
#                                  'Curious; motivated; autonomous',
#                                  'mechanical design, high volume product '
#                                  'design, first principle thinking, curiosity, '
#                                  'drive',
#                                  'decision making; cost analysis; relationship '
#                                  'building',
#                                  'Engineering; practical hands on skills; '
#                                  'adaptability',
#                                  'Communication; analytical thinking;',
#                                  'Resilience, humility, determination',
#                                  'connections, experience, professional '
#                                  'knowledge',
#                                  'Expertise in wholesale and retail, regulated '
#                                  'and deregulated power markets; strong '
#                                  'analytical skills; adaptability',
#                                  'engineering, project management, strategy',
#                                  'Independent learning; Teamwork; Being '
#                                  'organized',
#                                  'Good Communication Skills; Broad knowledge '
#                                  'in many engineering diseplines; Materials '
#                                  'science background',
#                                  'Creativity; chemistry;',
#                                  'discipline',
#                                  'Deep understanding of technology, strategy, '
#                                  'and leadership',
#                                  'Software, networking, electronics',
#                                  'Fundamental knowledge ( Cell testing) ; '
#                                  '(battery Pack Testing); (BMS Testing)',
#                                  'Project management, business strategy, '
#                                  'analysis',
#                                  'Battery knowledge; Lab experience; Willing '
#                                  'to learn',
#                                  'Chemistry knowledge, impedance analysis, '
#                                  'intuition',
#                                  'Critical thinking, communication, and '
#                                  'engineering background',
#                                  'Skill1: Networking, Skill2: Expermental '
#                                  'Subject knowledge, Skills 3: knowhow market',
#                                  'Picking up concepts quickly',
#                                  'Software Development',
#                                  'Physics background, programming, data '
#                                  'analysis',
#                                  'Technical understanding of energy storage ; '
#                                  'experience with required equipment ; '
#                                  'communication skills',
#                                  'Curiosity, grit, adaptability',
#                                  'Ability to learn; good communication; coding '
#                                  'in python',
#                                  'Proactive, good communication, presentation',
#                                  'Flexibility, fast learning, perseverance',
#                                  'Python data analysis; test engineering; '
#                                  'battery electrochemistry',
#                                  'Research, Data analysis, Communication',
#                                  'Materials synthesis, testing and advanced '
#                                  'analysis',
#                                  'global knowledge of battery innovation',
#                                  '"Simulation study; Cell Manufacturing; '
#                                  'Electrode synthesis"',
#                                  'Team management, quick learning, innovation, '
#                                  'team leadership',
#                                  'perseverance, curiosity, courage, vehicle '
#                                  'integration',
#                                  'Continuos learning, foundational knowledge, '
#                                  'programming',
#                                  'flexibility; understanding of start ups; '
#                                  'emerging tech approach',
#                                  'Fundamental knowledge; persistency; critical '
#                                  'thinking',
#                                  'Being quick learner, taking risk, agile '
#                                  'product development approach',
#                                  'Data analysis, molecular quantum mechanics, '
#                                  'cell modelling',
#                                  'Network',
#                                  'Communication; perseverance; programming',
#                                  "determination; perserverance; UNC's "
#                                  'chemistry program',
#                                  'Experience; Education; Scientific Curiosity;',
#                                  'Leadership,  planning',
#                                  'Fast learner; analytical mindset; '
#                                  'detail-oriented',
#                                  '1. Electrical background 2. Understanding of '
#                                  'the renewable energy industry 3. I had a '
#                                  'wide knowledge base t',
#                                  'Generalism, open mindedness, collaboration',
#                                  'International; network; business development',
#                                  'People leadership, techno-economics, '
#                                  'communication',
#                                  '[DoE],[Python Programming],[Data Analysis]',
#                                  'Team leadership skills, mentorship of peers, '
#                                  'inter-team collaboration',
#                                  'Laboratory skills',
#                                  'Troubleshooting, question formulation, '
#                                  'communication',
#                                  'electrical, electronic knowledge; project '
#                                  'managment; testing knowledge',
#                                  'Focus, network, interesr',
#                                  'experience across multiple disciplines, '
#                                  'productization focused, solution selling',
#                                  'creativity; fundamental knowledge of '
#                                  'batteries',
#                                  'ndt, testing',
#                                  'Electrochemistry',
#                                  'Product Knowledge (Battery structure + '
#                                  'chemical transport phenomena); Problem '
#                                  'Solving Acumen',
#                                  'luck; communication; product knowledge',
#                                  'Material Synthesis, Analytical '
#                                  'Characterization Expertise,',
#                                  'Teamworking, business analytics, strategic '
#                                  'planning',
#                                  'Dedication; enthusiasm; resilience',
#                                  'Drive, quality, interpersonal skill',
#                                  'Deep knowledge in several technologies, '
#                                  'experience in many R&D projects oriented to '
#                                  'bring up new market products',
#                                  'Education, Ambition, Fiction',
#                                  'Battery industry knowledge, automotive '
#                                  'industry knowledge, communication skills',
#                                  'Adaptability and Flexibility, Technical '
#                                  'Proficiency, Problem Solving',
#                                  'Mathematical modeling; mentorship; '
#                                  'experiment design',
#                                  'keeping my mouth shut, when my employer lies '
#                                  'to customers and investors',
#                                  'Synthesis, testing via electrochemical '
#                                  'method, structural characterization',
#                                  'people skills; project managemnet; technical '
#                                  'knowledge',
#                                  'Problem solving and critical thinking; Hands '
#                                  'on approach; Hard work',
#                                  'adaptability; strive for excellence; '
#                                  'synthesis',
#                                  'Matlab, Technical Understanding, Analysis',
#                                  'Experience from many different fields']}

# %%
plotter.make_bar_plot_from_dict(
    res_company_skills['skills_how_to_improve'],
    title='When you first started in the battery industry, what could have improved your job performance on day one?',
    saveas='company_skills_how_to_improve.png',
    num_elements=3,
    sorted=True
)

plotter.make_bar_plot_from_dict(
    res_company_skills['skills_how_was_trained'],
    title='When you first started your role, how were you trained?',
    saveas='company_skills_how_was_trained.png',
    num_elements=3,
    sorted=True
)

# %% [markdown]
# ## Company Retention

# %%
res_company_retention = analyst.summarize_company_retention()
pprint(res_company_retention)
# Out:
# {'retention_factors': {'A non-toxic work environment and quality upper management': 1,
#                        'Autonomy': 1,
#                        'Career growth opportunities': 447,
#                        'Chance of Success of Companies Technology/Product': 1,
#                        'Company Viability and Trajectory': 1,
#                        'Company Vision and Goals': 1,
#                        'Company culture': 420,
#                        'Company vision': 1,
#                        "Company's chance for success": 1,
#                        'Eco-friendliness': 1,
#                        'Equity': 219,
#                        'Ethics': 1,
#                        'For a different potentially better role/interesting tasks': 1,
#                        'Good manager': 1,
#                        'I will not seek another opportunity': 1,
#                        "I'm getting close to retirement and am not looking for another job.": 1,
#                        'Impact': 1,
#                        'Innovation': 1,
#                        'Insurance coverage': 1,
#                        'Interest in project': 1,
#                        'International exposure': 1,
#                        'Job for my wife': 1,
#                        'Job stability': 329,
#                        'Location': 4,
#                        'Location (i.e. NOT west coast USA)': 1,
#                        'Market advantage based on innovation & technical capability': 1,
#                        'Nothing will get me to leave': 1,
#                        'Parental leave': 74,
#                        'People and the environment': 1,
#                        'Perks': 128,
#                        'Problem space': 1,
#                        'Salary': 548,
#                        'Support on R&D Projects': 1,
#                        'Supportive Leadership': 1,
#                        'Technical challenges': 1,
#                        'Technology Relevance': 1,
#                        'The problems I would be working on': 1,
#                        'Time Flexibility': 1,
#                        'Total hours worked': 176,
#                        'Vacation time': 254,
#                        'Visa sponsorship': 127,
#                        'Work location': 1,
#                        'Work location flexibility': 340,
#                        'Work-life balance': 2,
#                        '_tot_': 634,
#                        'bonuses': 548,
#                        'interesting projects': 1,
#                        'job responsabilities': 1,
#                        'swarm intelligence': 1},
#  'retention_is_on_market': {False: 310, True: 328, '_tot_': 638},
#  'retention_misc_list': ["Just recently changed jobs, still haven't started "
#                          'new one yet',
#                          'Geography',
#                          'geography; stability; pay',
#                          'Visa sponsorship.',
#                          'A firm that values my experiences',
#                          'community involvement - make EVs accessible to all',
#                          'geography',
#                          'hybrid option; better pay',
#                          'Nope',
#                          'Company stability',
#                          'Need cheap housing and low cost daycare in the '
#                          'location of next role',
#                          'no',
#                          'Benefits;Money;Culture',
#                          'Diversity, international opportunities',
#                          'Learning opportunities and mentorship',
#                          'Development; Testing; Modelling',
#                          'Family friendly policies',
#                          'Next generation cell development',
#                          'Salary, work location flexibility, Driven team',
#                          'Environmental Impact',
#                          'company financial stability and company culture',
#                          'role ; salary ; culture',
#                          'affordable homes or high salaries',
#                          'Sustainability focus, the technology cannot make the '
#                          'planet worse, or their marketing/positioning in the '
#                          'market cannot be greenwashing.',
#                          'Impact, salary',
#                          'personal growth; clear career path; innovative',
#                          'Flexible working hours and vacation- as long as I '
#                          'deliver on my targets and work hard, I need the '
#                          'freedom of being allowed time off',
#                          'Innovative environment, career growth opportunities, '
#                          'collaboration culture, work life balance',
#                          'robotics; culture',
#                          'Money; responsibility; career growth',
#                          'Higher compensation, ability to better focus on '
#                          'value-add contributions',
#                          'Geography, salary, work-life balance',
#                          'Location in Europe ; no consulting anymore',
#                          'The project',
#                          'New learning; work life balance',
#                          'Diversity; career opportunities; work location '
#                          'flexibilities',
#                          'carreer groth and learning experience',
#                          'geography; good leadership; generous maternity leave',
#                          'Developing a scalabale, future-proof technology',
#                          'nil',
#                          'Geography; culture; stability',
#                          'a better work-life balance',
#                          'remote work',
#                          'geography or ability to work remote',
#                          'Good team and company culture, adequate '
#                          'compensation, visa sponsorship',
#                          'flexibility in country location 1',
#                          'Idk',
#                          'stock options; culture; interesting product',
#                          'Headquarters in upper Midwest; strong culture '
#                          '(competent people & held accountable); '
#                          'quality-focused',
#                          'not looking for another role.  Growing my own '
#                          'company',
#                          'visa sponsorship, career growth, culture',
#                          'Money; personal and professional development',
#                          'I am open to consultation work and contract work '
#                          'with reputable companies. Years of experience... '
#                          'But, in this competitive industry, especially in '
#                          'California, I am too old for them. I get lots of '
#                          'attention due to my skills and experience, but once '
#                          'they detect my age... Interview is already over. The '
#                          'silent discriminator, age',
#                          'Geography; political environment',
#                          'I am not looking for another role',
#                          'Item 1: on-site/remote work flexibility; item 2: '
#                          'parental leave; item 3: more senior than current '
#                          'role',
#                          'Appreciation; opportunity; supports',
#                          'Location, funding of the company, the competitive '
#                          "edge of the company's core technology",
#                          'More stable company finances, clearer progression '
#                          'opportunities, more money',
#                          'Culture; salary; company outlook',
#                          'Not sure I need another role at this point in my '
#                          'career',
#                          'Location, Money',
#                          'no',
#                          'Work-life balance, potential to make meaningful '
#                          'contribution to the industry, compensation',
#                          'reasonable commute time, good work-life balance, '
#                          'fair treatment of women',
#                          'Career growth opportunities,\n'
#                          'Valued role and responsibilities,\n'
#                          'Compensation and benefits.',
#                          'Open for new ideas and great culture to work',
#                          'More PTOs, remote work flexibility, career change '
#                          'opportunities',
#                          "Can't define now",
#                          'STRONG ENGINEERING TEAM; COMPETITIVE SALARY; COMPANY '
#                          'CULTURE',
#                          'geography; money; flexibility',
#                          'Business leadership position',
#                          'role; money; benefits',
#                          'Culture, Benefits, Flexibility',
#                          '"geography", "career growth options", "better work '
#                          'life balances"',
#                          "Professional  development budget that doesn't "
#                          'require employee match',
#                          'Money; Location flexibility; Role near the clients',
#                          'Open & Inclusive work environment; Global Travel '
#                          'Opportunities; $100k+ package',
#                          'No',
#                          'For me, money is one of the biggest factors in '
#                          'making decisions, but equally important is the '
#                          'chances of growth in both my career and as a '
#                          'researcher. Of course, the company benefits and '
#                          'culture are significant as well. I want to work in '
#                          "an environment that respects people's differences, "
#                          "is willing to listen to their team members' opinions "
#                          'and needs, and is appreciated as a worker. We are '
#                          'all human after all.',
#                          '"Research;Fun;Vision"',
#                          'relocation help, trainings',
#                          'Work live balance',
#                          'There is a lot of talk but very little action in '
#                          'this industry',
#                          'Commutability; culture; increase in responsibility',
#                          'Culture: less firefighting, more strategy; '
#                          'geography: new country',
#                          'An ideal employer should have a stable revenue '
#                          'stream outside of exclusive dependence on battery '
#                          'industry, to manage inevitable boom & bust in the '
#                          'emerging battery industry.',
#                          'Remote opportunities',
#                          'Remote Work; Collaborative Culture; Climate Impact',
#                          'cutting edge technology',
#                          'I Like to have a lot of Travel During my Work',
#                          'company culture, office location, flexible time '
#                          '(work from home option)',
#                          'Chance to learn',
#                          'salary, growth, positivity',
#                          'Growth, Role and Benefits',
#                          'Better work life personal life balance',
#                          'France, Canada, Belgium',
#                          'Equity; Appreciative culture',
#                          'Where the office is located',
#                          'Mild climate, developed city; total annual salary '
#                          '$100,000+ or opportunity to rapid growth; value of '
#                          'an employee with a PhD',
#                          'interesting projects,',
#                          'Money, Proper resources for R&D, benefits, culture, '
#                          'work-life balance',
#                          'no',
#                          'more money, better job stability',
#                          'Mainly career opportunities',
#                          'corporate culture of "niceness" (not like Tesla)',
#                          'local language requirement also a key concern for me',
#                          'Geography; money; role',
#                          'money, better work culture, better benefits,',
#                          'remote work; competent program management; salary',
#                          'money; full remote; culture',
#                          'item 1: more responsibility',
#                          ', salary, career growth, job satisfaction',
#                          'Relocation and settling in support; Return flights; '
#                          'Training support',
#                          'Please stop using violent words ie Tesla Mafia. '
#                          'Words matters, thank you',
#                          'Geography: in process of moving to Portugal.',
#                          'Peaceful Location; Supporting Team; Motivation',
#                          'Stability;Fair Treatment;Training',
#                          'Strong Mentorship culture;\nGood work life balance;',
#                          'Possibility to work remotly, Money, Possibility to '
#                          'growth',
#                          'Competitiveness of company technology and quality of '
#                          'management',
#                          'More money, Remote US/CAN',
#                          'To be within driving/visiting distance of family; '
#                          'competitive pay; job security',
#                          'compromised team, interesting project, location '
#                          'independence',
#                          'Control of budget',
#                          'Growth',
#                          'Team leadership and compensation for this',
#                          'Developing a role to foster a mentoring environment '
#                          'between experienced and inexperienced engineers',
#                          'Money',
#                          'Work from home when it makes sense',
#                          'Item 1 - Skill transferability',
#                          'Technical leadership; Functional Safety',
#                          'More stability',
#                          'Family oriented',
#                          'More money!',
#                          'hybrid, salary, good healthcare, reasonable location',
#                          'Better Organizational structure, clarity on career '
#                          'goals and milestones.',
#                          '"Company\'s vision;CEO\'s vision"',
#                          'Company culture; permanent contract; high salary',
#                          'benefits, compensation, flexible working scheme',
#                          'Geography, culture, benefits',
#                          'Remote working flexibility, better culture',
#                          'stock options',
#                          'Geography; Proactive continuous training; '
#                          'Non-founder lead',
#                          'Explore new place, money making, carrer growth',
#                          'Knowledge, research mentality, good compensation',
#                          'Challenge; Recognition; Honesty;',
#                          'Salary, Benefits, Culture, Technological '
#                          'Innovations, Hybrid Flexibility',
#                          'Cultural experience; career development; income',
#                          'Culture',
#                          '[Leadership position]',
#                          'Location, impact, culture',
#                          'RSUs instead of stock options',
#                          'Competent management',
#                          'No',
#                          'Innovation',
#                          'Geography, hybrid work',
#                          'more upside, unicorn',
#                          'Opportunity to work with big EV company',
#                          'more influence over decision making; focus on '
#                          'processes',
#                          'growth, ownership, accountability',
#                          'Remote, Salary raise, Flexible time off',
#                          'Salary to match cost of living for geography; better '
#                          'parental leave (ideally 5+ months); better equity '
#                          'package',
#                          'Money, benefits, role, culture',
#                          'growth; compensation; flexibility',
#                          'Viability',
#                          'Geography, role, culture',
#                          'If I was to move jobs, it would be because my '
#                          'organization is bankrupt, or to pursue a lower '
#                          'pressure role with more work-life balance. Otherwise '
#                          'I do not see a reason to move to a new company until '
#                          'I have achieved what I need to for this company.',
#                          'Flexible work (hybrid/remote), stable hours, closer '
#                          'to where I live',
#                          "I'd like to maintain what I think is great vacation "
#                          'and work remote flexibility while also getting paid '
#                          'about 30% more. I could take or leave equity.',
#                          '"Financial Compensation; Visa process help to move; '
#                          'Job Security',
#                          'Technology that has a potential to be safer than '
#                          'lithium ion',
#                          'no',
#                          'Culture; Location; Work-life balance',
#                          'More stability and better leadership',
#                          'money, benefits, culture,',
#                          'Would like to move into program creation and '
#                          'direction',
#                          'Money;',
#                          'impact on society / environment',
#                          'Job duties; ability to learn new skills; travel '
#                          '(lots)',
#                          'Manager roles , equity and more challenging '
#                          'opportunities like getting the products to the '
#                          'market',
#                          'Sustainability',
#                          "potential for growth in the company's battery "
#                          'technology/chemistry',
#                          'Culture and cohesive decision making is the most '
#                          'important',
#                          'autonomy',
#                          'work life balance',
#                          'Major American city, abundant outdoor recreation, '
#                          'opportunities for mentorship, stable growth, '
#                          'established product and clear company vision',
#                          'I’m looking for career growth , work life balance '
#                          'and with my skills new things to involve for '
#                          'organizations, need sponsorship to know other '
#                          'country people to what type of mind they have , what '
#                          'type of thinking they have .',
#                          'Need more funders and investors for project',
#                          'Nil',
#                          'immediate joiner. 16 years in Lithium metal and '
#                          'Solid State Battery Industrial R&D.',
#                          'Having multidisciplinary and intercultural, openness '
#                          'to collaboration, cross functional communication '
#                          'vertically and horizontally are the key for maturing '
#                          'industry that i am trying to focus on.',
#                          'geography;friendliness;money',
#                          'Location. It should not be too remotely located',
#                          'emphasis can be placed on location flexibility',
#                          'Geography, Salary, Culture',
#                          'part of a larger team; resource availability; '
#                          'motivated and dedicated colleagues',
#                          'VP role, salary increase',
#                          'money; culture; role; company growth opportunity',
#                          '“Geography cannot be way out”',
#                          'right geography',
#                          'Ability for hybrid work, culture, mission/vision',
#                          'Culture',
#                          'innovation',
#                          'Move to other country and became expert expats',
#                          'Use of current capabilities, geography, work-life '
#                          'balance',
#                          'Money',
#                          'Stability, salary, culture',
#                          'Better WLB; better mentorship',
#                          'Stability',
#                          'no',
#                          'geography, money, benefits, role',
#                          'Growth opportunity; Role; Money',
#                          'stability, better compensation, work culture and '
#                          'innovation',
#                          'geography; culture; role; money',
#                          'Middle east, business develoment',
#                          "The company's approach to sustainability",
#                          'more travel, more impact, more compensation',
#                          'geography, company funding, collaboration, education',
#                          'Sustainability strong culture',
#                          'Established processes that have a successful track '
#                          'record. Culture of helping to improve skills. '
#                          'Company culture is to stick by hard workers and not '
#                          'judge them solely on outcomes',
#                          'More money; long term stability; better organization '
#                          'overall',
#                          "I'll retire after this role",
#                          'role; reputation',
#                          'Reciprocal flexibility (emplyer/employee); employer '
#                          'location;',
#                          'money, stability, career growth',
#                          'new country; money; role',
#                          'Geography',
#                          'no',
#                          'Leadership and project management learning '
#                          'opportunities',
#                          'Culture, Remote Work, Money',
#                          'diversity, financially strong company to invest in '
#                          'growth and innovation >5 years',
#                          'proven technology',
#                          'WFH',
#                          'geography',
#                          'New challenges, interesting problems to solve',
#                          'Clear targets, respect the strategy execution, to be '
#                          'real responsible for the key activity of my role, '
#                          'respect for the budget they give me, sharing more',
#                          'Mentors to learn from; good projects to work on; '
#                          'salary',
#                          'role; culture; benefits',
#                          'none',
#                          'I am looking for opportunities to work with bigger e '
#                          'mobility company in Europe and America',
#                          'Female job descriptors appear to be lower',
#                          'Better parental leave, flexible remote to hyrbid '
#                          'work in my area, career growth as a Material '
#                          'engineer.',
#                          'no',
#                          'Benefits, Role, Work life balance',
#                          'Training',
#                          'Work-Life balance',
#                          '1. Job security 2. Capacity building 3. Location',
#                          'Role in process R&D',
#                          'having fun while working',
#                          'Geographical, better salary, better company culture',
#                          'remote-working, benefits, role',
#                          'Career growth; Work-life balance; Competitive salary',
#                          'Career Growth\nMoney',
#                          'No',
#                          'More decision making',
#                          'Company culture, Career Developement, Mentoring, '
#                          'Development Opportunities',
#                          'Geography, stability, money',
#                          'US based or  Belgium, strategy development, coaching',
#                          'Stability, Learning opportunities, Carrier '
#                          'opportunities',
#                          'Innovative solution; strong growth opportunity',
#                          'money, remote',
#                          'Clear Job Description',
#                          'I am being asked to relocate in the next year. An '
#                          'opportunity to stay where I am is my highest '
#                          'priority.',
#                          'money, career growth, career strategy',
#                          'Geography; company stability; culture',
#                          'more money without being stretched as thin',
#                          'Ability to work fully remote',
#                          'money, work life balance, communication across the '
#                          'teams',
#                          'Money, posibility for personal growth',
#                          '1. Role 2. Compensation 3. Location',
#                          'Hybrid schedule (vs in person everyday), higher '
#                          'salary',
#                          'upward mobility',
#                          'thinking of leaving the country, thinking of '
#                          'switching to other aspects in this industry such as '
#                          'data or product',
#                          'Time flexibility',
#                          'The company should be focused on producing good '
#                          'product/service not focused on speed to market;\n'
#                          'A company with good documentation and processes in '
#                          'place',
#                          'Talented colleagues',
#                          'Culture, position',
#                          'Stability, work from home',
#                          'Money, career development',
#                          'Compensation, growth, flat organization.',
#                          'Item 1: Culture, Item 2: Innovation, Item 3: Career '
#                          'growth and opportunities',
#                          "I'd be willing to take a pay cut to only work 3 "
#                          "days/week since I have personal projects I'm working "
#                          'on',
#                          'benefits, culture',
#                          'Not in the battery industry',
#                          'Geography, Perks, Culture',
#                          'global opportunities where i can take my learning to '
#                          'middle east and africa',
#                          'Learning opportunities',
#                          'More hands-on work, more impact',
#                          'Moneys, work balance',
#                          'Tolerance for Muslim praying time; no racial '
#                          'discrimination; flexibility in communication',
#                          'New edge technology and advancement in EVs',
#                          'Pay as contractor; hours per week',
#                          'Not looking',
#                          'If it were looking i would need to be in a '
#                          'leadership position and would do more business '
#                          'development w people that have a team that is all '
#                          'encompassing and well funded',
#                          'geography, benefits, money, role',
#                          'Better pay and resources',
#                          'Creative growth; stability; money',
#                          'Work-life, leave, benefits',
#                          'ability to contribute to product and company '
#                          'direction, dynamic/growing company,',
#                          'Better facilities and environment',
#                          'Culture; Opportunity for personal growth within '
#                          'company structure; compensation',
#                          'No',
#                          'responsibility',
#                          'culture',
#                          'Research; business; Director',
#                          'Culture, Team Quality',
#                          'geography, money, benefits, culture are high '
#                          'important for me',
#                          'job security, but it does not exist anywhere, not '
#                          'even in National Labs',
#                          'role change, career development',
#                          'Salary raises; upward movement',
#                          'a good manager'],
#  'retention_num_employer_changes': {np.float64(0.0): 184,
#                                     np.float64(1.0): 212,
#                                     np.float64(2.0): 123,
#                                     np.float64(3.0): 84,
#                                     np.float64(4.0): 14,
#                                     np.float64(5.0): 1,
#                                     np.float64(6.0): 3,
#                                     np.float64(7.0): 1,
#                                     np.float64(10.0): 2,
#                                     '_tot_': 624},
#  'retention_sentiment': {'keys': ['My company has a good reputation in the '
#                                   'industry',
#                                   'I want to stay with my company for at least '
#                                   '12 more months',
#                                   'I am satisfied with my current job '
#                                   'stability',
#                                   'I am confident in my ability to find my '
#                                   'next job in the industry'],
#                          'mean': array([3.7254902 , 3.61652893, 3.41186161, 3.92520325]),
#                          'stdev': array([1.07548617, 1.34166217, 1.28803555, 1.10177931]),
#                          'values': array([[2., 2., 4., 4.],
#        [3., 3., 2., 5.],
#        [4., 5., 3., 5.],
#        ...,
#        [5., 3., 5., 3.],
#        [4., 5., 5., 5.],
#        [4., 5., 5., 4.]], shape=(665, 4))}}

# %%
plotter.make_bar_plot_from_dict(
    res_company_retention['retention_factors'],
    title='If you were offered a similar role with a different company, what factors would influence your decision to accept the offer?',
    saveas='company_retention_factors.png',
    exclusions=['bonuses'],
    replacements={'Salary': 'Salary, bonuses'},
    num_elements=12,
    sorted=True
)

plotter.make_bar_plot_from_dict(
    res_company_retention['retention_is_on_market'],
    title='Are you currently seeking new job opportunities?',
    saveas='company_retention_is_on_market.png',
    sorted=True
)

plotter.make_bar_plot_from_dict(
    res_company_retention['retention_num_employer_changes'],
    title='How many times have you changed employers in the past 5 years?',
    saveas='company_retention_num_employer_changes.png',
    num_elements=5,
)

# %% [markdown]
# ## Company Benefits

# %%
res_company_benefits = analyst.summarize_company_benefits()
pprint(res_company_benefits)
# Out:
# {'benefits_priorities': {'keys': ['Mental health support',
#                                   'Work-life balance initiatives',
#                                   'Financial wellness programs',
#                                   'Career development opportunities'],
#                          'mean': array([3.13615023, 3.13551402, 2.83568075, 3.07328605]),
#                          'stdev': array([1.18292159, 1.18216911, 1.10536215, 1.15544567]),
#                          'values': array([[nan, nan, nan, nan],
#        [nan, nan, nan, nan],
#        [nan, nan, nan, nan],
#        ...,
#        [ 3.,  3.,  1.,  3.],
#        [ 3.,  4.,  3.,  4.],
#        [ 3.,  3.,  5.,  3.]], shape=(665, 4))},
#  'entitlements': {'Advance salary': 1,
#                   'Child care FSA account': 1,
#                   'Educational': 100,
#                   'Employee Stock Purchase Program': 1,
#                   'Engineer title cost repayment': 1,
#                   'Gym or physical wellness stipend': 94,
#                   'Healthcare coverage or stipend': 312,
#                   'I am self employed so these are not available to me...yet': 1,
#                   'Learning': 1,
#                   'Market intelligence tools': 1,
#                   'Meal stipend': 73,
#                   'NOthing': 1,
#                   'No other benefits': 1,
#                   'None': 1,
#                   'Nothing': 1,
#                   'Nothing above': 1,
#                   'Parking': 1,
#                   'Personal transport': 1,
#                   'Retirement account funding or match': 240,
#                   'Student loan matching': 3,
#                   'Telephone': 1,
#                   'Transit benefits': 75,
#                   'Transportation': 1,
#                   'Work-from-home stipend': 71,
#                   '_tot_': 387,
#                   'free Transport by public transport companies': 1,
#                   'none': 2,
#                   'nothing from this list': 1,
#                   'or continued education stipend': 100,
#                   'parking': 1,
#                   'railway (first-class)': 1,
#                   'trainings': 1,
#                   'tuition': 100},
#  'parental_leave_weeks': {np.float64(0.0): 68,
#                           np.float64(1.0): 15,
#                           np.float64(2.0): 43,
#                           np.float64(3.0): 11,
#                           np.float64(4.0): 23,
#                           np.float64(5.0): 5,
#                           np.float64(6.0): 19,
#                           np.float64(7.0): 1,
#                           np.float64(8.0): 20,
#                           np.float64(9.0): 2,
#                           np.float64(10.0): 3,
#                           np.float64(12.0): 45,
#                           np.float64(13.0): 2,
#                           np.float64(14.0): 1,
#                           np.float64(15.0): 1,
#                           np.float64(16.0): 14,
#                           np.float64(17.0): 1,
#                           np.float64(18.0): 2,
#                           np.float64(20.0): 1,
#                           np.float64(24.0): 1,
#                           np.float64(26.0): 2,
#                           np.float64(27.0): 1,
#                           np.float64(30.0): 2,
#                           np.float64(32.0): 1,
#                           np.float64(36.0): 1,
#                           np.float64(48.0): 2,
#                           np.float64(49.0): 1,
#                           np.float64(52.0): 7,
#                           np.float64(60.0): 2,
#                           np.float64(68.0): 1,
#                           np.float64(69.0): 1,
#                           np.float64(78.0): 1,
#                           np.float64(90.0): 1,
#                           np.float64(96.0): 1,
#                           np.float64(104.0): 1,
#                           np.float64(400.0): 1,
#                           '_tot_': 304},
#  'pto_weeks': {np.float64(0.0): 14,
#                np.float64(1.0): 5,
#                np.float64(2.0): 46,
#                np.float64(3.0): 70,
#                np.float64(4.0): 68,
#                np.float64(5.0): 62,
#                np.float64(6.0): 53,
#                np.float64(7.0): 6,
#                np.float64(8.0): 3,
#                np.float64(10.0): 4,
#                np.float64(12.0): 4,
#                np.float64(13.0): 1,
#                np.float64(15.0): 7,
#                np.float64(18.0): 1,
#                np.float64(20.0): 13,
#                np.float64(21.0): 4,
#                np.float64(22.0): 2,
#                np.float64(24.0): 3,
#                np.float64(25.0): 9,
#                np.float64(26.0): 3,
#                np.float64(30.0): 9,
#                np.float64(40.0): 3,
#                np.float64(43.0): 1,
#                np.float64(45.0): 1,
#                np.float64(50.0): 1,
#                np.float64(52.0): 3,
#                np.float64(120.0): 1,
#                np.float64(176.0): 1,
#                np.float64(365.0): 1,
#                '_tot_': 399},
#  'sick_leave_days': {np.float64(0.0): 54,
#                      np.float64(1.0): 12,
#                      np.float64(2.0): 9,
#                      np.float64(3.0): 15,
#                      np.float64(4.0): 9,
#                      np.float64(5.0): 74,
#                      np.float64(6.0): 14,
#                      np.float64(7.0): 9,
#                      np.float64(8.0): 9,
#                      np.float64(9.0): 2,
#                      np.float64(10.0): 42,
#                      np.float64(11.0): 1,
#                      np.float64(12.0): 10,
#                      np.float64(13.0): 1,
#                      np.float64(14.0): 9,
#                      np.float64(15.0): 9,
#                      np.float64(20.0): 14,
#                      np.float64(21.0): 2,
#                      np.float64(24.0): 1,
#                      np.float64(25.0): 2,
#                      np.float64(30.0): 16,
#                      np.float64(40.0): 5,
#                      np.float64(42.0): 1,
#                      np.float64(45.0): 1,
#                      np.float64(60.0): 2,
#                      np.float64(90.0): 6,
#                      np.float64(100.0): 1,
#                      np.float64(120.0): 1,
#                      np.float64(180.0): 1,
#                      np.float64(200.0): 1,
#                      np.float64(300.0): 1,
#                      np.float64(365.0): 12,
#                      '_tot_': 346},
#  'unique_benefits_list': ['Career Opportunities',
#                           'Exposure to senior executives',
#                           '[Parental leave is state governed, 480 days/child '
#                           'at 80% of salary, matched another part by company '
#                           "by 10%.] [Sweden don't have sick days, it is 80% of "
#                           'salary for "as long as needed" (not infinite, but '
#                           'long, not sure how long)]. [Also like the 7 week '
#                           'vacation.]',
#                           'Kids school entry subsidie; Kids Cristsmas present',
#                           '-',
#                           'work life balance, flexibility, flat structure',
#                           'Na',
#                           'The opportunity to make an own project and defend a '
#                           'PhD work',
#                           'unlimited annual leave',
#                           'long holiday allowance;',
#                           'Free flying lessons with instructor of my free '
#                           'choice',
#                           'unlimited PTO; work travel flexibility '
#                           '(airline/hotel); remote work',
#                           'hybrid work; ambitious project; team culture',
#                           'schedule flexibility, bonuses',
#                           '1) Work from home 2)100% company paid health '
#                           'premium paid',
#                           'working from home',
#                           '0',
#                           'Parental Leave; Sick Days; Vacation',
#                           'Vacation',
#                           'car+ tickets restaurant',
#                           'Equity grants',
#                           'RRSP Matching;',
#                           'My own company',
#                           'mentorship, continued education',
#                           'home office, life work balance',
#                           'unlimited PTO (within reason) / flexible work '
#                           'schedule',
#                           'Employee discounts',
#                           'company car, internet payment, train ticket',
#                           'Adoption assistance; pet insurance; on-site fitness '
#                           'center',
#                           'No time clock; autonomy; input valued',
#                           'Snacks; WFR capabilities',
#                           'Work from home, parental leave',
#                           'Autonomy as sole director',
#                           'Flexible leaves',
#                           'fully covered healthcare for me and a dependent',
#                           'continuing education stipend',
#                           'none',
#                           '"New equipment training"',
#                           'Possibility to do more than 3 times business trip a '
#                           'year; transportation benefit; unlimited sick leave '
#                           'opportunity to take',
#                           'Additional holidays',
#                           'flexible working scheme, health benefits',
#                           'Honesty, communication, training',
#                           'Superannuation, free parking, flexible work hours',
#                           'Benefit of recognising talent and appreciation',
#                           'Travelling;',
#                           'Time Flexibility, Stressfree Work, Freewill',
#                           'Housing benifit',
#                           'work from home, freedom, growth',
#                           'Health Insurance',
#                           'no',
#                           'Flexible time off; remote work',
#                           'SARs (for our employees); weekly helathy lunch;  '
#                           'drinks and parties',
#                           'Equity; mental health benefit; better health '
#                           'insurance',
#                           'Dependent Care Savings Account; Inexpensive but '
#                           'high quality life insurance; Short Term and Long '
#                           'Term Disability Insurance',
#                           'No',
#                           'Flexible hours',
#                           'Meal bonus, healthcare, pension',
#                           'career growth',
#                           '401k matching on roth 401k contributions',
#                           'paid family leave, work time flexibility, time off '
#                           'is infinite (but realistically around 30 days)',
#                           '401k matching; stocks',
#                           'no',
#                           '4 day work week; paid healthcare; hybrid work '
#                           'schedule',
#                           '100% remote work',
#                           'no',
#                           'no',
#                           'Cell phone compensation',
#                           'autonomy, leadership quality',
#                           'Equity, Mobile phone usage',
#                           'bonus, meals, novel chances to train in new '
#                           'processes',
#                           'Hybrid work schedule',
#                           'one time bike stipend',
#                           'Friday lunches provided!',
#                           'Relocation leave',
#                           'known senior management',
#                           'Festival coupon, gifts',
#                           'Culture, potential, industry',
#                           'sickleave with pay;variable work hours with core '
#                           'time at office and the rest as per own wishes; own '
#                           'planning of work',
#                           'No not really',
#                           'Internal growth opportunity',
#                           'Pension scheme',
#                           'Transport assistance, health insurance, unpaid '
#                           'leave',
#                           'Share option pool',
#                           'ESOp',
#                           'no need to check-in/out at daily base of work',
#                           'Retention bonus',
#                           'equity',
#                           'hybrid work, snacks/lunch, vacation balances',
#                           'Good pension',
#                           'Personal Health days (2); flextime; hybrid work '
#                           'schedule',
#                           'Generous health insurance',
#                           'NO',
#                           'Statutory German insurances, i.e. health, pension, '
#                           'etc.',
#                           'Bonus; Health insurance; children education support',
#                           'Pension, 401k match, stock options',
#                           'Unlimited PTO (but with pressure not to take it '
#                           'lol)',
#                           'Lunch stipend; work travel',
#                           'EXPATRIATION, HOUSEHOLD, DEPENDING CHILD',
#                           'no',
#                           'No',
#                           'flexible holidays',
#                           'none',
#                           'Company Car',
#                           'generous parental leave; health benefit e.g. gym '
#                           'contribution',
#                           'workplace flexibility (remote/hybrid), flexibility '
#                           'to delegate portions of benefits to certain health '
#                           'categories, no limit to sick days',
#                           'Parental leave, work from home flexibility',
#                           "We offer stock options but I'm not high on them",
#                           'Breakfast and lunch provided',
#                           'degree of freedom',
#                           'free EV charging; free lunches; hybrid '
#                           'work/location',
#                           'Growth Opportunity',
#                           'company car',
#                           'Unlimited PTO',
#                           'Flexible home office',
#                           'sport programm, job bike',
#                           'my focus is on job quality not benefits...if the '
#                           'salary is aligned I will think by myself to my life '
#                           'or benefits',
#                           'freedom; flexible work times',
#                           'no',
#                           'HMO, Pension, out station allowance',
#                           '1. LTIP, 2. structured performance related bonuses, '
#                           '3. extra medical care stipend, 4. company '
#                           'retirement plans',
#                           'Parental leave, flexible work environment',
#                           'no',
#                           'Flexibility; Independent',
#                           'Friendly',
#                           'nothing',
#                           'Nil',
#                           'Relocation perk',
#                           '[working environment]; [flexible working hours]; '
#                           '[gym in the factory]]',
#                           'work from home perks, flexible working hours',
#                           'Comprehensive health insurance Flexible working '
#                           'hours Professional development courses',
#                           'Good working atmosphere; Confidence; Profit '
#                           'sharing; Salary increases',
#                           'Car lease salary sacrifice',
#                           'partner and children to move to the US',
#                           'Gifts for kids, Association discounts, subsidies '
#                           'sport/culture/school',
#                           'Unlimited PTO; fully remote',
#                           'work remotely',
#                           'Dependable health insurance, generous paid time off',
#                           '"Health Insurance; Compensation"',
#                           'Remote work',
#                           'Retirement match; health care',
#                           'product discounts',
#                           'Egg freezing',
#                           '401k match, hsa match, meals',
#                           'No',
#                           '1. Role 2. Location 3. Industry',
#                           'Unlimited PTO',
#                           'Equity compensation (RSUs or stock options), hybrid '
#                           'work schedule',
#                           'Work life balance; flexibility',
#                           'company events/celebration, flexibility for unpaid '
#                           'leave for extended international travel',
#                           'courses for personal development, conferences',
#                           'Flexibility with my time; company name recognition',
#                           'a gym at the office',
#                           'No',
#                           'pension contribution',
#                           'No I have no any benefit',
#                           'Remote work, respect weekends, good 401(k) match of '
#                           '4%',
#                           'no',
#                           'Flex Time off ; HSA health plans ; Equity',
#                           'Flexible time off',
#                           'No',
#                           'Meals by kitchen team',
#                           '1. Sports',
#                           'Recognition, next level challenge',
#                           'Continuos education (seminars and conferences), gym',
#                           'Company car , on long haul flight business class',
#                           'wfh',
#                           'Prayer room; flexibility in handling the job; '
#                           'transport and telecommunication coverage',
#                           'ESOPs',
#                           'No',
#                           'I have a lot of freedom',
#                           'Free healthcare plan',
#                           'Work from Home, Health Insurance, Retirement Match',
#                           'lunch meal',
#                           'Unlimited time off',
#                           'no',
#                           'No',
#                           'vehicle scheme',
#                           'No',
#                           'Company car',
#                           'no',
#                           'pension, health care into retirement',
#                           'No']}

# %%
plotter.make_bar_plot_from_dict(
    res_company_benefits['entitlements'],
    title='What benefits does your company entitle you to?',
    saveas='company_benefits_entitlements.png',
    exclusions=['tuition', 'or continued education stipend'],
    replacements={'Educational' : 'Educational, tuition, or continued education stipend'},
    num_elements=10,
    sorted=True
)

plotter.make_bar_plot_from_dict(
    utils.sort_dict(res_company_benefits['parental_leave_weeks'], by='keys', reverse=False),
    title='How many weeks of parental leave are you entitled to?',
    saveas='company_benefits_parental_leave_weeks.png',
    num_elements=16
)

plotter.make_bar_plot_from_dict(
    utils.sort_dict(res_company_benefits['pto_weeks'], by='keys', reverse=False),
    title='How many weeks of paid time off are you entitled to each year?',
    saveas='company_benefits_pto_weeks.png',
    num_elements=16
)

plotter.make_bar_plot_from_dict(
    utils.sort_dict(res_company_benefits['sick_leave_days'], by='keys', reverse=False),
    title='How many days of sick leave are you entitled to?',
    saveas='company_benefits_sick_leave_days.png',
    num_elements=16
)

# %% [markdown]
# # Filter on subpopulations

# %%
filtered_list = analyst.filter_respondents_on(is_student=False,
                                              gender='Female')
print(len(filtered_list))
# Out:
# 193

# %% [markdown]
# # Summarize stats for subpopulations

# %%
res = analyst.summarize_census_skills_demand(filtered_list)
pprint(res)
# Out:
# {'skills_in_demand': ['Scientific Observation, Data Analysis, ability to '
#                       'contribute to a team',
#                       '[cell knowledge]',
#                       'electrochemistry, adaptability, perserverance',
#                       'Cell cycling experience, electrode fabrication '
#                       'experience, SEM',
#                       'hands-on experience building cells; materials research '
#                       'for dry processes; interdisciplinary collaboration',
#                       'Data analysis, statistics, communication',
#                       'troubleshooting, learning, communication',
#                       'Electrochemical analysis, resilience, adaptability',
#                       'materials science, electrochemistry, eagerness/ability '
#                       'to learn',
#                       'Fundamental electrochemistry knowledge, Material '
#                       'characterization, Data analysis and interpretation',
#                       'AI/ML, Electrochemical Expertise, Thermal Management',
#                       'Engineering supply chain project development',
#                       'Skill 1 Prior knowledge of industry Skill 2 ability to '
#                       'formulate effective procedures skill 3 flexibility',
#                       'Faire protection engineering; maintenance; '
#                       'manufacturing technician',
#                       'Battery manufacturing skills, capabilities to quickly '
#                       'build prototype, simulation skills',
#                       'Battery energy storage system; electrical engineering',
#                       'Materials knowledge; research experience; understanding '
#                       'of basic science',
#                       '1) Basic understanding of a battery 2) Battery '
#                       'manufacturing 3)Battery failures',
#                       'project management; critical thinking; communication',
#                       'Experience with deposition techniques; Experience with '
#                       'batteries; Experience with imaging techniques',
#                       'Manufacturing; Materials Science; Data Analytics',
#                       'Coding; Electrochemistry knowledge',
#                       'Advanced manufacturing; supply chain; cell development',
#                       'The ability to improve the process; software automation',
#                       '[multilingualism 1] [product design 2] [marketing 3]',
#                       'Motivation, Innovation, AI',
#                       'integration into bigger picture, understanding numbers',
#                       'Electrochemistry data analysis/data science; '
#                       'manufacturing/scale-up knowledge; good communication of '
#                       'scientific findings',
#                       'Leadership Communication Empathy',
#                       'Programming; electrochemistry; mechanical design',
#                       'data analysis; quality control; hands-on know-how',
#                       'Skill 1: systems approach with scientific '
#                       'methodologies; skill 2: both chemistry and engineering '
#                       'process R&D; skill 3: safety testing and mitigation '
#                       'analysis',
#                       'Software engineering, product marketing, market '
#                       'optimization experts',
#                       '[Battery modelling ] [project management] [market '
#                       'knowledge]',
#                       'communication, power electronic knowledge, compliance '
#                       'knowledge',
#                       'Problem solving; communication; experience',
#                       '"Communication; collaboration;team work;AI")',
#                       'data analysis, electrochemistry, systems engineering',
#                       '1. PLC programming ,in depth knowledge of battery '
#                       'management system and quick decision',
#                       'data science knowledge; AI based algorithm capability; '
#                       'battery design expertise',
#                       'Leading a technical team with emotional intelligence,, '
#                       'failure analysis standardized in residential battery '
#                       'industry(honesty versus marketing, could help clear up '
#                       'issues to standardize, sexual harassment trainings for '
#                       'technical managers',
#                       'Innovation; Business Development; Cross-cultural '
#                       'Understanding',
#                       'Flexibility, Knowledge, Qualification',
#                       'data analysis, electrical engineering, programming',
#                       'Automation and AI integration into the manufacturing '
#                       'process; handling hazardous materials and chemical '
#                       'engineering',
#                       'Technical project/program management; Business acumen',
#                       'Hollistic understanding, material, battery regulations',
#                       'Curiosity, team spirit',
#                       'Communication, Getting things done, working under '
#                       'pressure',
#                       'Equipment design, process optimization, facility design '
#                       'and implementation',
#                       'material synthesis, material analysis, electrochemistry',
#                       'Data Analysis; Leadership; Fast-paced learning',
#                       'scaling technology; battery recycling; battery '
#                       'manufacturing',
#                       'System integration, mechanical engineering, chemical '
#                       'engineering',
#                       'High volume manufacturing experience; experience with '
#                       'high volume manufacturing tools - how they work, how to '
#                       'spec them, Digital Architecture for a battery '
#                       'factory... MES/SCADA',
#                       'Diverse Mindset; Interdisciplinary Communications; '
#                       'Public Engagement',
#                       'data science, battery recycling expertise, circular '
#                       'economy expertise',
#                       'knowledge in electrochemistry, material chemistry, '
#                       'system design',
#                       '[global strategic view] ;[real compromise for action '
#                       'against climatic change]',
#                       'integration; electronics, electrochemistry',
#                       'Supply chain knowledge; Ability to work in a team; '
#                       'Coating knowledge',
#                       '[process engineers - manufacturing]',
#                       'data analysis; time management; understanding of '
#                       'chemistry',
#                       'Experience',
#                       'electrochemical testing; programming, data analysis',
#                       '1) communication 2)collaboration 3)empathy',
#                       'Controls(bms), material discovery (ml AI)',
#                       'NPI, sales, statistics',
#                       'Machine learning, modeling, characterization testing',
#                       'Battery trouble shooting; battery knowledge; adhesive '
#                       'knowledge',
#                       'Cell design, Process and material selection',
#                       'the ability to transfer R&D lab results to pilot and '
#                       'production; ability to communicate/facilitate the '
#                       'communication between people with different backgrounds '
#                       'and education level. Willingness to get hands dirty.',
#                       'flexibility and ability to deal with change',
#                       'control, models, systems',
#                       'Networks, Abilities to speak around technical topics,  '
#                       'ready to fast changing',
#                       'Cell cycling, electrochemical modelling, 5+ years '
#                       'experience',
#                       'Technical acumen; Board relationship management',
#                       '[technical understanding], [Soft skills]',
#                       'Most in demand is different from overlooked… '
#                       'underappreciated skills are data analytics; science '
#                       'communication; mentorship and community building',
#                       'interpretation of data, statistics, operational '
#                       'experience',
#                       'Fire response and mitigation. Just the one',
#                       'Data science,Leadership and Time Management',
#                       'electrochemistry, manufacturing, data analyses',
#                       'Process engineering, manufacturing-related, modelling',
#                       'electrochemistry, people skills, simulation',
#                       '[cross-disciplinary collaboration]; [communication]; '
#                       '[VUCA Robustness]',
#                       'tallented; hard-working; well-organized',
#                       'Failure modeling; battery physics/chemistry modeling; '
#                       'field data analysis',
#                       'BESS integrator, battery testing and R&D ,',
#                       'Focus on solutions for disposing of and recycling '
#                       'lithium or other chemical batteries',
#                       'System Architecture development; requirement '
#                       'decomposition; thermal propagation prevention design',
#                       'Regulatory Compliance; Battery synthesis; Engineering',
#                       'systems engineering, data analytics, technicians',
#                       'Web handling; Process development; Material development',
#                       'Meticulous, team-player, problem-solver',
#                       'data analysis, materials characterization',
#                       'Material Science and Engineering, Battery Simulation '
#                       'and Modeling, Electrochemical testing and '
#                       'characterization',
#                       'Data analysis, process development, manufacturing',
#                       'Explaining how batteries work in general terms; '
#                       'understanding of how things work with battery '
#                       'manufacturers; knowledge of battery system (cell + BMS) '
#                       'to understand system level performance',
#                       'Flexibility, collaboration, drive',
#                       'Skill 1 Think outside of the box Skill 2 Flexable Skill '
#                       '3 Great memory thing change fast',
#                       'Team oriented; flexible; self-motivated',
#                       'Understanding of how a business works, communication '
#                       'skills',
#                       '(communication skill)(AI)(business development)',
#                       'Battery Management Systems Operator and Technician, '
#                       'Energy Storage Grid Optimization, Manufacturing '
#                       'technician',
#                       'HV safety,',
#                       'technical expertise, understanding numbers',
#                       'Development, O&M, legal',
#                       'Self starter, critical thinker, flexible',
#                       'electrochemistry, process engineering, Data science',
#                       'Electrochemistry, manufacturing',
#                       'Modeling, chemical handling/lab skills, machine '
#                       'learning',
#                       'Electrochemistry, Automation and AI',
#                       '[contractual specifics related to BESS]; [AI in the '
#                       'service of battery optimization]: [data analysis and '
#                       'modeling].]',
#                       'Electrochemistry; materials science; process '
#                       'engineering',
#                       'Electrochemistry, team working, data analysis',
#                       'Understanding of markets and revenue; understanding of '
#                       'the main processes of how to bring projects live; '
#                       'ability to learn new things/ not being scared of '
#                       'technical bits',
#                       'integration skills that can optimize battery '
#                       'performance',
#                       'R&D, battery analysis, battery engineering',
#                       'Curiosity, rigor, teamwork',
#                       'Ability to work with uncertainty, Grit, Persistence',
#                       'Creativity, Solid academic background, technical '
#                       'understanding',
#                       'Deep understanding of cells (performance in the field, '
#                       'failure modes, manufacturing realities); Controls '
#                       'Engineering for factory tooling; coating development',
#                       'education, communication, willingness to learn',
#                       'operational strategy, embedded systems engineering, '
#                       'operational finance',
#                       'Technical, Communication, Collaboration',
#                       'Ability to handle uncertainties; Ability to fix complex '
#                       'problems that no one has handled before; ultrasonic '
#                       'laserwelding',
#                       'Material Science, Electrochemistry,  Electricity '
#                       'markets,',
#                       'mineral exploration, value driven leadership (vs. '
#                       'bottom line emphasis), and regulation fast-tracking',
#                       'agility, technical skills, intellectual curiosity',
#                       'BMS; Recycling; Data analysis',
#                       'computational skills, battery modelling, data analysis',
#                       'Skills: Hybrid knowledge of 1. CSA/MEP design & '
#                       'buildability, 2. Clean & Dry rooms design, and Process '
#                       'integration.',
#                       '[battery modelling];[good communication '
#                       'skills];[python/C++]',
#                       '"Soft" skills, like strategy',
#                       'supply chain',
#                       'Skill 1–Electrochemical testing setup. skill 2- DOE, '
#                       'skill 3-failure analysis',
#                       'technical and chemical understanding',
#                       'Python, electrochemical testing, crystallography',
#                       'teamwork; communication; presentation',
#                       'Data interpretation; electrochemistry; surface '
#                       'knowledge',
#                       'Adaptability, team work, staying on task',
#                       'clear communication, cell-level design, BMS tuning',
#                       'Research; Validation; Technical Skill',
#                       'Design and simulation, Research, problem solving skills',
#                       'technical knowledge, recycling knowledge',
#                       'collaborate in teams with efficiency and good '
#                       'communication',
#                       'failure mode analysis, degradation mechanism, life '
#                       'prediciton',
#                       'Really depends on the role (and these are more '
#                       'characteristics than skills), but generally: domain '
#                       'expertise; network; passion',
#                       'Critical thinking, creativity, science communication',
#                       'Network Time spent intorno this business Technic '
#                       'Knowledge',
#                       'battery applications, emerging chemistry, business '
#                       'modeling',
#                       'Modeling; optimization; creativity',
#                       'Curious, flexible, patient.',
#                       'software, maccor data, Python',
#                       '[Project Managment]; [Adaptability]; [Chemistry '
#                       'Expertise]',
#                       '[hands-on industry experience][creativity][scale up '
#                       'processing]',
#                       'Understanding of electrical circuits; Statistics; '
#                       'Ability to get things done',
#                       'Electrochemistry, business acumen ,Materials '
#                       'manufacturing',
#                       'Data analysis, knowledge of electro chemistry, '
#                       'understanding of the market',
#                       'Experience in industrialization and provision, 2. Data '
#                       'processing and analysis, 3. The ability to integrate '
#                       'various characterization method',
#                       '[Electrochemistry];[Software];[Hardware];',
#                       'Transparency in methods, communication with leaders, '
#                       'critical review',
#                       'recognizing patterns; safety focus; system integration',
#                       'Patience, sharing knowledge',
#                       'Broad skillsets; battery knowledge; data analysis',
#                       'Network; experience; business development',
#                       'cell chemistry modeling, Machine learning, system '
#                       'modeling',
#                       '[Data Analysis],[DoE],[Physics]',
#                       'Laboratory skills, Data Analytical skills, '
#                       'Communication',
#                       'innovation on materials; data analytics; understanding '
#                       'of manufacturing workflow',
#                       'quality control',
#                       'Thermal Management and Safety Engineering – Expertise '
#                       'in understanding, modeling, and mitigating thermal '
#                       'runaway and fire risks in batteries, especially for '
#                       'large-scale energy storage and EV applications, is '
#                       'critical but often underappreciated.  Battery Recycling '
#                       'and Lifecycle Analysis – Skills in designing for '
#                       'recyclability and performing detailed lifecycle '
#                       'assessments are becoming increasingly vital as the '
#                       'industry focuses on sustainability and circular '
#                       'economies.  Electrochemical Simulation and Modeling – '
#                       'Advanced computational skills to model battery behavior '
#                       '(e.g., charge-discharge cycles, degradation) are in '
#                       'high demand but often overshadowed by more hands-on lab '
#                       'expertise.',
#                       'Safety knowledge; engineering/software; innovation',
#                       'Adaptability; synthesis; innovation'],
#  'value_chain_in_demand': {'Cell production': 91,
#                            'Component/precursor production': 47,
#                            'Consulting': 13,
#                            'Diagnostic/repair': 1,
#                            'Energy infrastructure': 44,
#                            'Equipment manufacturing': 32,
#                            'Mining': 10,
#                            'Module/pack production': 37,
#                            'Not sure': 1,
#                            'Product integration (electronics)': 18,
#                            'Product integration (stationary storage)': 29,
#                            'Product integration (vehicles': 32,
#                            'Recycling': 94,
#                            'Refining': 14,
#                            'Safety & Compliance': 1,
#                            'Software': 37,
#                            'Waste collection and disassembly': 1,
#                            '_tot_': 193,
#                            'efficient use': 1,
#                            'geoscience skills for exploration': 1,
#                            'health and safety diagnostics': 1,
#                            'material discovery': 1,
#                            'mobility)': 32,
#                            'no idea': 1,
#                            'research and development': 1}}

# %% [markdown]
# # Study company information
#
# Operate on the subset of data corresponding to working professionals who have completed the survey in its entirety.

# %%
res = analyst.summarize_company_satisfaction()
res
# Out:
# {'keys': ['I am satisfied with my compensation',
#   'I am being underpaid compared to similar roles',
#   'I am satisfied with the raises and/or bonuses I have been receiving'],
#  'values': array([[3., 4., 2.],
#         [4., 2., 3.],
#         [3., 5., 2.],
#         ...,
#         [2., 3., 3.],
#         [4., 2., 4.],
#         [4., 1., 4.]], shape=(665, 3)),
#  'submit_time': array([Timestamp('2024-10-04 20:36:11'), Timestamp('2024-10-04 20:35:28'),
#         Timestamp('2024-10-04 20:34:34'), Timestamp('2024-10-04 20:34:32'),
#         Timestamp('2024-10-04 20:31:17'), Timestamp('2024-10-04 20:28:57'),
#         Timestamp('2024-10-04 20:23:39'), Timestamp('2024-10-04 20:22:55'),
#         Timestamp('2024-10-04 20:22:39'), Timestamp('2024-10-04 20:16:00'),
#         Timestamp('2024-10-04 20:15:36'), Timestamp('2024-10-04 20:14:41'),
#         Timestamp('2024-10-04 20:12:39'), Timestamp('2024-10-04 20:09:39'),
#         Timestamp('2024-10-04 20:08:20'), Timestamp('2024-10-04 20:02:18'),
#         Timestamp('2024-10-04 19:59:19'), Timestamp('2024-10-04 19:57:04'),
#         Timestamp('2024-10-04 19:56:40'), Timestamp('2024-10-04 19:56:37'),
#         Timestamp('2024-10-04 19:55:59'), Timestamp('2024-10-04 19:55:12'),
#         Timestamp('2024-10-04 19:53:56'), Timestamp('2024-10-04 19:53:14'),
#         Timestamp('2024-10-04 19:52:27'), Timestamp('2024-10-04 19:51:08'),
#         Timestamp('2024-10-04 19:47:59'), Timestamp('2024-10-04 19:43:42'),
#         Timestamp('2024-10-04 19:41:38'), Timestamp('2024-10-04 19:40:54'),
#         Timestamp('2024-10-04 19:31:07'), Timestamp('2024-10-04 19:28:07'),
#         Timestamp('2024-10-04 19:27:58'), Timestamp('2024-10-04 19:21:08'),
#         Timestamp('2024-10-04 19:09:01'), Timestamp('2024-10-04 19:08:31'),
#                        'Education or tuition reimbursement': 58,
#                        'Equity (stock': 259,
#                        'Expert tax relief': 1,
#                        'Food/groceries stipend': 1,
#                        'German IG Metall collective bargaining benefits': 1,
#                        'HRA': 1,
#                        'Health and dental': 1,
#                        'Health and wellness stipends': 140,
#                        'Health insurance': 1,
#                        'Healthcare': 1,
#                        'Healthcare plan': 1,
#                        'Holiday compensation': 1,
#                        'Housing': 2,
#                        "I am self-employed and I'm not able to provide these for myself...yet.": 1,
#                        'Leaves': 1,
#                        'Life insurance': 1,
#                        'NONE': 1,
#                        'Na': 1,
#                        'Nil': 1,
#                        'No': 2,
#                        'No Answer': 1,
#                        'No additional Compensation': 1,
#                        'No additional compensation': 1,
#                        'Nothing': 4,
#                        'Patent incentive': 1,
#                        'Pension': 3,
#                        'Random bonus that comes in with no basis': 1,
#                        'Small increase based on performance': 1,
#                        'Transit reimbursement': 1,
#                        'Transport compensation': 1,
#                        'Transportation': 1,
#                        '_tot_': 581,
#                        'cofeteria': 1,
#                        'company car': 1,
#                        'entertaiment': 1,
#                        'etc.)': 259,
#                        'eventually retirement matching': 1,
#                        'free EV charging': 1,
#                        'health/dependent care flexible spending accounts': 1,
#                        'living cost allowance': 1,
#                        'mobile phone compensation': 1,
#                        'no compensation': 1,
#                        'none': 4,
#                        'nothing': 2,
#                        'options': 259,
#                        'private health insurance and pension': 1,
#                        'training fund and pension': 1},
#  'salary_num_bonuses': {'0': 295, '1': 278, '2': 30, '3+': 23, '_tot_': 626},
#  'salary_num_raises': {'0': 243, '1': 372, '2': 30, '3+': 10, '_tot_': 655}}

# %%
plotter.make_bar_plot_from_dict(
    utils.sort_dict(res_company_salary['salary_num_raises'], by='keys', reverse=False),
    title='How many times have you received a base salary increase \nover the past 12 months of employment?',
    saveas='company_salary_num_raises.png'
)

plotter.make_bar_plot_from_dict(
    utils.sort_dict(res_company_salary['salary_num_bonuses'], by='keys', reverse=False),
    title='How many times have you received a bonus \nover the past 12 months of employment?',
    saveas='company_salary_num_bonuses.png'
)

plotter.make_bar_plot_from_dict(
    res_company_salary['salary_comp_types'],
    title='Beyond base salary, what additional compensation types \ndo you receive?',
    saveas='company_salary_comp_types.png',
    exclusions=['options', 'etc.)'],
    replacements={'Equity (stock' : 'Equity (stock options, etc.)'},
    sorted=True
)

# %% [markdown]
# ## Company Info

# %%
res_company_info = analyst.summarize_company_info()
pprint(res_company_info)
# Out:
# {'company_country': {'Argentina': 2,
#                      'Australia': 7,
#                      'Belgium': 8,
#                      'Canada': 23,
#                      'Chile': 1,
#                      'China': 11,
#                      'Czech Republic': 1,
#                      'Denmark': 3,
#                      'Estonia': 1,
#                      'Finland': 3,
#                      'France': 18,
#                      'Germany': 41,
#                      'Hungary': 1,
#                      'India': 40,
#                      'Indonesia': 2,
#                      'Iran': 3,
#                      'Ireland {Republic}': 2,
#                      'Israel': 4,
#                      'Italy': 13,
#                      'Japan': 3,
#                      'Kenya': 1,
#                      'Korea South': 3,
#                      'Luxembourg': 1,
#                      'Malaysia': 3,
#                      'Mexico': 3,
#                      'Morocco': 1,
#                      'Netherlands': 11,
#                      'Nigeria': 3,
#                      'Norway': 10,
#                      'Poland': 2,
#                      'Portugal': 6,
#                      'Serbia': 1,
#                      'Singapore': 2,
#                      'South Africa': 1,
#                      'Spain': 7,
#                      'Sweden': 24,
#                      'Switzerland': 6,
#                      'Taiwan': 2,
#                      'Turkey': 7,
#                      'United Arab Emirates': 1,
#                      'United Kingdom': 52,
#                      'United States': 329,
#                      'Vietnam': 1,
#                      'Zambia': 1,
#                      '_tot_': 665},
#  'company_headcount': {'1,001-5,000': 63,
#                        '1-10': 65,
#                        '10,001-25,000': 23,
#                        '100,000+': 57,
#                        '101-250': 74,
#                        '11-50': 116,
#                        '25,001-50,000': 20,
#                        '251-500': 60,
#                        '5,001-10,000': 46,
#                        '50,001-100,000': 14,
#                        '501-1,000': 44,
#                        '51-100': 77,
#                        '_tot_': 659},
#  'company_stage': {'Established (significant market presence)': 195,
#                    'Mid-sized (stable growth)': 68,
#                    'Pre-startup (planning)': 20,
#                    'Scale-up (rapid growth)': 174,
#                    'Startup (early growth)': 201,
#                    '_tot_': 658},
#  'company_state': {'Alabama': 1,
#                    'Arizona': 5,
#                    'California': 133,
#                    'Colorado': 12,
#                    'Connecticut': 2,
#                    'District': 1,
#                    'District of Columbia': 2,
#                    'Florida': 1,
#                    'Georgia': 3,
#                    'Illinois': 7,
#                    'Indiana': 6,
#                    'Kentucky': 2,
#                    'Louisiana': 2,
#                    'Maryland': 4,
#                    'Massachusetts': 29,
#                    'Michigan': 35,
#                    'Minnesota': 6,
#                    'Missouri': 2,
#                    'Montana': 1,
#                    'Nevada': 4,
#                    'New Jersey': 3,
#                    'New York': 12,
#                    'North Carolina': 6,
#                    'Ohio': 1,
#                    'Oklahoma': 1,
#                    'Oregon': 2,
#                    'Pennsylvania': 7,
#                    'Rhode Island': 1,
#                    'Tennessee': 2,
#                    'Texas': 13,
#                    'Virginia': 3,
#                    'Washington': 8,
#                    '_tot_': 317},
#  'company_team_count': {'1-10': 424,
#                         '101+': 13,
#                         '11-20': 125,
#                         '21-50': 61,
#                         '51-100': 13,
#                         '_tot_': 636},
#  'company_value_chain': {'Automation components': 1,
#                          'Battery R&D': 1,
#                          'Battery manufacturing': 1,
#                          'Cell production': 210,
#                          'Chemical supplier': 1,
#                          'Component/precursor production': 145,
#                          'Construction': 1,
#                          'Consulting': 103,
#                          'Contract Research': 1,
#                          'Data': 1,
#                          'Department of Energy': 1,
#                          'Distribution': 1,
#                          'Distributor and sales': 1,
#                          'Education': 2,
#                          'Electrolyte': 1,
#                          'Electrolyte and Cell R&D': 1,
#                          'Energy infrastructure': 48,
#                          'Equipment manufacturing': 77,
#                          'GOVERNMENT/INTERNATIONAL ORGANIZATION': 1,
#                          'Government funded research': 1,
#                          'Independent power producers': 1,
#                          'Innovation': 1,
#                          'Investment': 1,
#                          'Mineral Exploration and Geoscience': 1,
#                          'Mining': 14,
#                          'Module/pack production': 128,
#                          'Non-Profit': 1,
#                          'Nonprofit': 2,
#                          'Not a battery company': 1,
#                          'OEM': 1,
#                          'Packaging': 1,
#                          'Product integration (electronics)': 49,
#                          'Product integration (stationary storage)': 74,
#                          'Product integration (vehicles': 113,
#                          'Project development': 1,
#                          'ProtoType': 1,
#                          'QA/QC': 1,
#                          'Quality Inspection Equipment': 1,
#                          'R&D': 11,
#                          'R&D and Prototyping': 1,
#                          'Recruitment': 1,
#                          'Recycling': 40,
#                          'Refining': 21,
#                          'Research': 4,
#                          'Research Center': 1,
#                          'Research Institution': 1,
#                          'Research and Coalition Lead': 1,
#                          'Research and development': 1,
#                          'Semiconductor suppliers': 1,
#                          'Software': 81,
#                          'Testing & R&D': 1,
#                          'Testing. Should be a category people... Always overlooked until you need us': 1,
#                          'Utility': 1,
#                          'Vehicle maintenance': 1,
#                          'Venture Capital': 1,
#                          '_tot_': 648,
#                          'car retail': 1,
#                          'development and design': 1,
#                          'education': 1,
#                          'engineering design': 1,
#                          'green chemicals': 1,
#                          'mobility)': 113,
#                          'not for profit trade association': 1,
#                          'research': 2,
#                          'seal': 1,
#                          'with a chemistry resambling that of lithium batteries': 1},
#  'num_days_in_office_list': array([  4.,   3.,   5.,   4.,   5.,   5.,   5.,   2.,   0.,   6.,   6.,
#          5.,   3.,   5.,   5.,   0.,   5.,   5.,   4.,  nan,   5.,   0.,
#          1.,   5.,   5.,   4.,   1.,   0.,   5.,   5.,   5.,   4.,   5.,
#          5.,   5.,   5.,   0.,  45.,   5.,   3.,   5.,   2.,   0.,   5.,
#          5.,   6.,   6.,   5.,   6.,   0.,   5.,   0.,   5.,   5.,   3.,
#          5.,   5.,  32.,   0.,   0.,   0.,   5.,   5.,   5.,   5.,   0.,
#          5.,   4.,   5.,   5.,   5.,   0.,   5.,   4.,   3.,   4.,   6.,
#          5.,   0.,   4.,   5.,   5.,   0.,   5.,   4.,   5.,   2.,   4.,
#         40.,   5.,   3.,   3.,   5.,   2.,   0.,   5.,   6.,   3.,   0.,
#          5.,  40.,   5.,  nan,   0.,   5.,   5.,  nan,   0.,   5.,   3.,
#          3.,   5.,  70.,   5.,   4.,   0.,   5.,   5.,   0.,   5.,  40.,
#          3.,   5.,   5.,   3.,   0.,   5.,   5.,   5., 160.,  40.,   0.,
#          4.,   5.,   5.,   5.,   5.,   5.,   5.,   3.,   5.,   5.,   5.,
#          6.,   5.,   5.,   5.,   6.,   5.,   5.,  24.,  50.,   0.,   7.,
#          3.,   5.,   5.,   5.,   1.,   0.,   5.,   0.,  55.,   0.,   5.,
#          1.,   0.,   5.,   5.,   5.,   5.,   4.,   1.,   4.,   0.,   5.,
#          5.,   1.,   3.,   5.,   3.,   0.,   5.,   5.,   5.,   5.,   4.,
#          0.,   0.,   5.,   0.,  nan,   0.,   5.,   0.,   0.,   5.,   2.,
#          5.,   5.,   2.,   4.,   5.,   5.,   3.,  40.,   5.,   5.,   5.,
#          4.,   5.,   5.,   5.,   0.,   5.,   0.,   5.,   5.,   0.,   3.,
#          4.,  48.,   0.,   5.,   6.,   3.,   5.,   3.,   5.,   6.,   5.,
# %% [markdown]
# ## Role

# %%
res_company_role = analyst.summarize_company_role()
pprint(res_company_role)
# Out:
# {'role_level': {'Career': 112,
#                 'Developing': 61,
#                 'Director/VP': 65,
#                 'Entry': 26,
#                 'Executive': 44,
#                 'Expert': 91,
#                 'Manager': 92,
#                 'Senior': 167,
#                 '_tot_': 658},
#  'role_prev_industries': {'No': 217,
#                           'Yes, in a different role': 187,
#                           'Yes, in a similar role': 254,
#                           '_tot_': 658},
#  'role_prev_role_list': ['Distinguished Member of Technical Staff, Design for '
#                          'Reliability',
#                          'Administrative Assistant',
#                          'product manger',
#                          'Machine Design Engineer',
#                          'Mechanical Engineer - Turbine Airfoils',
#                          'Investment Analyst',
#                          'Product development - body exterior',
#                          'Director of R&D',
#                          'Simulation engineer',
#                          'Automotive engineering for autonomous vehicles',
#                          'Senior Scientist',
#                          'project manager',
#                          'Instrumentation Engineer',
#                          'Patent Analyst',
#                          'Electrical Grid engineer',
#                          'Software Engineer',
#                          'Applications Engineer',
#                          'Scientist',
#                          'R&D in polymers industry',
#                          'Electronics manufacturing industry',
#                          'Senior Sourcing Manager',
#                          'Business Development Manager',
#                          'Senior Engineer',
#                          'Senior Materials Engineer',
#                          'Chemicals',
#                          'Laboratory Scientist',
#                          'engineer',
#                          'Metrology engineer',
#                          'solar expert',
#                          'Materials Scientist',
#                          'Automotive supplier analyst',
#                          'Science education and outreach',
#                          'Software engineer',
#                          'Intern for fuel cell manufacturing, graduate student',
#                          'I had many roles',
#                          'R&D',
#                          'Technical Lead Engineer',
#                          'Product Management',
#                          'Drone',
#                          'Pharmaceutical',
#                          'Consultant',
#                          'Teacher',
#                          'Total quality management',
#                          'Engineer',
#                          'Software development engineer',
#                          'Climate Communication Specialist',
#                          'Consultant',
#                          'Head of b2g',
#                          'Strategy Consultant',
#                          'Postdoctoral Research Associate',
#                          'CAM manufacturing R&D',
#                          'Electrical Engineer',
#                          'Lab technician',
#                          'Design Engineer',
#                          'Engineering Consulting',
#                          'Chartered Accountant Analyst',
#                          'Solar Industry',
#                          'Researcher',
#                          'research engineer',
#                          'Chemist',
#                          'Pulsed Plasma chemical vapor deposition on goose '
#                          'down feathers for Patagonia. manufacturing engineer, '
#                          'Semiconductor equipment, artificial heart valves, '
#                          'rock concert lighting, CNC machining.',
#                          'Wind industry',
#                          'Warehouse Technician',
#                          'Telecom Consultant',
#                          'Electrochemical expert',
#                          'Assistant Professor',
#                          'Project Manager, Software Developer',
#                          'Water chemistry',
#                          'inside sales',
#                          'Battery Engineer',
#                          'production engineer',
#                          'Manufacturing Engineer',
#                          'Research Scientist',
#                          'Researcher',
#                          'Research Scientist',
#                          'Mechanical Engineering',
#                          'Fire Officer',
#                          'Sr. Technical Lead (Development)',
#                          'Materials',
#                          'Battery Engineer',
#                          'Automotive design and Validation engineer',
#                          'Senior Graduate Student Researcher (Engineer & '
#                          'Consultant) / PhD student in Taiwan',
#                          'Quality and Campaign Prevention Supervisor',
#                          'University researcher',
#                          'Sr Product specialist',
#                          'Product Line Manager',
#                          'Maintenance Engineer',
#                          'wave energy developer',
#                          'Technical Sales Manager',
#                          'Technical Applications Engineer/ R&D Chemist',
#                          'Sales',
#                          'Defence',
#                          'IC verification',
#                          'Battery and Power systems analyst',
#                          'Process Engineer',
#                          'Consultant; Engineer',
#                          'semiconductor process engineer',
#                          'Climate Change Officer in local government',
#                          'IT Management and PM Management',
#                          'Principal Scientist',
#                          'Biologist',
#                          'Corrosion engineer',
#                          'COO battery co in China, GM battery co in Canada, GM '
#                          'critical communications co in Canada',
#                          'North American Manager',
#                          'R&D at battery startup',
#                          'Manufacturing',
#                          'Research Scientist, Process Engineer',
#                          'Project management, Investor, BD',
#                          'Researcher and Data Scientist',
#                          'Sales and Marketing of Electronic Test equipment',
#                          'Maintenance engineer',
#                          'Industrial Design',
#                          'University lecturer and researcher',
#                          'Aircraft Maintenance Engineer',
#                          'Oil & lubricants scientist',
#                          'Data anotator',
#                          'Account Manager, Product Manager, Project Manager, '
#                          'Process Engineer',
#                          'Sales Manager',
#                          'Product Support Engineer',
#                          'General Manager',
#                          'CEO',
#                          'Process Engineer',
#                          'Researcher',
#                          'Staff Cell Engineer',
#                          'Program Manager',
#                          'Consultant',
#                          'Technology specialist Sodium Chlorate',
#                          'RUBBER COMPANY',
#                          'researcher / manager in a non-profit',
#                          'Automotive',
#                          'Consultant',
#                          'Key Account Manager',
#                          'R&D',
#                          'Practise Manager Project Services',
#                          'Fixed-term researcher',
#                          'Engineer in electronics',
#                          'Metals',
#                          'Major Account Executive',
#                          'project leader',
#                          'Key Account Manager',
#                          'Performance engineer in gas turbines',
#                          '3D printing internship',
#                          'Associate Professor',
#                          'lubricants',
#                          'Product Line Manager',
#                          'Marketing',
#                          'Senior Scientist',
#                          'R&D Engineer',
#                          'Innovation manager',
#                          'Mechanical Design Engineering',
#                          'R&D technical analyst, Project leader',
#                          'Test Engineer',
#                          'Soldier',
#                          'academic and industrial R&D in the field of '
#                          'catalysis',
#                          'Construction',
#                          'Business development manager',
#                          'Educator',
#                          'Project Managament in the automotive industry',
#                          'Composite Materials Engineer',
#                          'Project Manager',
#                          'Contact cleaning equipment',
#                          'Process Engineer in pharmaceuticals',
#                          'Senior Researcher',
#                          'Builder',
#                          'Director of Sales & Marketing for Specialty Papers '
#                          'Division of GP',
#                          'Chemical Process Engineer',
#                          'ICT Test Enginner; project engineer',
#                          'VP Business Development and Technical Manager',
#                          'R&D Engineer, Solid Oxide Fuel Cells',
#                          'designer',
#                          'M&A',
#                          'Battery Test Engineer',
#                          'Technical Manager in medical devices. Manager of '
#                          'Space projects in earth obervation. Senior DSP '
#                          'design in semiconductor industry. Signal Processing '
#                          'and Communications Engineer',
#                          'Repair and maintenance supervisor',
#                          'R&D personal care',
#                          'Marketing Manager',
#                          'Consulting'],
#  'role_role': {'Advisory': 1,
#                'Analysis': 1,
#                'Communications': 1,
#                'Consultation': 1,
#                'Data Analysis': 2,
#                'Diagnosis and repair': 1,
#                'Education/Training': 1,
#                'Engineering and design': 355,
#                'Environment': 1,
#                'Facilities': 40,
#                'Finance': 52,
#                'FuSa Analysis': 1,
#                'FuSa Audits & Assessment': 1,
#                'FuSa Concepts': 1,
#                'Fundraising': 2,
#                'Geoscience technical and field work': 1,
#                'IT infrastructure': 22,
#                'Investor': 47,
#                'Legal': 37,
#                'Managing people': 207,
#                'Managing projects or programs': 289,
#                'Manufacturing and production': 107,
#                'Marketing': 107,
#                'New product introduction (NPI)': 158,
#                'Product design': 153,
#                'Quality': 121,
#                'R+D': 1,
#                'Recruiting': 79,
#                'Recruitment': 1,
#                'Research and development': 364,
#                'Safety & Compliance': 1,
#                'Safety Architecture & Design Definition': 1,
#                'Safety Case creation': 1,
#                'Safety and Training': 1,
#                'Sales and services': 122,
#                'Software development': 68,
#                'Software integration': 47,
#                'Stakeholder Technical Management': 1,
#                'Strategy and planning': 205,
#                'Supply chain': 90,
#                'TECHNOLOGY MONITORING': 1,
#                'Technical writing for industry publications': 1,
#                'Testing and validation': 229,
#                '_tot_': 660,
#                'administration': 1,
#                'costing': 1,
#                'market research': 1,
#                'partnerships': 1,
#                'public policy': 1,
#                'teaching': 1},
#  'role_title_list': ['Manager, R&D',
#                      'Design for Reliability',
#                      'Manager',
#                      'battery design release engineer',
#                      'Senior Battery Engineer',
#                      'Production Team Member',
#                      'post doctoral research associate',
#                      'Principal Engineer',
#                      'Asst. General Manager',
#                      'Research assistant',
#                      'Manager, Strategy and Corporate Development',
#                      'Content Manager',
#                      'Operations Supervisor',
#                      'Sales Director',
#                      'Engineering Consultant',
#                      'Associate Scientist',
#                      'Development Engineer',
#                      'BATTERY FIELD SYSTEMS ENGINEER',
#                      'Manager Consultant',
#                      'Principal Engineer',
#                      'Director',
#                      'Business development manager',
#                      'Electrolyte Scientist',
#                      'Senior Engineer',
#                      'Chief Technology Officer',
#                      'Director',
#                      'Staff Engineer',
#                      'Scientist',
#                      'Engineer',
#                      'Senior engineer',
#                      'System engineer',
#                      'Business development',
#                      'Algorithms engineer',
#                      'Commercial',
#                      'Director of R&D',
#                      'Senior Scientist',
#                      'Senior Application Engineer',
#                      'sales engineer',
#                      'Senior Engineer',
#                      'industrial engineer',
#                      'Senior Material Engineer',
#                      'Business Development',
#                      'Founder',
#                      'VP of Engineering',
#                      'Head of Growth Marketing',
#                      'Research Engineer',
#                      'CEO',
#                      'Principal Process Engineer',
#                      'Battery Materials Development Researcher',
#                      'Hybrid/BESS energy analyst',
#                      'Senior Software Engineer',
#                      'Product Manager',
#                      'Business Development Director',
#                      'VP R&D',
#                      'test engineer',
#                      'Hardware Developer',
#                      'CEO',
#                      'Manager',
#                      'Senior R&D Scientist',
#                      'Engineering Manager',
#                      'Senior Consultant',
#                      'Technical Solution Engineer',
#                      'CTO',
#                      'Staff Engineer',
#                      'CEO',
#                      'Lead Battery Scientist',
#                      'Deputy manager Battery operations',
#                      'Senior Director of Procurement',
#                      'Director of Member Success',
#                      'Manager',
#                      'Engineer',
#                      'Test & Validation Engineer',
#                      'Materials Engineer',
#                      'Technical Program Manager',
#                      'Field Application Engineer',
#                      'Senior Fellow',
#                      'Senior battery technology scientist',
#                      'post doc',
#                      'Lead Engineer',
#                      'Sr. Staff Engineer',
#                      'Process engineer',
#                      'Director of Marketing & Communications',
#                      'Battery algorithm development',
#                      'co-CEO',
#                      'ceo',
#                      'Senior scientist',
#                      'Battery Research Scientist',
#                      'Staff Software Engineer',
#                      'Energy market specialist',
#                      'Smts',
#                      'mechanical design engineer',
#                      'Research Associate',
#                      'Principal',
#                      'President and CTO',
#                      'Senior Product Scientist',
#                      'Director of Business Development',
#                      'Battery Simulation Engineer',
#                      'Director of Operations',
#                      'MD',
#                      'battery engineer',
#                      'Electrochemical Engineer',
#                      'Senior ATE System Technical Manager',
#                      'Research scientist',
#                      'Senior Vice President and Co-Founder',
#                      'Director of Research',
#                      'Sr. Director of R&D',
#                      'Test Engineer',
#                      'Engineering Manager',
#                      'Technical Marketing Consultant',
#                      'Senior Engineer',
#                      'Senior researcher',
#                      'Senior mechanical engineer',
#                      'Battery Engineer',
#                      'Principal',
#                      'Lead Polymer Scientist',
#                      'Principal Scientist',
#                      'Founder',
#                      'SCIENTIST',
#                      'Assistant Manager',
#                      'Staff R&D Scientist',
#                      'Advisor',
#                      'Engineer',
#                      'Production incharge',
#                      'Senior Engineer, R&D Operations',
#                      'R&D Manager',
#                      'ASSISTANT ENGINEER DESIGN',
#                      'Principal Engineer',
#                      'technical expert',
#                      'Director of Product Management',
#                      'Director, Product Management',
#                      'Head of Costing',
#                      'battery system department Manager',
#                      'Senior Simulation Engineer',
#                      'Service Operations coordinator',
#                      'Cell Design Engineer',
#                      'Executive Director',
#                      'Senior Engineer II',
#                      'Industrial Research Analyst',
#                      'Instructor',
#                      'Lead Chemist- Lab Manager',
#                      'Staff Engineer',
#                      'Director of Engineering',
#                      'R&D Engineer',
#                      'Development Engineer',
#                      'Senior product manager',
#                      'R&D scientist',
#                      'Construction director',
#                      'Senior cell development engineer',
#                      'Project Engineer',
#                      'Battery engineering specialist',
#                      'Head of division',
#                      'Skills director',
#                      'Development Engineer',
#                      'Manager',
#                      'Battery Process Engineer',
#                      'Analyst',
#                      'Global Sales Manager - Technical Sales Engineer',
#                      'Senior manager, business development',
#                      'Battery safety lead engineer',
#                      'project manager',
#                      'Head of Battery Engineering',
#                      'Sr. Technical Project Manager, Battery Engineering',
#                      'Technica Fellow - Principal Controls Engineer',
#                      'Cell Design Engineer',
#                      'Marketing Intelligence Manager',
#                      'Manager',
#                      'scientist',
#                      'Test manager',
#                      'Cell Process Development',
#                      'Business Development Manager',
#                      'Chief Product Officer',
#                      'Battery management systems',
#                      'Project Engineer',
#                      'Project Manager',
#                      'Corporate Development Analyst',
#                      'Product Stewardship Specialist',
#                      'Project Engineer',
#                      'Key Account Manager',
#                      'Techonlogy Manager',
#                      'EUROPEAN SALES DIRECTOR',
#                      'Sales Manager',
#                      'Engineer',
#                      'technical leader',
#                      'Senior Executive',
#                      'Sales Operations Director',
#                      'Materials Scientist',
#                      'Li-ION HV Battery Pack Process and Production Leader',
#                      'Scientist/Project Manager',
#                      'Development of new materials for electrodes of Li-ion '
#                      'batteries',
#                      'CEO',
#                      'project development',
#                      'R&D Scientist',
#                      'Application Scientist',
#                      'System Engineer',
#                      'technical fellow',
#                      'Consultant',
#                      'Manufacturing Engineer',
#                      'Research technician',
#                      'Senior Research Scientist -II - LFP',
#                      'Principal Analyst',
#                      'Business development manager',
#                      'Process Engineer',
#                      'Senior Research Scientist',
#                      'Senior Engineer',
#                      'Staff Battery Cell Design Engineer',
#                      'Energy Storage Unit Manager',
#                      'Logistics technical specialist',
#                      'BESS Product manager',
#                      'Quality control lead',
#                      'Energy Trainer',
#                      'Lead Engineer',
#                      'Senior Battery Scientist',
#                      'Product Owner',
#                      'BDM battery/epower',
#                      'Sales Engineer',
#                      'Business Development',
#                      'Senior Scientist',
#                      'Senior Program Manager',
#                      'general manager costing department',
#                      'Business Development',
#                      'Research Engineer - Testing and Validation',
#                      'Business Development Manager',
#                      'Embedded Hardware Engineer',
#                      'Scientist',
#                      'Business development',
#                      'Senior algorithms engineer',
#                      'Senior Project Lead Engineer',
#                      'Director',
#                      'Manager New Analytical Techniques',
#                      'Research Engineer',
#                      'Research Scientist',
#                      'R&D Engineer',
#                      'Battery Project Engineer',
#                      'Technical Principal',
#                      'Senior Materials Scientist',
#                      'Chief Engineer',
#                      'Sr. Engineering Manager',
#                      'Manufacturing associate',
#                      'Associate Scientist',
#                      'Principal',
#                      'Advanced failure analysis engineer',
#                      'Battery Engineer',
#                      'Battery Engineer - Formation & Test',
#                      'Senior Engineer',
#                      'Consultant Engineer & Trainer',
#                      'Principal Functional Safety Engineer II',
#                      'Staff Product Manager',
#                      'EHS Manager',
#                      'Battery Modeling Engineer',
#                      'Program Manager, Battery',
#                      'Senior sales manager',
#                      'VP - Research',
#                      'Product and Process development Lead - Battery '
#                      'Manufacturing',
#                      'Sr. Manager, Battery Supplier Development and Quality',
#                      'Battery RnD Engineer',
#                      'Solid State Battery Team Leader',
#                      'R&D',
#                      'Program Manager',
#                      'Product engineer - electrodes',
#                      'Sr mechanical engineer',
#                      'Project design engineer',
#                      'Education and Training Director',
#                      'Product Manager',
#                      'Senior Business Development Manager',
#                      'Sr engineer',
#                      'Electrical Engineer',
#                      'Senior Engineer',
#                      'Manager',
#                      'Business Development Manager',
#                      'Associate Professor',
#                      'Systems Engineer',
#                      'Contracts Leader',
#                      'VP Business Development',
#                      'CTO',
#                      'Reliability Engineer',
#                      'Field Application Engineer',
#                      'R&D Scientist',
#                      'Director of Technology',
#                      'Senior Manager, R&D',
#                      'President',
#                      'Lead Engineer BESS',
#                      'Sr Talent Acquisition Specialist',
#                      'Test and validation engineer',
#                      'Market Quality Specialist',
#                      'Senior Supplier Capacity Manager',
#                      'Senior Research Scientist',
#                      'Account manager',
#                      'Technology Planning Manager',
#                      'Thermal Battery Abuse Test Technician',
#                      'CTO',
#                      'System Architecture Engineer',
#                      'Business Development',
#                      'Sr. Scientist',
#                      'senior chemical engineer',
#                      'EHS & Compliance Manager',
#                      'Development Engineer',
#                      'Process Engineer III',
#                      'Researcher',
#                      'Project Manager for new factory build projects',
#                      'Development Engineer',
#                      'senior process development engineer',
#                      'Junior Data Scientist',
#                      'BMS Algorithm Developer',
#                      'Sn. Scientist',
#                      'After Sales Service Engineer',
#                      'Associate Process Engineer',
#                      'Principal engineer',
#                      'Lead Scientist',
#                      'Operations Manager',
#                      'VP R&D',
#                      'Lab Manager',
#                      'Director HR',
#                      'Chief Commercial Officer',
#                      'Director',
#                      'CEO, business development',
#                      'Marketing Communications Manager',
#                      'Advanced failure analysis engineer',
#                      'Assistant Professor',
#                      'Technical Sales Engineer 2',
#                      'Marketing',
#                      'Lead Engineer',
#                      'Sr Director Business Operations',
#                      'Principal Engineer product safety',
#                      'Business Development Manager',
#                      'Senior Engineer',
#                      'Lead Advisor',
#                      'Founder, CEO',
#                      'Senior Manager Battery Design Engineering',
#                      'Sr battery scientist',
#                      'Manager / Principle Scientist',
#                      'Senior Battery Lab Technician',
#                      'Program manager',
#                      'Senior Battery Systems Engineer',
#                      'Sr. BD manager',
#                      'Staff Performance Engineer',
#                      'Quality Manager',
#                      'Content Developer and Trainer',
#                      'Engineer',
#                      'Associate cell engineer',
#                      'GM Geology and Mining',
#                      'Manufacturing engineer',
#                      'sales coach',
#                      'Project Research Engineer',
#                      'Professor of Practice',
#                      'Assistant manager r&d',
#                      'R&D Engineer',
#                      'Coordinator in R&D',
#                      'researcher',
#                      'Shop lead',
#                      'Design',
#                      'CEO',
#                      'Battery Safety Specialist',
#                      'R&D Manager',
#                      'Process Development',
#                      'Global Commodity Lead',
#                      'COO',
#                      'analytical testing',
#                      'Principal engineer battery modelling',
#                      'Junior Battery Engineer',
#                      'Innovation Analyst',
#                      'Modelling Engineer',
#                      'Business Development Manager',
#                      'Team Lead',
#                      'Global Product Manager',
#                      'Managing Director',
#                      'Recruitment Consultant',
#                      'Head of battery test and diagnostics',
#                      'Manager R&D',
#                      'Major Project Director',
#                      'Senior Fellow',
#                      'Strategy Manager',
#                      'Formation Technology Leader',
#                      'Director -Co Founder',
#                      'Researcher',
#                      'Research Scientist',
#                      'Area Sales Manager',
#                      'Lead Engineer',
#                      'Consultant',
#                      'Production Engineer',
#                      'Battery engineer III',
#                      'Cell Engineer',
#                      'Staff Product Manager',
#                      'President',
#                      'CTO',
#                      'Senior strategist',
#                      'Corporate Development',
#                      'Development Engineer',
#                      'SCIENTIFIC OFFICER',
#                      'CTO',
#                      'Process Engineering',
#                      'Senior Researcher',
#                      'Senior Specialist Engineer',
#                      'Battery materials engineer',
#                      'Research Associate',
#                      'Senior researcher',
#                      'Manager Technology',
#                      'Managing Director',
#                      'Global Director Talent Acquisition & Talent Integration',
#                      'Sr. Controls Engineer',
#                      'Staff Engineer',
#                      'Senior Engineer',
#                      'Geology Consultant & Founder',
#                      'Procurement Manager',
#                      'Battery Pack Lead DRE',
#                      'North American Sales Manager',
#                      'Marketing and Technical Service Manager',
#                      'Recruiting Consultant',
#                      'Sr Talent Acquisition Partner',
#                      'Co-Founder and Group Managing Director',
#                      'Engineering Manager- Fuel & New Energies',
#                      'Manager',
#                      'Data Analyst',
#                      'Technology & IP Analyst',
#                      'Senior Project manager',
#                      'battery modelling and simulation engineer',
#                      'project and global category buyer',
#                      'Battery development engineer',
#                      'Account Manager',
#                      'Sr. R&D Manager',
#                      'VP Business Development',
#                      'Scientist',
#                      'Marketing Director, Sales Manager',
#                      'senior- product establishment',
#                      'Research Associate',
#                      'Battery leader',
#                      'Battery Expert',
#                      'Junior Battery Engineer',
#                      'Finance director',
#                      'Senior Director Business Development',
#                      'Research Associate',
#                      'Project Manager',
#                      'project manager spezialiced',
#                      'Head of engineering',
#                      'Head of Product Management, VP Product',
#                      'Renewable Energy Consultant',
#                      'Managing director',
#                      'Project Manager and Senior Research and Development',
#                      'CTO',
#                      'Market Quality Specialist',
#                      'R&D Manager',
#                      'General Manager',
#                      'Material Engineering Technician',
#                      'Business Development',
#                      'Research Fellow',
#                      'Senior Business Development Manager',
#                      'Laboratory Instructor',
#                      'Senior research',
#                      'senior researcher',
#                      'Supervisor',
#                      'Intern',
#                      'Application Manager',
#                      'Manager process engineering',
#                      'professor',
#                      'Battery Mechanical Design Engineer',
#                      'Vehicle Engineer',
#                      'Business analyst',
#                      'Manager Material Science R&D',
#                      'Senior battery management system and general power '
#                      'electronic hardware design engineer',
#                      'Senior Battery System Engineer',
#                      'Partner',
#                      'Battery Consultant',
#                      'Head of partnerships, benchmark and public fundings',
#                      'Head of Battery Materials',
#                      'Managing Director',
#                      'Major Projects Director',
#                      'Lab Manager',
#                      'Leading the market development team in EMEA',
#                      'Team Leader',
#                      'cmo',
#                      'Senior Staff Field Applications Engineer',
#                      'Battery Algorithm',
#                      'Principal Scientist',
#                      'Sales Leader',
#                      'Director Business Development',
#                      'MD, CEMO',
#                      'Cell design engineer',
#                      'Business developer',
#                      'Sr Business Development Manager',
#                      'Electrical Systems Manager',
#                      'Battery Systems Engineer',
#                      'CTO',
#                      'Research scientist',
#                      'Product',
#                      'Product manager',
#                      'New process implementation engineer',
#                      'Founder, Chief Strategy Officer',
#                      'Account Manager',
#                      'Senior Mechanical Engineer',
#                      'Supply Chain Manager',
#                      'Director',
#                      'Sales Engineer',
#                      'Vice President',
#                      'VP R&D',
#                      'Director, Renewable Energy Solutions NA',
#                      'COO',
#                      'Staff Reliability Engineer',
#                      'Sr. Mechanical Engineer - Battery',
#                      'Materials Analyst',
#                      'Battery Data Analyst',
#                      'Team leader',
#                      'Software Engineer',
#                      'Testing Engineer',
#                      'Purchasing Manager',
#                      'R and D Project Chemist',
#                      'BD manager',
#                      'Battery Scientist II',
#                      'Business Development Manager',
#                      'Senior Research Scientist2',
#                      'Data Engineer',
#                      'Senior Test Engineer',
#                      'Cell Test Engineer',
#                      'Manager Quality Labs',
#                      'Research Scientist',
#                      'Test Engineer',
#                      'Sr materials engineer',
#                      'Battery Safety Engineer',
#                      'Sr scientist',
#                      'Founder',
#                      'Electrochemical Engineer',
#                      'Program Manager',
#                      'Test Manager',
#                      'Sales&Marketing',
#                      'Technology specialist',
#                      'Head of Engineering',
#                      'Solid State Battery Team Leader',
#                      'Senior Technical Manager, Charging Systems',
#                      'Senior Characterisation Engineer',
#                      'Principal',
#                      'Senior Data Scientist',
#                      'Ceo',
#                      'Head of Advanced Battery Separator Group',
#                      'Project Scientist',
#                      'Battery System Engineer',
#                      'Part Owner, business development, electrician',
#                      'Managing Director',
#                      'CTO',
#                      'Cell Manufacturing Engineer',
#                      'Associate Cell Engineer',
#                      'Research Engineer',
#                      'Process Engineer',
#                      'Senior test engineer',
#                      'Senior Director, BD',
#                      'Energy Solutions Application Engineer',
#                      'research scientist',
#                      'business head',
#                      'St. Cell Tech',
#                      'Cell & Process Engineer',
#                      'sales',
#                      'Staff Scientist',
#                      'R & D Manager',
#                      'Director',
#                      'Sales Manager',
#                      'Director R&D and Business Development',
#                      'Battery Test Operations Manager',
#                      'Head of Engineering',
#                      'R&D Team Leader',
#                      'Head of Business Development',
#                      'industrial product establishment',
#                      'Electrochemical Engineer',
#                      'Senior Mechanical Design Engineer',
#                      'no answer',
#                      'Chemist',
#                      'Research Engineer',
#                      'Principal Engineer',
#                      'Senior technical expert'],
#  'role_why_choose': {'Autonomy and independence': 156,
#                      'Career growth opportunities': 296,
#                      'Challenge and innovation': 396,
#                      'Competitive salary and benefits': 190,
#                      'Confidence in reported results': 1,
#                      'Desirable work location': 197,
#                      "Didn't have a choice. I love ev tech but very few jobs in recruiting. I'm lucky I have a job.": 1,
#                      'Due to there are less jobs': 1,
#                      'Employment': 2,
#                      'Entrepreneurship': 1,
#                      'Family reason': 1,
#                      'Female owned business': 1,
#                      'Founded the company': 1,
#                      'Founder': 1,
#                      'Had no choice. The site has been taken over': 1,
#                      'Hiring During COVID': 1,
#                      'Hybrid/remote work': 123,
#                      'I Co-founded the Company': 1,
#                      'I was previously unemployed': 1,
#                      'Job security': 99,
#                      'Laid off at a well paying start up company that makes electric trucks': 1,
#                      'Learning and skills development': 326,
#                      'Love for what I do': 1,
#                      'Love my job': 1,
#                      'Mentoring young professionals': 1,
#                      'My own company': 1,
#                      'Needed a job': 1,
#                      'New business line in existing co': 1,
#                      'New technology': 1,
#                      'OK salary': 1,
#                      'Own company': 1,
#                      'Passion': 1,
#                      'Passion for product': 1,
#                      'Really good benefits': 1,
#                      'Reputation in industry': 1,
#                      'Socially interesting environment': 1,
#                      'Sole director of own company': 1,
#                      'Sponsor work visa': 1,
#                      'Supportive team and environment': 200,
#                      'Sustainability and impact': 238,
#                      'This is my former company': 1,
#                      'To learn about funding early stage projects': 1,
#                      'Too old to get real job': 1,
#                      'Work-life balance': 189,
#                      '_tot_': 643,
#                      'development on earlier career': 1,
#                      'family heritage': 1,
#                      'hint. This current opportunity came in fast and was close to home': 1,
#                      'need of part time role': 1,
#                      'vans and SUVs.. hint': 1}}

# %%
plotter.make_bar_plot_from_dict(res_company_role['role_level'],
                                title='What is your current level?',
                                saveas='company_role_level.png'
)

plotter.make_bar_plot_from_dict(
    res_company_role['role_role'],
    title='What does your role involve?',
    saveas='company_role.png',
    num_elements=23,
    sorted=True
)

plotter.make_bar_plot_from_dict(
    res_company_role['role_why_choose'],
    title='Why did you choose your current role and company?',
    saveas='company_role_why_choose.png',
    num_elements=11,
    sorted=True
)

plotter.make_bar_plot_from_dict(
    utils.sort_dict(res_company_role['role_prev_industries'], by='keys', reverse=True),
    title='Have you previously worked in other industries?',
    saveas='company_role_previous_industries.png'
)

# %%
res_company_role['role_prev_role_list']
# Out:
# ['Distinguished Member of Technical Staff, Design for Reliability',
#  'Administrative Assistant',
#  'product manger',
#  'Machine Design Engineer',
#  'Mechanical Engineer - Turbine Airfoils',
#  'Investment Analyst',
#  'Product development - body exterior',
#  'Director of R&D',
#  'Simulation engineer',
#  'Automotive engineering for autonomous vehicles',
#  'Senior Scientist',
#  'project manager',
#  'Instrumentation Engineer',
#  'Patent Analyst',
#  'Electrical Grid engineer',
#  'Software Engineer',
#  'Applications Engineer',
#  'Scientist',
#  'R&D in polymers industry',
#  'Electronics manufacturing industry',
#  'Senior Sourcing Manager',
#  'Business Development Manager',
#  'Senior Engineer',
#  'Senior Materials Engineer',
#  'Chemicals',
#  'Laboratory Scientist',
#  'engineer',
#  'Metrology engineer',
#  'solar expert',
#  'Materials Scientist',
#  'Automotive supplier analyst',
#  'Science education and outreach',
#  'Software engineer',
#  'Intern for fuel cell manufacturing, graduate student',
#  'I had many roles',
#  'R&D',
#  'Technical Lead Engineer',
#  'Product Management',
#  'Drone',
#  'Pharmaceutical',
#  'Consultant',
#  'Teacher',
#  'Total quality management',
#  'Engineer',
#  'Software development engineer',
#  'Climate Communication Specialist',
#  'Consultant',
#  'Head of b2g',
#  'Strategy Consultant',
#  'Postdoctoral Research Associate',
#  'CAM manufacturing R&D',
#  'Electrical Engineer',
#  'Lab technician',
#  'Design Engineer',
#  'Engineering Consulting',
#  'Chartered Accountant Analyst',
#  'Solar Industry',
#  'Researcher',
#  'research engineer',
#  'Chemist',
#  'Pulsed Plasma chemical vapor deposition on goose down feathers for Patagonia. manufacturing engineer, Semiconductor equipment, artificial heart valves, rock concert lighting, CNC machining.',
#  'Wind industry',
#  'Warehouse Technician',
#  'Telecom Consultant',
#  'Electrochemical expert',
#  'Assistant Professor',
#  'Project Manager, Software Developer',
#  'Water chemistry',
#  'inside sales',
#  'Battery Engineer',
#  'production engineer',
#  'Manufacturing Engineer',
#  'Research Scientist',
#  'Researcher',
#  'Research Scientist',
#  'Mechanical Engineering',
#  'Fire Officer',
#  'Sr. Technical Lead (Development)',
#  'Materials',
#  'Battery Engineer',
#  'Automotive design and Validation engineer',
#  'Senior Graduate Student Researcher (Engineer & Consultant) / PhD student in Taiwan',
#  'Quality and Campaign Prevention Supervisor',
#  'University researcher',
#  'Sr Product specialist',
#  'Product Line Manager',
#  'Maintenance Engineer',
#  'wave energy developer',
#  'Technical Sales Manager',
#  'Technical Applications Engineer/ R&D Chemist',
#  'Sales',
#  'Defence',
#  'IC verification',
#  'Battery and Power systems analyst',
#  'Process Engineer',
#  'Consultant; Engineer',
#  'semiconductor process engineer',
#  'Climate Change Officer in local government',
#  'IT Management and PM Management',
#  'Principal Scientist',
#  'Biologist',
#  'Corrosion engineer',
#  'COO battery co in China, GM battery co in Canada, GM critical communications co in Canada',
#  'North American Manager',
#  'R&D at battery startup',
#  'Manufacturing',
#  'Research Scientist, Process Engineer',
#  'Project management, Investor, BD',
#  'Researcher and Data Scientist',
#  'Sales and Marketing of Electronic Test equipment',
#  'Maintenance engineer',
#  'Industrial Design',
#  'University lecturer and researcher',
#  'Aircraft Maintenance Engineer',
#  'Oil & lubricants scientist',
#  'Data anotator',
#  'Account Manager, Product Manager, Project Manager, Process Engineer',
#  'Sales Manager',
#  'Product Support Engineer',
#  'General Manager',
#  'CEO',
#  'Process Engineer',
#  'Researcher',
#  'Staff Cell Engineer',
#  'Program Manager',
#  'Consultant',
#  'Technology specialist Sodium Chlorate',
#  'RUBBER COMPANY',
#  'researcher / manager in a non-profit',
#  'Automotive',
#  'Consultant',
#  'Key Account Manager',
#  'R&D',
#  'Practise Manager Project Services',
#  'Fixed-term researcher',
#  'Engineer in electronics',
#  'Metals',
#  'Major Account Executive',
#  'project leader',
#  'Key Account Manager',
#  'Performance engineer in gas turbines',
#  '3D printing internship',
#  'Associate Professor',
#  'lubricants',
#  'Product Line Manager',
#  'Marketing',
#  'Senior Scientist',
#  'R&D Engineer',
#  'Innovation manager',
#  'Mechanical Design Engineering',
#  'R&D technical analyst, Project leader',
#  'Test Engineer',
#  'Soldier',
#  'academic and industrial R&D in the field of catalysis',
#  'Construction',
#  'Business development manager',
#  'Educator',
#  'Project Managament in the automotive industry',
#  'Composite Materials Engineer',
#  'Project Manager',
#  'Contact cleaning equipment',
#  'Process Engineer in pharmaceuticals',
#  'Senior Researcher',
#  'Builder',
#  'Director of Sales & Marketing for Specialty Papers Division of GP',
#  'Chemical Process Engineer',
#  'ICT Test Enginner; project engineer',
#  'VP Business Development and Technical Manager',
#  'R&D Engineer, Solid Oxide Fuel Cells',
#  'designer',
#  'M&A',
#  'Battery Test Engineer',
#  'Technical Manager in medical devices. Manager of Space projects in earth obervation. Senior DSP design in semiconductor industry. Signal Processing and Communications Engineer',
#  'Repair and maintenance supervisor',
#  'R&D personal care',
#  'Marketing Manager',
#  'Consulting']

# %% [markdown]
# ## Company Skills

# %%
res_company_skills = analyst.summarize_company_skills()
pprint(res_company_skills)
# Out:
# {'barriers_to_talent_list': ['Startups are fighting headwinds in terms of '
#                              'market and investment, startup culture is not '
#                              'always the most professional, incumbents are '
#                              'hard to displace',
#                              'Location   (Michigan? no!)',
#                              'Perception, Recruiters, Judgement',
#                              'location, the potential of company or program to '
#                              'succeed, team environment,',
#                              'Lack of training programs specifically for the '
#                              'battery industry, lack of awareness of the '
#                              'battery industry',
#                              'Lack of Specialised People; Large Growth in Job '
#                              'Demand; Cyclic Industry',
#                              'no knowledge of tech',
#                              'Lack of Innovative Thinking & Patience',
#                              'Unwillingness to consider transferable skills',
#                              'Not many people with such knowledge.',
#                              'competition from higher paying companies; '
#                              'physical location constraints',
#                              'not much battery manufacturing in the US; '
#                              'electrochemistry is hard unless you are formally '
#                              'trained in it',
#                              'Entreprise projects',
#                              'Not real qualified engineers on the battery '
#                              'technology and understanding of the systems',
#                              'Boring field',
#                              'Too much flux in start up companies related to '
#                              'battery industry',
#                              'Talents are abundant these days，positions are '
#                              'scarce',
#                              'Salary',
#                              'lack of trained professional',
#                              'lack of qualified workers',
#                              'Difficult skillset',
#                              'Increased Training, Better Career Opportunities, '
#                              'More employment benefits',
#                              'Not enough candidates; Not good reach; Not '
#                              'enough material to prepare',
#                              'Knowledge, relevant skills, competitive '
#                              'compensation',
#                              'availability of talent',
#                              'Cyclical growing and collapsing market',
#                              'Outreach',
#                              'Availability of talent ready to hit the ground '
#                              'running into a role (ie sufficient area '
#                              'knowledge)',
#                              'qualified and independent thinkers',
#                              'Compensation; location',
#                              'Compensation; Work Life Balance; Risk',
#                              'experience; discipline; degree',
#                              'no prior school or college education',
#                              'Salary ; benefits ; contract length',
#                              'risk/lack of security, compensation, lack of '
#                              'skilled talent',
#                              'Training experience and exposure',
#                              'Knowledge of the industry 1, Stage of market 2,',
#                              'Lack of schooling; industry knowledge',
#                              'Practical skills and understanding safety '
#                              'challenges',
#                              'Lack of job security. Competitive employment '
#                              'market. Lack of awareness to the indusrry',
#                              '1. Enough people coming through appropriate '
#                              'educational experience, 2. Citizenship, Visa’s '
#                              '3. Uneven funding',
#                              'compensation; good career path; location',
#                              "The hiring teams don't know what level of "
#                              "experience they're looking for. The interviews I "
#                              'gave in the Spring 2024 quarter- people in my '
#                              'hiring team were being laid off AS i was '
#                              'interviewing at the same time',
#                              'Education and training gaps, competition among '
#                              'industry, specialised knowledge',
#                              "We can't afford to hire",
#                              'Location, salary',
#                              'Overspecialized in degrees',
#                              'academic elitism and chronyism',
#                              'Compensation, Location',
#                              'Lack of resources for internal growth and '
#                              'development once hired, Inability for small '
#                              'startups to provide reasonable benefits, Lack of '
#                              'training in certain disciplines',
#                              'Availability of people',
#                              'Geographical concentration of certain talents',
#                              'location, limited pool of candidates, lack of '
#                              'cross functional skills',
#                              'Lack of industry knowledge, pay, candidates work '
#                              'ethic',
#                              'finding the right applicants, elitism & bias',
#                              'Electrical knowledge; Battery safety; Analytics '
#                              'thinking',
#                              'Lack of good talent, Salary budget',
#                              'Funding',
#                              'Compensation; requirement to travel',
#                              'not enough opportunities, companies are too few',
#                              '1) Lack of battery education',
#                              'Location; Lack of training programs; '
#                              'Compensation',
#                              'Funding in our case. Hard to hire talent too as '
#                              'a small company as talent is attracted to bigger '
#                              'companies.',
#                              'Employer unwillingness to compensate skilled '
#                              'candidates and train prospective candidates',
#                              'Lack of availability',
#                              'na',
#                              'Competition; Training; Location',
#                              'gap between industry & academia; lack of folks '
#                              'with both technical & business background; lack '
#                              'of focus on manufacturing prowess and '
#                              'scalability',
#                              'Barrier 1 - unwillingness to recognize battery '
#                              'experience outside chemistry of interest;',
#                              'skills, knowledge and communication skills',
#                              'Scarcity of professionals; Salary (country '
#                              'specific)',
#                              'Competitive Pay',
#                              'Low expertise in the field',
#                              'Lack of specialists, Salary expectations, '
#                              'Competition with big players',
#                              'nascent talent pool relying on transferable '
#                              'skills',
#                              'Skill; Knowledge of electrochemistry',
#                              'competitive salary,',
#                              'looking for prior battery experience instead of '
#                              'transferable skills',
#                              'Work experience, different scales in academic '
#                              'and industry, managerial skills',
#                              'depth in staff with experience 1, not enough '
#                              'STEM background 2, inflexibility 3',
#                              'Idk',
#                              'location; compensation',
#                              'Poor job descriptions; lack of battery '
#                              'fundamentals skills; knowledgeable balance '
#                              'between chemistry & engineering skills',
#                              'lack of qualified people; inability for start-up '
#                              'to pay competitive salaries; location',
#                              'industry knowledge',
#                              'market price;geographic location;skillset',
#                              'hands on experience; knowledge',
#                              'Lack of hands on practical experience in a lab; '
#                              'impractical spreadsheet math and planning',
#                              'The talents themselves',
#                              'visa sponsorship',
#                              'Money, and work-life balance... The lack of it '
#                              'that is, at a small companies and startups, '
#                              "kills recruitment if you don't offer large "
#                              'salaries and substantial benefits.',
#                              'hands on knowledge; quality assurance norms',
#                              'Geographic pay differences; centralized '
#                              'manufacturing/R&D requires skilled talent to '
#                              'move for the job',
#                              'limited number of educated individual',
#                              'Barrier 1: relevent battery skills and '
#                              'knowledge; barrier 2: huge hiring competition '
#                              'for a small talent pool; barrier 3: hiring and '
#                              'lay-off fluctuations within the industry',
#                              'Salary expectations; skills set; visa '
#                              'requirement',
#                              'Compensation package',
#                              'Connection, Communication, Competitive mMarkets',
#                              'Not competitive pay, high risk of layoffs, '
#                              'industry complexity',
#                              'available talent',
#                              'Lack of experienced candidates',
#                              '"Stable companies"; "stable industry"; '
#                              '"fragmented technical knowledge"',
#                              'Location, Compensation',
#                              'lack of quality students',
#                              'lack of on the job experience',
#                              'New field',
#                              'Cost',
#                              'Talent Scouting, Undervalued Role, Overhyped '
#                              'Expectations',
#                              'Politics in company,favorism, partiality',
#                              'Mismatch in expectations, companies being too '
#                              'greedy and elitist',
#                              'Battery industry experience',
#                              'ACADEMICS',
#                              'Small pool of experienced and competent '
#                              'engineers',
#                              'availability',
#                              'Compensation, scarcity of experienced talent',
#                              'location; compensation; missing of technical '
#                              'background',
#                              'Lack of Talent pool',
#                              'In my Country evert talented or experienced '
#                              'person left the Country',
#                              'Talent shortage',
#                              'strong semiconductor industry, lower priority '
#                              'due to weak battery industry in last decade',
#                              'Companies lacking competitive salaries, not '
#                              'enough kids going to trade schools and '
#                              'assumption most of these roles should be held by '
#                              'men',
#                              'Concrete experience (evidence of capability / '
#                              'demonstrable experience)',
#                              'high salary, lack of skilled people',
#                              'Package; Resource Support; Team Support',
#                              'No opinion',
#                              'New tech;',
#                              'Prior Knowledge',
#                              'Training, hands on developmental programs',
#                              'People not trained well, or not trained at all. '
#                              'People too narrow minded and not willing to '
#                              'learn.',
#                              '"Location;Competition for talent;Future '
#                              'perspective in relation to political and '
#                              'business commitment"',
#                              'Missing hands on experience',
#                              'salaries, relocation costs, opportunities for '
#                              'continuous improvement',
#                              'No local experienced people',
#                              'Compensation; work scope; maturity of the '
#                              'company',
#                              'Bad interviewing/ automated resume screening',
#                              'There’s a lot of ego. There’s a lot of '
#                              'discrimination against people who are not cis '
#                              'het males, there’s a lot of people who PhDs who '
#                              'have narrow expertise but lack the self '
#                              'awareness to admit they will always be learning '
#                              'something new,',
#                              'Lack of knowledge on the industry; lack of STEM '
#                              'professionals',
#                              'Lack of sufficient talent available',
#                              'Lack or people, lack of people with needed '
#                              'skills',
#                              'For technical roles unwillingness to consider '
#                              'related experience; work location; “battery '
#                              'bubble” and economic conditions',
#                              'Lack of industry experience; fledgling '
#                              'ecosystem; poor quality hiring agencies',
#                              'Shortage of candidates with academic preparation '
#                              'in chemical engineering.  Shortage of people '
#                              'with interest in marketing, who are also '
#                              'qualified in chemical engineering & economic '
#                              'analysis.',
#                              'Not enough candidates',
#                              'Companies looking for very specific skills and '
#                              'past experience in cell/battery, not realizing '
#                              'that many of the skills are transferable from '
#                              'other industries and battery/cell specific '
#                              'knowledge can be learnt on the job.',
#                              'Lack of established battery manufacturing '
#                              'industry',
#                              'Not as popular background to pull from compared '
#                              'to traditional areas',
#                              'Not being open minded enough to hire from '
#                              'adjacent industries',
#                              'lack of experience talent, from academia to '
#                              'industry, robotics scale-up manufacturing',
#                              'Lack of experienced candidates; Automotive '
#                              'companies suck up all the talent; New discipline '
#                              "that candidates don't actively consider",
#                              "don't know",
#                              'Lack of electrochemistry modules at university; '
#                              'Emerging industry lack of internships ;',
#                              'Salary',
#                              'Candidate supply and demand,',
#                              'location of office',
#                              'Experience',
#                              'Pipeline',
#                              'There is lack of skilled and qualified engineers '
#                              'and other roles in Poland.',
#                              'Not enough experienced people',
#                              'small talent pool; lack of gender diversity in '
#                              'the talent pool (need more female engineers)',
#                              'competitive landscape, location of office, fast '
#                              'growing industry without enough people with '
#                              'appropriate experience',
#                              'Existing preconceptions; "old boys club" '
#                              'mentality; New Chemistries vs Li-ion outlook',
#                              'Compensation; Education/Training',
#                              "Lack of marketing, lack of large 'well known' "
#                              'companies, global sentiment around the '
#                              "industry's role in the future",
#                              'poor education, lack of jobs, low pay',
#                              'Basic Foundation, Analytical skills',
#                              'Young sector in EU, fast expanding, resulting in '
#                              'large requirement on import of competences.',
#                              'Lack of industrial experience, Language Barieer, '
#                              'Non-competive Salary',
#                              'lots of open positions; too high salary '
#                              'expectation;',
#                              'Cost; Availability of experienced candidates',
#                              'lack of correct skills, personnel with not '
#                              'enough experience, lack of personnel with '
#                              'experience in instrument/machines operation',
#                              'Passport, lack of experts, lack of skilled '
#                              'managers to evaluate candidates and unrealistic '
#                              'expectations towards candidates.',
#                              'Pay, Location, knowledge base',
#                              'salary; salary+bonuses; bonuses+salary.',
#                              'Finding experienced people',
#                              'the knowledge of the selectors',
#                              'Salary, Location, resources',
#                              'Missing understanding in the management',
#                              'Lack of skilled engineers; Lack of experienced '
#                              'engineers; High competition between companies',
#                              "Visa's, experience, location",
#                              'Matching skillsets to needs.',
#                              'amount of technical skill needed; need for '
#                              'people to work with toxic materials and wear '
#                              'PPE; inflexibility in hiring/highly specific job '
#                              'requirements',
#                              'Immigration',
#                              'Lack of correct training provision; Lack of '
#                              'correct university courses; Lack of trained '
#                              'individuals',
#                              'adequate financing, Bay Area cost of living, Bay '
#                              'Area Poo & Filth',
#                              'flexibility; salary',
#                              'Awareness of industry; Market forecasts',
#                              'looking for all checkboxes to be filled rather '
#                              'than most, low salary offer',
#                              'compensation; location; willingness to train',
#                              'Lack of expertise; low salary; scarcity',
#                              'knowledge,',
#                              'barrier 1: lack of talents in the domain',
#                              'Pay, geography',
#                              'inconsistent market, under skilled workers,',
#                              'Lack of local talents; Difficulty in integrating '
#                              'multicultural team; Hiring right skillsets',
#                              'Toxic patriarchy:  Christopher Morris, Executive '
#                              'Director, Marketing and Business Development at '
#                              'Xerion Advanced Battery Corp. "Very few women '
#                              'elect/chose to pursue the battery science '
#                              'education fundamental to succeeding and '
#                              'advancing this industry. Lots of opportunities '
#                              'for motivated women...but they have to show up '
#                              'and put in the time and hard work" '
#                              'https://www.linkedin.com/posts/dknuckey_the-tesla-mafia-is-shaking-up-the-battery-activity-7039355064490090496-Mn0r?utm_source=share&utm_medium=member_desktop',
#                              'College education related to battery technology, '
#                              'compensation competition with big tech and '
#                              'pharma companies',
#                              'shareholders; lack of talent;',
#                              'Experience, Salary expectations, Market '
#                              'uncertainty',
#                              'Extreme specificity requirements',
#                              'competition with other more lucrative industries',
#                              'lack of pool of people with experience in '
#                              'battery industry',
#                              'Similar experience as per the project '
#                              'requirements',
#                              'Resume not reaching the hiring manager',
#                              'Compensation, Work Life Balance, Talent mismatch',
#                              'Visa issues',
#                              'Lack of experience',
#                              'Lack of domain specific training',
#                              'Competition; Compensation; Location',
#                              'Skills shortage',
#                              'Specialized knowledge scarcity; Rapid '
#                              'technological evolution; Cross-industry '
#                              'competition',
#                              'lack of experience, language(in north America), '
#                              'Less competitive wages',
#                              'Compensation',
#                              'remote work',
#                              'Work authorization; Compensation; Location',
#                              'Skills gap',
#                              'Experience; Narrow Focus',
#                              'Hiring rules',
#                              'limited carreer and salary development for '
#                              'technical experts',
#                              '1) manufacturing employers do not want to hire '
#                              'chemists/engineers with electrochemistry '
#                              'knowledge (prefer mechanical, industrial, or '
#                              'electrical engineers); 2) hiring managers are '
#                              'not able to recognize talent, or deficiencies in '
#                              'needed skill sets; 3) inexperienced candidates '
#                              'have no experience (academic, or practical) with '
#                              'electrochemical systems (experimental testing, '
#                              'data analysis, machine designing, &/or process '
#                              'development)',
#                              'Education; experience; antiquated business '
#                              'practices',
#                              'Outdated curriculums',
#                              'the breadth of info that batteries cover means '
#                              'that it is easy for someone to have one skill '
#                              'set but lack another skill which seems '
#                              'immediately adjacent',
#                              'Striking the balance between graduate entry and '
#                              'pay scales',
#                              'Low Salaries; right fitment of skills',
#                              'Skilled background',
#                              'Location of candidates to facility, finding '
#                              'candidates with battery knowledge',
#                              'Few of them exist, they are too expensive',
#                              'location',
#                              'pay , and importance of technical backgrounds',
#                              'Gen Z work ethic; Poor public schools; Social '
#                              'Safety nets',
#                              'Location of the Company and Talent in Battery '
#                              'industry',
#                              'understanding of exactly how battery is made and '
#                              'managed.',
#                              '"Working culture;Salary & compensation; company '
#                              'growing potential"',
#                              'Technical gap from academia and industry; visa '
#                              'requirements for international employment; '
#                              'mismanagement',
#                              'Small pool',
#                              'lack of both technical and practical knowledge',
#                              'Skills, experience, knowledge',
#                              'Small pool, high expected salaries',
#                              'Lack of experience/skills',
#                              'availability of labour, uncertainty of tenure, '
#                              'competition for trades',
#                              'Salary, experience, mindset',
#                              'Pay; Competition; Impression',
#                              'Salary negotiations, location constraints, work '
#                              'environment, reference culture',
#                              'lack of proper educational program in '
#                              'universities, lack of knowledge generally on the '
#                              'field',
#                              'Well rounded skillset, experience, '
#                              'electromechanical knowledge',
#                              'Language; Location; Compensation',
#                              'No good candidates',
#                              'Skills shortage; VISAs;',
#                              'Lack of previous experience, Perception of '
#                              'non-transferrable skills, Gatekeeping mentality '
#                              'within some companies',
#                              'Location; Job stability; Income',
#                              'lack of availability',
#                              'wages, lack of knowledge, desire for remote work',
#                              'Overly theoretical school programs,',
#                              'Lack of battery studies for college '
#                              'undergraduates',
#                              '[Lack of trained workforce][lack of training]',
#                              'Salary, Innovative Mindset, Material Science '
#                              'Innovations',
#                              'Hands on Experience; contextual experience; '
#                              'geographical pay standards',
#                              'Battery companies expect narrow expertise in '
#                              "batteries, I'm a generalist in power "
#                              'electronics.',
#                              'Salary, Talent Pool, Location',
#                              'Difficult to gain expertise, unattractive '
#                              'locations',
#                              'lack of prior experience that translates',
#                              'Lack of required skills set, poor battery '
#                              'education, slow EV adoption',
#                              'Fierce competition for talent; bloated claims by '
#                              'start-ups; focus on domain knowledge over soft '
#                              'skills',
#                              'There isn’t enough background knowledge in the '
#                              'talent pool, it needs developed',
#                              'limited local availability, high competition',
#                              'Tough job market, companies fluctuating in '
#                              'funding',
#                              'small industry (in NL); lack of experience',
#                              'Shitty HR filtering; Lack of knowledge; poor '
#                              'pay/benefits',
#                              'Lack of industry talent in USA; questionable '
#                              'market finance commitments making hiring picture '
#                              'difficult',
#                              'Low salaries',
#                              'flexibility',
#                              'Too much priority in hiring engineers without '
#                              'hiring enough internal infrastructure roles to '
#                              'support effectively.',
#                              'location; competitive benefits',
#                              'niche industry',
#                              'competition',
#                              'Not many large battery companies in the US, Lack '
#                              'of battery related education, Wide variety of '
#                              'technical skills needed',
#                              'Location, competition, career prospects',
#                              'Lack of direct background; lack of effective '
#                              'recruitment skills; lack of talent pool',
#                              'Matching compensation and knowledge',
#                              'Pay and future planning',
#                              'The need to relocate, finding the talent with '
#                              'exactly what you want',
#                              'Education; Experience;',
#                              'Skill gap, location',
#                              'Base Salary below or around average; hot market',
#                              'Skilled labour',
#                              'pay',
#                              'Availability outside California; willingness to '
#                              'move to NC; high salary expectations',
#                              'Location; Applicable Knowledge; Salary',
#                              'The field is still very young so many people in '
#                              "the industry don't have enough experience "
#                              'outside university',
#                              'not enough teaching of electrochmistry/batteries '
#                              'at universities',
#                              'lack of domestic education focused on battery '
#                              'industry',
#                              'Benifit; future plan; salary',
#                              'visas, salary, location',
#                              'Gender',
#                              'Inflexible hiring practices',
#                              "industry demand isn't there to create enough "
#                              'jobs, still a ways away',
#                              'Education; HV familiarity; chemical awareness',
#                              'base salary',
#                              'Rigid attention to job description; location of '
#                              'job; unreasonable expectations',
#                              'lack of skilled personnel, salaries offered by '
#                              'some companies, location',
#                              'Finding people with experience',
#                              'Location, Competition for technical talent',
#                              'Rapidly changing job functions; lack of formal '
#                              'education about batteries',
#                              'Limited availability of talent',
#                              'Limited talent pool, difficult of getting talent '
#                              'to change industries',
#                              'Budget',
#                              'US public school system, marijuana, entitlement '
#                              'mentality',
#                              'Salary',
#                              'Exposure to technology and common practices; '
#                              'Fundamental understanding of how batteries work; '
#                              'The difference between R&D/prototype design vs '
#                              'production design',
#                              'hard science + soft skills background is hard to '
#                              'find.. Competing with tech industry makes it '
#                              'hard to attract talent',
#                              'Networking',
#                              'Few people have the experience, or are willing '
#                              'to invest',
#                              'Lack of workforce trained with specific skill '
#                              'sets, lack of focus within relevant departments '
#                              'in higher education',
#                              'Job security',
#                              'Process engineer',
#                              'no one knows who needs which talent at one place',
#                              'Lack of skills, opportunity, training',
#                              'Too many academic electrochemists (physicists '
#                              'and chemists) with no engineering background or '
#                              'knowledge.',
#                              'Lack of multiple test considering his '
#                              'professional performance and his overall '
#                              'behaviour.',
#                              'Company and employee profile, vision, old HR '
#                              'strategy for new needs',
#                              '"assuming anyone living in africa is not '
#                              'skilled; location-far north; employment '
#                              'opportunities for spouses"',
#                              'Lack of good combination of engineering skills '
#                              'with people management',
#                              'Electrochemistry is far from electricity '
#                              'engineering',
#                              'sufficient number of people who have actually '
#                              'done it before. This skill is actually still '
#                              'limited to Asian companies even today.',
#                              'salary expectations, skills shortage, '
#                              'immigration barriers',
#                              'Lack of battery knowlege; lack of battery '
#                              'development experience',
#                              'Salary',
#                              'salary',
#                              'Location; Credentialism; HR',
#                              'Insufficient skilled people;working '
#                              'permit;ratherly newer field to work;',
#                              'Lack of talent',
#                              'SME size',
#                              'not enough people with right skills; other '
#                              'sectors pay better; relocation',
#                              'Less experience; less hands on experience',
#                              'Salary, poor employer branding, availability of '
#                              'skilled talents',
#                              'availablility of talent',
#                              'bias from recruiters',
#                              'low wage',
#                              'Academia and Industry differences',
#                              'Salary, Location, Products',
#                              'cultural barriers ; company knowledge',
#                              '“[low wages]”',
#                              'location constraints; talent shortage; work visa',
#                              "Lack of peers, new technology that doesn't "
#                              'exist, High cost of living in SF Bay Area',
#                              'Restricted capable pool of available resource',
#                              "Employer's lack of willingness to invest in "
#                              "qualified people; employer's lack of willingness "
#                              'to invest in tools and infrastructure; '
#                              'fundamental lack of capital',
#                              'Limited formal education',
#                              'Knowledge, Hands-on experience, Risk taking '
#                              'ability',
#                              'Availability',
#                              'Lack of Opportunities; Rivalry from Asian '
#                              'markets',
#                              'Limited pool of talent/experience',
#                              'Competitive compensation; work life balance',
#                              'Salary, company stability, company perspective',
#                              'Lack of battery related experience',
#                              'Pay; risk tolerance; trust in leadership',
#                              'salary expectations, skill mismatch, '
#                              'certifications',
#                              'Lack of practical manufacturing experience',
#                              'Lack of experienced people',
#                              'Experience, training, compensation',
#                              'education',
#                              'COMPANY INTERNAL RECRUITMENT PROCEDURES',
#                              'age discrimination',
#                              'Attracting talent and explaining knowledge '
#                              'transfer',
#                              'salary',
#                              ';',
#                              'Compensation; Unstable funding; Not enough '
#                              'skilled talents',
#                              'visa processes',
#                              'competitivity; salary; market stability',
#                              'salary',
#                              'unknown',
#                              'Small talent pool; lack of educational programs; '
#                              'a lot of competition',
#                              'Research opportunities in university are all '
#                              'chemistry based no manufacturing; people look '
#                              'down on manufacturing; locations most facilities '
#                              "need to be in aren't california",
#                              'no established workforce development',
#                              'Experience, Burnout, Compensation',
#                              'uncertainty (since the industry is newer vs '
#                              'others like oil/gas), no meaningful and '
#                              'accessible opportunities to get into the '
#                              'industry, and global political climate',
#                              'salary',
#                              'Barrier 1 - when a company sets expectations '
#                              'that’s aren’t achievable. Barrier 2 - lack of '
#                              'alignment from hiring decision makers around '
#                              'role responsibilities.  barrier 3 - lack of '
#                              'willingness to train (plenty of people who apply '
#                              'to jobs are 8/10 qualified but companies don’t '
#                              'want to take the risk to be able to train up the '
#                              'other 2/10 skills)',
#                              'Not enough local talent; talent is too spread '
#                              'out; we are still behind China for overall '
#                              'talent',
#                              'Unrealistic expectations from management; lack '
#                              'of funding; role too specific/broad',
#                              'competing for great people; instability in the '
#                              'industry',
#                              'Lack of Foundational knowledge about Battery',
#                              'salary; competence; experience',
#                              'lack of talents;',
#                              'geographical location; lack of clear roadmaps;',
#                              'lack of skilled people, visas, low salaries vs '
#                              'cost of life',
#                              'wide range of technology',
#                              'location; salary; carrier growth',
#                              'No workforce',
#                              'Pay scale;talent pool',
#                              'lack of experienced and skilled applicants',
#                              'Salary and expectations of employers that '
#                              'scientists should also know data science etc',
#                              'High Salaries, Few Battery Professionals, '
#                              'Startup Status',
#                              'working in dryroom;',
#                              'location',
#                              'availibility',
#                              'More onboarding knowledge needed; little support '
#                              'from public policy; public perception of safety',
#                              'Location',
#                              'Realistic hiring expectations from the team, '
#                              'organized recruiting process',
#                              'not enough experience in the work force',
#                              'Lack of battery knowhow, lack of hands-on '
#                              'experience, not interesting or competitive for '
#                              'software or mechanical engineers',
#                              'salary',
#                              'Lack of skilled workers',
#                              'Funding; availability of skilled worker; job '
#                              'experience',
#                              "Low salaries; headhunter's knowledge;",
#                              'other companies hired them',
#                              'Lack of skilled personnel, lack of battery '
#                              'education, poor renumeration',
#                              'Availability of skilled workers',
#                              '1. Voluntarism of the process (recruitment '
#                              'skills not suited for industry), 2. Suitable '
#                              'talent scarcity, 3. lack of golden middle for '
#                              'the mix structured approach / enterpreneurial '
#                              '(managed risk taking)',
#                              'Finding qualified people',
#                              'Finding them',
#                              'Salary; Project availability; Benefits',
#                              '"Low pay; No equity; transactional nature"',
#                              'Budget',
#                              'sponsership employment',
#                              '1. Competitive market 2. Skill mismatched 3. '
#                              'Hiring process',
#                              'Expertise; Hard-Working; Knowledgeable',
#                              'No pool for specialist having domain knowledge',
#                              '[employment laws];',
#                              'Skilled professional',
#                              'lack of skill',
#                              'Experience required',
#                              'competition, skills, niches',
#                              'Lil knowledge of HR on necessary skills; '
#                              'Structures driven by mechanical engineering; low '
#                              'starter income',
#                              'Lack of specialized education and training '
#                              'programs; Limited availability of experienced '
#                              'professionals; High competition for talent '
#                              'across industries.',
#                              'Education; Market uncertainty',
#                              'non availability of good people in the UK',
#                              'Location; Reputation; Visibility',
#                              'Not enough specific profiles (technician, '
#                              'engineer, doctor)',
#                              'Availability',
#                              'Lack of resource, industry challenges in Europe, '
#                              'slow EV take up in EU',
#                              'Perception of the Industry; Competition Across '
#                              'Industries; Talent Shortage',
#                              'Communication of the requirements',
#                              'uncertanty about financial survival of  '
#                              'companies, no stable financial environment',
#                              'Language, lack of industrial experience, '
#                              'non-competitive salaries',
#                              'Location, pay, competition',
#                              'Lack of domain expertise',
#                              '[bounce in the ev adoption, then in the battery '
#                              'industry outlook];[lack of training diversity]',
#                              'salary too low, no remote option, low autonomy',
#                              'Workforce Size and Experience; Location; Pay',
#                              "Generally, I don't think recent grads see "
#                              'battery research/production all that '
#                              'challenging.',
#                              'chaotic employment; impatient management; '
#                              'excessive travel',
#                              'lack of experience; historically batteries were '
#                              'not "sexy"; very few people were aware of the '
#                              'market',
#                              'Location, lack of industrial environment',
#                              'Yes',
#                              'Lack of experience',
#                              'Interest;  company stability',
#                              'lack of specific experience, poor compensation '
#                              'offers, poor training',
#                              'visa, underqualified candidate,',
#                              'No people, work in office',
#                              'Not enough skilled workers, outdated knowledge '
#                              'about battery industry lack of practical '
#                              'experience - only based on academic or doctoral '
#                              'program',
# ...
#                                  'Manufacturing;electrochemistry;analytical '
#                                  'instruments',
#                                  'strategic thinking; sales skills; listening',
#                                  'Communication',
#                                  'Flexibility, Desire to Learn, Networking',
#                                  'Experience, Knowledge, Technical proficiency',
#                                  'Electrochemical knowledge; being a quick '
#                                  'learner; communication',
#                                  'lifelong Learning attitude',
#                                  'Time management; open communication; basic '
#                                  'programming',
#                                  'Finance, accounting, tax',
#                                  'Willingness',
#                                  'XRD/crystallography, Python',
#                                  'communication, efficiency, attention to '
#                                  'detail',
#                                  'openess to ask questions',
#                                  'Generalist, Battery Knowledge (PhD), '
#                                  'hands-on engineering',
#                                  'Problem solving, Empathy, Public speacking, '
#                                  'strategy',
#                                  'Mindset/willingness to learn; critical '
#                                  'thinking and reasoning;',
#                                  'Endurance; teamwork; experience',
#                                  '[Leadership];[Knowledge];[Multitasking];[Communication];[Experience]',
#                                  'previous experience with electrochemistry',
#                                  'Industrial Automation, Battery energy '
#                                  'storage system integration, Microsoft excel',
#                                  'Solid state chemistry, people management',
#                                  '1. Ability to bread on experiences from '
#                                  'different industries, 2. Crisis management, '
#                                  '3. Curiosity',
#                                  'Adaptability, tenacity, continuously learner',
#                                  'Program management, technical, engineering',
#                                  'Critical thinking; Analytical; Persistent',
#                                  '"Adaptation; Research"',
#                                  'Research and Development; Technical; '
#                                  'Analytical',
#                                  'Management skills, patience, Projects- deep '
#                                  'handling',
#                                  '1. Hardworking 2. Experience 3. Management',
#                                  '[Excellent Quality]; [Support to Customers]; '
#                                  '[Hard-Working]',
#                                  'Hardworking',
#                                  '[hard-working]; [not giving up]; [patience]',
#                                  'Programming, Electronics',
#                                  'Fast learning, autonomy, curiosity',
#                                  'flexibility, curiosity, dedication',
#                                  'Logical thinking; quickness of mind; wide '
#                                  'professional knowledge incl. Business '
#                                  'science',
#                                  'Problem-solving; Teamwork; Time management',
#                                  'Problem solving; Mechanical mind; '
#                                  'Cross-functional knowledge',
#                                  'Automotive ecosystem understanding, business '
#                                  'acumen, networking',
#                                  'Flexibility; Open Mindness;',
#                                  'Sociability; Technical and scientific '
#                                  'mastery; Management; Strictness',
#                                  'Skill 1 - read a lot - learn quickly',
#                                  'grit, determination, big picture thinking, '
#                                  'optimism',
#                                  'Can do attitude, flexibility, experience',
#                                  'Communication; Project Management; Data '
#                                  'Analysis; Empathy; Proactivity; Teamwork; '
#                                  'Critical Thought; Materials Knowledge',
#                                  'Problem solving skills, Curiosity, Strategic '
#                                  'Thinking',
#                                  'product development; material knowledge; '
#                                  'sales knowledge; marketing; mentoring',
#                                  'Agility, Easy Learning skills, Social skills',
#                                  'Technical knowledge, hands-on experience, '
#                                  'materials science',
#                                  'Battery and energy industry expertise; being '
#                                  'a "full stack" marketer',
#                                  '[engineering][electronics][manufacturing '
#                                  'system]',
#                                  'problem solving, communication, perseverance',
#                                  'Adaptability; Fundamental Electrochemistry '
#                                  'Knowledge',
#                                  'multidisciplinary knowledge, willingness to '
#                                  'learn, creative thinking',
#                                  '"Engineering ; Technical ; Applications"',
#                                  'global contacts; process experience; '
#                                  'economics',
#                                  'critical thinking, wanting to learn, self '
#                                  'starter',
#                                  'Electrochemistry, communication',
#                                  'Quick learner Flexibility',
#                                  '1. Broad Technical Knowledge 2. Industrial '
#                                  'Industry Experience 3. VOC skills',
#                                  'Multitasking; adaptability; diplomacy',
#                                  'detailed mindset, data science, '
#                                  'communication',
#                                  'curiosity, adaptability, social skills',
#                                  'Asking questions; intellectual humility',
#                                  'knowledge, personality, academic history',
#                                  'Flexibility',
#                                  'Practical knowlwdge about battery '
#                                  'prosuction, teoretical knowledge about '
#                                  'li-ions battery,statistical skills',
#                                  '1. Knowledge 2. Risk Taking 3. Problem '
#                                  'Solving',
#                                  'Curious; motivated; autonomous',
#                                  'mechanical design, high volume product '
#                                  'design, first principle thinking, curiosity, '
#                                  'drive',
#                                  'decision making; cost analysis; relationship '
#                                  'building',
#                                  'Engineering; practical hands on skills; '
#                                  'adaptability',
#                                  'Communication; analytical thinking;',
#                                  'Resilience, humility, determination',
#                                  'connections, experience, professional '
#                                  'knowledge',
#                                  'Expertise in wholesale and retail, regulated '
#                                  'and deregulated power markets; strong '
#                                  'analytical skills; adaptability',
#                                  'engineering, project management, strategy',
#                                  'Independent learning; Teamwork; Being '
#                                  'organized',
#                                  'Good Communication Skills; Broad knowledge '
#                                  'in many engineering diseplines; Materials '
#                                  'science background',
#                                  'Creativity; chemistry;',
#                                  'discipline',
#                                  'Deep understanding of technology, strategy, '
#                                  'and leadership',
#                                  'Software, networking, electronics',
#                                  'Fundamental knowledge ( Cell testing) ; '
#                                  '(battery Pack Testing); (BMS Testing)',
#                                  'Project management, business strategy, '
#                                  'analysis',
#                                  'Battery knowledge; Lab experience; Willing '
#                                  'to learn',
#                                  'Chemistry knowledge, impedance analysis, '
#                                  'intuition',
#                                  'Critical thinking, communication, and '
#                                  'engineering background',
#                                  'Skill1: Networking, Skill2: Expermental '
#                                  'Subject knowledge, Skills 3: knowhow market',
#                                  'Picking up concepts quickly',
#                                  'Software Development',
#                                  'Physics background, programming, data '
#                                  'analysis',
#                                  'Technical understanding of energy storage ; '
#                                  'experience with required equipment ; '
#                                  'communication skills',
#                                  'Curiosity, grit, adaptability',
#                                  'Ability to learn; good communication; coding '
#                                  'in python',
#                                  'Proactive, good communication, presentation',
#                                  'Flexibility, fast learning, perseverance',
#                                  'Python data analysis; test engineering; '
#                                  'battery electrochemistry',
#                                  'Research, Data analysis, Communication',
#                                  'Materials synthesis, testing and advanced '
#                                  'analysis',
#                                  'global knowledge of battery innovation',
#                                  '"Simulation study; Cell Manufacturing; '
#                                  'Electrode synthesis"',
#                                  'Team management, quick learning, innovation, '
#                                  'team leadership',
#                                  'perseverance, curiosity, courage, vehicle '
#                                  'integration',
#                                  'Continuos learning, foundational knowledge, '
#                                  'programming',
#                                  'flexibility; understanding of start ups; '
#                                  'emerging tech approach',
#                                  'Fundamental knowledge; persistency; critical '
#                                  'thinking',
#                                  'Being quick learner, taking risk, agile '
#                                  'product development approach',
#                                  'Data analysis, molecular quantum mechanics, '
#                                  'cell modelling',
#                                  'Network',
#                                  'Communication; perseverance; programming',
#                                  "determination; perserverance; UNC's "
#                                  'chemistry program',
#                                  'Experience; Education; Scientific Curiosity;',
#                                  'Leadership,  planning',
#                                  'Fast learner; analytical mindset; '
#                                  'detail-oriented',
#                                  '1. Electrical background 2. Understanding of '
#                                  'the renewable energy industry 3. I had a '
#                                  'wide knowledge base t',
#                                  'Generalism, open mindedness, collaboration',
#                                  'International; network; business development',
#                                  'People leadership, techno-economics, '
#                                  'communication',
#                                  '[DoE],[Python Programming],[Data Analysis]',
#                                  'Team leadership skills, mentorship of peers, '
#                                  'inter-team collaboration',
#                                  'Laboratory skills',
#                                  'Troubleshooting, question formulation, '
#                                  'communication',
#                                  'electrical, electronic knowledge; project '
#                                  'managment; testing knowledge',
#                                  'Focus, network, interesr',
#                                  'experience across multiple disciplines, '
#                                  'productization focused, solution selling',
#                                  'creativity; fundamental knowledge of '
#                                  'batteries',
#                                  'ndt, testing',
#                                  'Electrochemistry',
#                                  'Product Knowledge (Battery structure + '
#                                  'chemical transport phenomena); Problem '
#                                  'Solving Acumen',
#                                  'luck; communication; product knowledge',
#                                  'Material Synthesis, Analytical '
#                                  'Characterization Expertise,',
#                                  'Teamworking, business analytics, strategic '
#                                  'planning',
#                                  'Dedication; enthusiasm; resilience',
#                                  'Drive, quality, interpersonal skill',
#                                  'Deep knowledge in several technologies, '
#                                  'experience in many R&D projects oriented to '
#                                  'bring up new market products',
#                                  'Education, Ambition, Fiction',
#                                  'Battery industry knowledge, automotive '
#                                  'industry knowledge, communication skills',
#                                  'Adaptability and Flexibility, Technical '
#                                  'Proficiency, Problem Solving',
#                                  'Mathematical modeling; mentorship; '
#                                  'experiment design',
#                                  'keeping my mouth shut, when my employer lies '
#                                  'to customers and investors',
#                                  'Synthesis, testing via electrochemical '
#                                  'method, structural characterization',
#                                  'people skills; project managemnet; technical '
#                                  'knowledge',
#                                  'Problem solving and critical thinking; Hands '
#                                  'on approach; Hard work',
#                                  'adaptability; strive for excellence; '
#                                  'synthesis',
#                                  'Matlab, Technical Understanding, Analysis',
#                                  'Experience from many different fields']}

# %%
plotter.make_bar_plot_from_dict(
    res_company_skills['skills_how_to_improve'],
    title='When you first started in the battery industry, what could have improved your job performance on day one?',
    saveas='company_skills_how_to_improve.png',
    num_elements=3,
    sorted=True
)

plotter.make_bar_plot_from_dict(
    res_company_skills['skills_how_was_trained'],
    title='When you first started your role, how were you trained?',
    saveas='company_skills_how_was_trained.png',
    num_elements=3,
    sorted=True
)

# %% [markdown]
# ## Company Retention

# %%
res_company_retention = analyst.summarize_company_retention()
pprint(res_company_retention)
# Out:
# {'retention_factors': {'A non-toxic work environment and quality upper management': 1,
#                        'Autonomy': 1,
#                        'Career growth opportunities': 447,
#                        'Chance of Success of Companies Technology/Product': 1,
#                        'Company Viability and Trajectory': 1,
#                        'Company Vision and Goals': 1,
#                        'Company culture': 420,
#                        'Company vision': 1,
#                        "Company's chance for success": 1,
#                        'Eco-friendliness': 1,
#                        'Equity': 219,
#                        'Ethics': 1,
#                        'For a different potentially better role/interesting tasks': 1,
#                        'Good manager': 1,
#                        'I will not seek another opportunity': 1,
#                        "I'm getting close to retirement and am not looking for another job.": 1,
#                        'Impact': 1,
#                        'Innovation': 1,
#                        'Insurance coverage': 1,
#                        'Interest in project': 1,
#                        'International exposure': 1,
#                        'Job for my wife': 1,
#                        'Job stability': 329,
#                        'Location': 4,
#                        'Location (i.e. NOT west coast USA)': 1,
#                        'Market advantage based on innovation & technical capability': 1,
#                        'Nothing will get me to leave': 1,
#                        'Parental leave': 74,
#                        'People and the environment': 1,
#                        'Perks': 128,
#                        'Problem space': 1,
#                        'Salary': 548,
#                        'Support on R&D Projects': 1,
#                        'Supportive Leadership': 1,
#                        'Technical challenges': 1,
#                        'Technology Relevance': 1,
#                        'The problems I would be working on': 1,
#                        'Time Flexibility': 1,
#                        'Total hours worked': 176,
#                        'Vacation time': 254,
#                        'Visa sponsorship': 127,
#                        'Work location': 1,
#                        'Work location flexibility': 340,
#                        'Work-life balance': 2,
#                        '_tot_': 634,
#                        'bonuses': 548,
#                        'interesting projects': 1,
#                        'job responsabilities': 1,
#                        'swarm intelligence': 1},
#  'retention_is_on_market': {False: 310, True: 328, '_tot_': 638},
#  'retention_misc_list': ["Just recently changed jobs, still haven't started "
#                          'new one yet',
#                          'Geography',
#                          'geography; stability; pay',
#                          'Visa sponsorship.',
#                          'A firm that values my experiences',
#                          'community involvement - make EVs accessible to all',
#                          'geography',
#                          'hybrid option; better pay',
#                          'Nope',
#                          'Company stability',
#                          'Need cheap housing and low cost daycare in the '
#                          'location of next role',
#                          'no',
#                          'Benefits;Money;Culture',
#                          'Diversity, international opportunities',
#                          'Learning opportunities and mentorship',
#                          'Development; Testing; Modelling',
#                          'Family friendly policies',
#                          'Next generation cell development',
#                          'Salary, work location flexibility, Driven team',
#                          'Environmental Impact',
#                          'company financial stability and company culture',
#                          'role ; salary ; culture',
#                          'affordable homes or high salaries',
#                          'Sustainability focus, the technology cannot make the '
#                          'planet worse, or their marketing/positioning in the '
#                          'market cannot be greenwashing.',
#                          'Impact, salary',
#                          'personal growth; clear career path; innovative',
#                          'Flexible working hours and vacation- as long as I '
#                          'deliver on my targets and work hard, I need the '
#                          'freedom of being allowed time off',
#                          'Innovative environment, career growth opportunities, '
#                          'collaboration culture, work life balance',
#                          'robotics; culture',
#                          'Money; responsibility; career growth',
#                          'Higher compensation, ability to better focus on '
#                          'value-add contributions',
#                          'Geography, salary, work-life balance',
#                          'Location in Europe ; no consulting anymore',
#                          'The project',
#                          'New learning; work life balance',
#                          'Diversity; career opportunities; work location '
#                          'flexibilities',
#                          'carreer groth and learning experience',
#                          'geography; good leadership; generous maternity leave',
#                          'Developing a scalabale, future-proof technology',
#                          'nil',
#                          'Geography; culture; stability',
#                          'a better work-life balance',
#                          'remote work',
#                          'geography or ability to work remote',
#                          'Good team and company culture, adequate '
#                          'compensation, visa sponsorship',
#                          'flexibility in country location 1',
#                          'Idk',
#                          'stock options; culture; interesting product',
#                          'Headquarters in upper Midwest; strong culture '
#                          '(competent people & held accountable); '
#                          'quality-focused',
#                          'not looking for another role.  Growing my own '
#                          'company',
#                          'visa sponsorship, career growth, culture',
#                          'Money; personal and professional development',
#                          'I am open to consultation work and contract work '
#                          'with reputable companies. Years of experience... '
#                          'But, in this competitive industry, especially in '
#                          'California, I am too old for them. I get lots of '
#                          'attention due to my skills and experience, but once '
#                          'they detect my age... Interview is already over. The '
#                          'silent discriminator, age',
#                          'Geography; political environment',
#                          'I am not looking for another role',
#                          'Item 1: on-site/remote work flexibility; item 2: '
#                          'parental leave; item 3: more senior than current '
#                          'role',
#                          'Appreciation; opportunity; supports',
#                          'Location, funding of the company, the competitive '
#                          "edge of the company's core technology",
#                          'More stable company finances, clearer progression '
#                          'opportunities, more money',
#                          'Culture; salary; company outlook',
#                          'Not sure I need another role at this point in my '
#                          'career',
#                          'Location, Money',
#                          'no',
#                          'Work-life balance, potential to make meaningful '
#                          'contribution to the industry, compensation',
#                          'reasonable commute time, good work-life balance, '
#                          'fair treatment of women',
#                          'Career growth opportunities,\n'
#                          'Valued role and responsibilities,\n'
#                          'Compensation and benefits.',
#                          'Open for new ideas and great culture to work',
#                          'More PTOs, remote work flexibility, career change '
#                          'opportunities',
#                          "Can't define now",
#                          'STRONG ENGINEERING TEAM; COMPETITIVE SALARY; COMPANY '
#                          'CULTURE',
#                          'geography; money; flexibility',
#                          'Business leadership position',
#                          'role; money; benefits',
#                          'Culture, Benefits, Flexibility',
#                          '"geography", "career growth options", "better work '
#                          'life balances"',
#                          "Professional  development budget that doesn't "
#                          'require employee match',
#                          'Money; Location flexibility; Role near the clients',
#                          'Open & Inclusive work environment; Global Travel '
#                          'Opportunities; $100k+ package',
#                          'No',
#                          'For me, money is one of the biggest factors in '
#                          'making decisions, but equally important is the '
#                          'chances of growth in both my career and as a '
#                          'researcher. Of course, the company benefits and '
#                          'culture are significant as well. I want to work in '
#                          "an environment that respects people's differences, "
#                          "is willing to listen to their team members' opinions "
#                          'and needs, and is appreciated as a worker. We are '
#                          'all human after all.',
#                          '"Research;Fun;Vision"',
#                          'relocation help, trainings',
#                          'Work live balance',
#                          'There is a lot of talk but very little action in '
#                          'this industry',
#                          'Commutability; culture; increase in responsibility',
#                          'Culture: less firefighting, more strategy; '
#                          'geography: new country',
#                          'An ideal employer should have a stable revenue '
#                          'stream outside of exclusive dependence on battery '
#                          'industry, to manage inevitable boom & bust in the '
#                          'emerging battery industry.',
#                          'Remote opportunities',
#                          'Remote Work; Collaborative Culture; Climate Impact',
#                          'cutting edge technology',
#                          'I Like to have a lot of Travel During my Work',
#                          'company culture, office location, flexible time '
#                          '(work from home option)',
#                          'Chance to learn',
#                          'salary, growth, positivity',
#                          'Growth, Role and Benefits',
#                          'Better work life personal life balance',
#                          'France, Canada, Belgium',
#                          'Equity; Appreciative culture',
#                          'Where the office is located',
#                          'Mild climate, developed city; total annual salary '
#                          '$100,000+ or opportunity to rapid growth; value of '
#                          'an employee with a PhD',
#                          'interesting projects,',
#                          'Money, Proper resources for R&D, benefits, culture, '
#                          'work-life balance',
#                          'no',
#                          'more money, better job stability',
#                          'Mainly career opportunities',
#                          'corporate culture of "niceness" (not like Tesla)',
#                          'local language requirement also a key concern for me',
#                          'Geography; money; role',
#                          'money, better work culture, better benefits,',
#                          'remote work; competent program management; salary',
#                          'money; full remote; culture',
#                          'item 1: more responsibility',
#                          ', salary, career growth, job satisfaction',
#                          'Relocation and settling in support; Return flights; '
#                          'Training support',
#                          'Please stop using violent words ie Tesla Mafia. '
#                          'Words matters, thank you',
#                          'Geography: in process of moving to Portugal.',
#                          'Peaceful Location; Supporting Team; Motivation',
#                          'Stability;Fair Treatment;Training',
#                          'Strong Mentorship culture;\nGood work life balance;',
#                          'Possibility to work remotly, Money, Possibility to '
#                          'growth',
#                          'Competitiveness of company technology and quality of '
#                          'management',
#                          'More money, Remote US/CAN',
#                          'To be within driving/visiting distance of family; '
#                          'competitive pay; job security',
#                          'compromised team, interesting project, location '
#                          'independence',
#                          'Control of budget',
#                          'Growth',
#                          'Team leadership and compensation for this',
#                          'Developing a role to foster a mentoring environment '
#                          'between experienced and inexperienced engineers',
#                          'Money',
#                          'Work from home when it makes sense',
#                          'Item 1 - Skill transferability',
#                          'Technical leadership; Functional Safety',
#                          'More stability',
#                          'Family oriented',
#                          'More money!',
#                          'hybrid, salary, good healthcare, reasonable location',
#                          'Better Organizational structure, clarity on career '
#                          'goals and milestones.',
#                          '"Company\'s vision;CEO\'s vision"',
#                          'Company culture; permanent contract; high salary',
#                          'benefits, compensation, flexible working scheme',
#                          'Geography, culture, benefits',
#                          'Remote working flexibility, better culture',
#                          'stock options',
#                          'Geography; Proactive continuous training; '
#                          'Non-founder lead',
#                          'Explore new place, money making, carrer growth',
#                          'Knowledge, research mentality, good compensation',
#                          'Challenge; Recognition; Honesty;',
#                          'Salary, Benefits, Culture, Technological '
#                          'Innovations, Hybrid Flexibility',
#                          'Cultural experience; career development; income',
#                          'Culture',
#                          '[Leadership position]',
#                          'Location, impact, culture',
#                          'RSUs instead of stock options',
#                          'Competent management',
#                          'No',
#                          'Innovation',
#                          'Geography, hybrid work',
#                          'more upside, unicorn',
#                          'Opportunity to work with big EV company',
#                          'more influence over decision making; focus on '
#                          'processes',
#                          'growth, ownership, accountability',
#                          'Remote, Salary raise, Flexible time off',
#                          'Salary to match cost of living for geography; better '
#                          'parental leave (ideally 5+ months); better equity '
#                          'package',
#                          'Money, benefits, role, culture',
#                          'growth; compensation; flexibility',
#                          'Viability',
#                          'Geography, role, culture',
#                          'If I was to move jobs, it would be because my '
#                          'organization is bankrupt, or to pursue a lower '
#                          'pressure role with more work-life balance. Otherwise '
#                          'I do not see a reason to move to a new company until '
#                          'I have achieved what I need to for this company.',
#                          'Flexible work (hybrid/remote), stable hours, closer '
#                          'to where I live',
#                          "I'd like to maintain what I think is great vacation "
#                          'and work remote flexibility while also getting paid '
#                          'about 30% more. I could take or leave equity.',
#                          '"Financial Compensation; Visa process help to move; '
#                          'Job Security',
#                          'Technology that has a potential to be safer than '
#                          'lithium ion',
#                          'no',
#                          'Culture; Location; Work-life balance',
#                          'More stability and better leadership',
#                          'money, benefits, culture,',
#                          'Would like to move into program creation and '
#                          'direction',
#                          'Money;',
#                          'impact on society / environment',
#                          'Job duties; ability to learn new skills; travel '
#                          '(lots)',
#                          'Manager roles , equity and more challenging '
#                          'opportunities like getting the products to the '
#                          'market',
#                          'Sustainability',
#                          "potential for growth in the company's battery "
#                          'technology/chemistry',
#                          'Culture and cohesive decision making is the most '
#                          'important',
#                          'autonomy',
#                          'work life balance',
#                          'Major American city, abundant outdoor recreation, '
#                          'opportunities for mentorship, stable growth, '
#                          'established product and clear company vision',
#                          'I’m looking for career growth , work life balance '
#                          'and with my skills new things to involve for '
#                          'organizations, need sponsorship to know other '
#                          'country people to what type of mind they have , what '
#                          'type of thinking they have .',
#                          'Need more funders and investors for project',
#                          'Nil',
#                          'immediate joiner. 16 years in Lithium metal and '
#                          'Solid State Battery Industrial R&D.',
#                          'Having multidisciplinary and intercultural, openness '
#                          'to collaboration, cross functional communication '
#                          'vertically and horizontally are the key for maturing '
#                          'industry that i am trying to focus on.',
#                          'geography;friendliness;money',
#                          'Location. It should not be too remotely located',
#                          'emphasis can be placed on location flexibility',
#                          'Geography, Salary, Culture',
#                          'part of a larger team; resource availability; '
#                          'motivated and dedicated colleagues',
#                          'VP role, salary increase',
#                          'money; culture; role; company growth opportunity',
#                          '“Geography cannot be way out”',
#                          'right geography',
#                          'Ability for hybrid work, culture, mission/vision',
#                          'Culture',
#                          'innovation',
#                          'Move to other country and became expert expats',
#                          'Use of current capabilities, geography, work-life '
#                          'balance',
#                          'Money',
#                          'Stability, salary, culture',
#                          'Better WLB; better mentorship',
#                          'Stability',
#                          'no',
#                          'geography, money, benefits, role',
#                          'Growth opportunity; Role; Money',
#                          'stability, better compensation, work culture and '
#                          'innovation',
#                          'geography; culture; role; money',
#                          'Middle east, business develoment',
#                          "The company's approach to sustainability",
#                          'more travel, more impact, more compensation',
#                          'geography, company funding, collaboration, education',
#                          'Sustainability strong culture',
#                          'Established processes that have a successful track '
#                          'record. Culture of helping to improve skills. '
#                          'Company culture is to stick by hard workers and not '
#                          'judge them solely on outcomes',
#                          'More money; long term stability; better organization '
#                          'overall',
#                          "I'll retire after this role",
#                          'role; reputation',
#                          'Reciprocal flexibility (emplyer/employee); employer '
#                          'location;',
#                          'money, stability, career growth',
#                          'new country; money; role',
#                          'Geography',
#                          'no',
#                          'Leadership and project management learning '
#                          'opportunities',
#                          'Culture, Remote Work, Money',
#                          'diversity, financially strong company to invest in '
#                          'growth and innovation >5 years',
#                          'proven technology',
#                          'WFH',
#                          'geography',
#                          'New challenges, interesting problems to solve',
#                          'Clear targets, respect the strategy execution, to be '
#                          'real responsible for the key activity of my role, '
#                          'respect for the budget they give me, sharing more',
#                          'Mentors to learn from; good projects to work on; '
#                          'salary',
#                          'role; culture; benefits',
#                          'none',
#                          'I am looking for opportunities to work with bigger e '
#                          'mobility company in Europe and America',
#                          'Female job descriptors appear to be lower',
#                          'Better parental leave, flexible remote to hyrbid '
#                          'work in my area, career growth as a Material '
#                          'engineer.',
#                          'no',
#                          'Benefits, Role, Work life balance',
#                          'Training',
#                          'Work-Life balance',
#                          '1. Job security 2. Capacity building 3. Location',
#                          'Role in process R&D',
#                          'having fun while working',
#                          'Geographical, better salary, better company culture',
#                          'remote-working, benefits, role',
#                          'Career growth; Work-life balance; Competitive salary',
#                          'Career Growth\nMoney',
#                          'No',
#                          'More decision making',
#                          'Company culture, Career Developement, Mentoring, '
#                          'Development Opportunities',
#                          'Geography, stability, money',
#                          'US based or  Belgium, strategy development, coaching',
#                          'Stability, Learning opportunities, Carrier '
#                          'opportunities',
#                          'Innovative solution; strong growth opportunity',
#                          'money, remote',
#                          'Clear Job Description',
#                          'I am being asked to relocate in the next year. An '
#                          'opportunity to stay where I am is my highest '
#                          'priority.',
#                          'money, career growth, career strategy',
#                          'Geography; company stability; culture',
#                          'more money without being stretched as thin',
#                          'Ability to work fully remote',
#                          'money, work life balance, communication across the '
#                          'teams',
#                          'Money, posibility for personal growth',
#                          '1. Role 2. Compensation 3. Location',
#                          'Hybrid schedule (vs in person everyday), higher '
#                          'salary',
#                          'upward mobility',
#                          'thinking of leaving the country, thinking of '
#                          'switching to other aspects in this industry such as '
#                          'data or product',
#                          'Time flexibility',
#                          'The company should be focused on producing good '
#                          'product/service not focused on speed to market;\n'
#                          'A company with good documentation and processes in '
#                          'place',
#                          'Talented colleagues',
#                          'Culture, position',
#                          'Stability, work from home',
#                          'Money, career development',
#                          'Compensation, growth, flat organization.',
#                          'Item 1: Culture, Item 2: Innovation, Item 3: Career '
#                          'growth and opportunities',
#                          "I'd be willing to take a pay cut to only work 3 "
#                          "days/week since I have personal projects I'm working "
#                          'on',
#                          'benefits, culture',
#                          'Not in the battery industry',
#                          'Geography, Perks, Culture',
#                          'global opportunities where i can take my learning to '
#                          'middle east and africa',
#                          'Learning opportunities',
#                          'More hands-on work, more impact',
#                          'Moneys, work balance',
#                          'Tolerance for Muslim praying time; no racial '
#                          'discrimination; flexibility in communication',
#                          'New edge technology and advancement in EVs',
#                          'Pay as contractor; hours per week',
#                          'Not looking',
#                          'If it were looking i would need to be in a '
#                          'leadership position and would do more business '
#                          'development w people that have a team that is all '
#                          'encompassing and well funded',
#                          'geography, benefits, money, role',
#                          'Better pay and resources',
#                          'Creative growth; stability; money',
#                          'Work-life, leave, benefits',
#                          'ability to contribute to product and company '
#                          'direction, dynamic/growing company,',
#                          'Better facilities and environment',
#                          'Culture; Opportunity for personal growth within '
#                          'company structure; compensation',
#                          'No',
#                          'responsibility',
#                          'culture',
#                          'Research; business; Director',
#                          'Culture, Team Quality',
#                          'geography, money, benefits, culture are high '
#                          'important for me',
#                          'job security, but it does not exist anywhere, not '
#                          'even in National Labs',
#                          'role change, career development',
#                          'Salary raises; upward movement',
#                          'a good manager'],
#  'retention_num_employer_changes': {np.float64(0.0): 184,
#                                     np.float64(1.0): 212,
#                                     np.float64(2.0): 123,
#                                     np.float64(3.0): 84,
#                                     np.float64(4.0): 14,
#                                     np.float64(5.0): 1,
#                                     np.float64(6.0): 3,
#                                     np.float64(7.0): 1,
#                                     np.float64(10.0): 2,
#                                     '_tot_': 624},
#  'retention_sentiment': {'keys': ['My company has a good reputation in the '
#                                   'industry',
#                                   'I want to stay with my company for at least '
#                                   '12 more months',
#                                   'I am satisfied with my current job '
#                                   'stability',
#                                   'I am confident in my ability to find my '
#                                   'next job in the industry'],
#                          'mean': array([3.7254902 , 3.61652893, 3.41186161, 3.92520325]),
#                          'stdev': array([1.07548617, 1.34166217, 1.28803555, 1.10177931]),
#                          'values': array([[2., 2., 4., 4.],
#        [3., 3., 2., 5.],
#        [4., 5., 3., 5.],
#        ...,
#        [5., 3., 5., 3.],
#        [4., 5., 5., 5.],
#        [4., 5., 5., 4.]], shape=(665, 4))}}

# %%
plotter.make_bar_plot_from_dict(
    res_company_retention['retention_factors'],
    title='If you were offered a similar role with a different company, what factors would influence your decision to accept the offer?',
    saveas='company_retention_factors.png',
    exclusions=['bonuses'],
    replacements={'Salary': 'Salary, bonuses'},
    num_elements=12,
    sorted=True
)

plotter.make_bar_plot_from_dict(
    res_company_retention['retention_is_on_market'],
    title='Are you currently seeking new job opportunities?',
    saveas='company_retention_is_on_market.png',
    sorted=True
)

plotter.make_bar_plot_from_dict(
    res_company_retention['retention_num_employer_changes'],
    title='How many times have you changed employers in the past 5 years?',
    saveas='company_retention_num_employer_changes.png',
    num_elements=5,
)

# %% [markdown]
# ## Company Benefits

# %%
res_company_benefits = analyst.summarize_company_benefits()
pprint(res_company_benefits)
# Out:
# {'benefits_priorities': {'keys': ['Mental health support',
#                                   'Work-life balance initiatives',
#                                   'Financial wellness programs',
#                                   'Career development opportunities'],
#                          'mean': array([3.13615023, 3.13551402, 2.83568075, 3.07328605]),
#                          'stdev': array([1.18292159, 1.18216911, 1.10536215, 1.15544567]),
#                          'values': array([[nan, nan, nan, nan],
#        [nan, nan, nan, nan],
#        [nan, nan, nan, nan],
#        ...,
#        [ 3.,  3.,  1.,  3.],
#        [ 3.,  4.,  3.,  4.],
#        [ 3.,  3.,  5.,  3.]], shape=(665, 4))},
#  'entitlements': {'Advance salary': 1,
#                   'Child care FSA account': 1,
#                   'Educational': 100,
#                   'Employee Stock Purchase Program': 1,
#                   'Engineer title cost repayment': 1,
#                   'Gym or physical wellness stipend': 94,
#                   'Healthcare coverage or stipend': 312,
#                   'I am self employed so these are not available to me...yet': 1,
#                   'Learning': 1,
#                   'Market intelligence tools': 1,
#                   'Meal stipend': 73,
#                   'NOthing': 1,
#                   'No other benefits': 1,
#                   'None': 1,
#                   'Nothing': 1,
#                   'Nothing above': 1,
#                   'Parking': 1,
#                   'Personal transport': 1,
#                   'Retirement account funding or match': 240,
#                   'Student loan matching': 3,
#                   'Telephone': 1,
#                   'Transit benefits': 75,
#                   'Transportation': 1,
#                   'Work-from-home stipend': 71,
#                   '_tot_': 387,
#                   'free Transport by public transport companies': 1,
#                   'none': 2,
#                   'nothing from this list': 1,
#                   'or continued education stipend': 100,
#                   'parking': 1,
#                   'railway (first-class)': 1,
#                   'trainings': 1,
#                   'tuition': 100},
#  'parental_leave_weeks': {np.float64(0.0): 68,
#                           np.float64(1.0): 15,
#                           np.float64(2.0): 43,
#                           np.float64(3.0): 11,
#                           np.float64(4.0): 23,
#                           np.float64(5.0): 5,
#                           np.float64(6.0): 19,
#                           np.float64(7.0): 1,
#                           np.float64(8.0): 20,
#                           np.float64(9.0): 2,
#                           np.float64(10.0): 3,
#                           np.float64(12.0): 45,
#                           np.float64(13.0): 2,
#                           np.float64(14.0): 1,
#                           np.float64(15.0): 1,
#                           np.float64(16.0): 14,
#                           np.float64(17.0): 1,
#                           np.float64(18.0): 2,
#                           np.float64(20.0): 1,
#                           np.float64(24.0): 1,
#                           np.float64(26.0): 2,
#                           np.float64(27.0): 1,
#                           np.float64(30.0): 2,
#                           np.float64(32.0): 1,
#                           np.float64(36.0): 1,
#                           np.float64(48.0): 2,
#                           np.float64(49.0): 1,
#                           np.float64(52.0): 7,
#                           np.float64(60.0): 2,
#                           np.float64(68.0): 1,
#                           np.float64(69.0): 1,
#                           np.float64(78.0): 1,
#                           np.float64(90.0): 1,
#                           np.float64(96.0): 1,
#                           np.float64(104.0): 1,
#                           np.float64(400.0): 1,
#                           '_tot_': 304},
#  'pto_weeks': {np.float64(0.0): 14,
#                np.float64(1.0): 5,
#                np.float64(2.0): 46,
#                np.float64(3.0): 70,
#                np.float64(4.0): 68,
#                np.float64(5.0): 62,
#                np.float64(6.0): 53,
#                np.float64(7.0): 6,
#                np.float64(8.0): 3,
#                np.float64(10.0): 4,
#                np.float64(12.0): 4,
#                np.float64(13.0): 1,
#                np.float64(15.0): 7,
#                np.float64(18.0): 1,
#                np.float64(20.0): 13,
#                np.float64(21.0): 4,
#                np.float64(22.0): 2,
#                np.float64(24.0): 3,
#                np.float64(25.0): 9,
#                np.float64(26.0): 3,
#                np.float64(30.0): 9,
#                np.float64(40.0): 3,
#                np.float64(43.0): 1,
#                np.float64(45.0): 1,
#                np.float64(50.0): 1,
#                np.float64(52.0): 3,
#                np.float64(120.0): 1,
#                np.float64(176.0): 1,
#                np.float64(365.0): 1,
#                '_tot_': 399},
#  'sick_leave_days': {np.float64(0.0): 54,
#                      np.float64(1.0): 12,
#                      np.float64(2.0): 9,
#                      np.float64(3.0): 15,
#                      np.float64(4.0): 9,
#                      np.float64(5.0): 74,
#                      np.float64(6.0): 14,
#                      np.float64(7.0): 9,
#                      np.float64(8.0): 9,
#                      np.float64(9.0): 2,
#                      np.float64(10.0): 42,
#                      np.float64(11.0): 1,
#                      np.float64(12.0): 10,
#                      np.float64(13.0): 1,
#                      np.float64(14.0): 9,
#                      np.float64(15.0): 9,
#                      np.float64(20.0): 14,
#                      np.float64(21.0): 2,
#                      np.float64(24.0): 1,
#                      np.float64(25.0): 2,
#                      np.float64(30.0): 16,
#                      np.float64(40.0): 5,
#                      np.float64(42.0): 1,
#                      np.float64(45.0): 1,
#                      np.float64(60.0): 2,
#                      np.float64(90.0): 6,
#                      np.float64(100.0): 1,
#                      np.float64(120.0): 1,
#                      np.float64(180.0): 1,
#                      np.float64(200.0): 1,
#                      np.float64(300.0): 1,
#                      np.float64(365.0): 12,
#                      '_tot_': 346},
#  'unique_benefits_list': ['Career Opportunities',
#                           'Exposure to senior executives',
#                           '[Parental leave is state governed, 480 days/child '
#                           'at 80% of salary, matched another part by company '
#                           "by 10%.] [Sweden don't have sick days, it is 80% of "
#                           'salary for "as long as needed" (not infinite, but '
#                           'long, not sure how long)]. [Also like the 7 week '
#                           'vacation.]',
#                           'Kids school entry subsidie; Kids Cristsmas present',
#                           '-',
#                           'work life balance, flexibility, flat structure',
#                           'Na',
#                           'The opportunity to make an own project and defend a '
#                           'PhD work',
#                           'unlimited annual leave',
#                           'long holiday allowance;',
#                           'Free flying lessons with instructor of my free '
#                           'choice',
#                           'unlimited PTO; work travel flexibility '
#                           '(airline/hotel); remote work',
#                           'hybrid work; ambitious project; team culture',
#                           'schedule flexibility, bonuses',
#                           '1) Work from home 2)100% company paid health '
#                           'premium paid',
#                           'working from home',
#                           '0',
#                           'Parental Leave; Sick Days; Vacation',
#                           'Vacation',
#                           'car+ tickets restaurant',
#                           'Equity grants',
#                           'RRSP Matching;',
#                           'My own company',
#                           'mentorship, continued education',
#                           'home office, life work balance',
#                           'unlimited PTO (within reason) / flexible work '
#                           'schedule',
#                           'Employee discounts',
#                           'company car, internet payment, train ticket',
#                           'Adoption assistance; pet insurance; on-site fitness '
#                           'center',
#                           'No time clock; autonomy; input valued',
#                           'Snacks; WFR capabilities',
#                           'Work from home, parental leave',
#                           'Autonomy as sole director',
#                           'Flexible leaves',
#                           'fully covered healthcare for me and a dependent',
#                           'continuing education stipend',
#                           'none',
#                           '"New equipment training"',
#                           'Possibility to do more than 3 times business trip a '
#                           'year; transportation benefit; unlimited sick leave '
#                           'opportunity to take',
#                           'Additional holidays',
#                           'flexible working scheme, health benefits',
#                           'Honesty, communication, training',
#                           'Superannuation, free parking, flexible work hours',
#                           'Benefit of recognising talent and appreciation',
#                           'Travelling;',
#                           'Time Flexibility, Stressfree Work, Freewill',
#                           'Housing benifit',
#                           'work from home, freedom, growth',
#                           'Health Insurance',
#                           'no',
#                           'Flexible time off; remote work',
#                           'SARs (for our employees); weekly helathy lunch;  '
#                           'drinks and parties',
#                           'Equity; mental health benefit; better health '
#                           'insurance',
#                           'Dependent Care Savings Account; Inexpensive but '
#                           'high quality life insurance; Short Term and Long '
#                           'Term Disability Insurance',
#                           'No',
#                           'Flexible hours',
#                           'Meal bonus, healthcare, pension',
#                           'career growth',
#                           '401k matching on roth 401k contributions',
#                           'paid family leave, work time flexibility, time off '
#                           'is infinite (but realistically around 30 days)',
#                           '401k matching; stocks',
#                           'no',
#                           '4 day work week; paid healthcare; hybrid work '
#                           'schedule',
#                           '100% remote work',
#                           'no',
#                           'no',
#                           'Cell phone compensation',
#                           'autonomy, leadership quality',
#                           'Equity, Mobile phone usage',
#                           'bonus, meals, novel chances to train in new '
#                           'processes',
#                           'Hybrid work schedule',
#                           'one time bike stipend',
#                           'Friday lunches provided!',
#                           'Relocation leave',
#                           'known senior management',
#                           'Festival coupon, gifts',
#                           'Culture, potential, industry',
#                           'sickleave with pay;variable work hours with core '
#                           'time at office and the rest as per own wishes; own '
#                           'planning of work',
#                           'No not really',
#                           'Internal growth opportunity',
#                           'Pension scheme',
#                           'Transport assistance, health insurance, unpaid '
#                           'leave',
#                           'Share option pool',
#                           'ESOp',
#                           'no need to check-in/out at daily base of work',
#                           'Retention bonus',
#                           'equity',
#                           'hybrid work, snacks/lunch, vacation balances',
#                           'Good pension',
#                           'Personal Health days (2); flextime; hybrid work '
#                           'schedule',
#                           'Generous health insurance',
#                           'NO',
#                           'Statutory German insurances, i.e. health, pension, '
#                           'etc.',
#                           'Bonus; Health insurance; children education support',
#                           'Pension, 401k match, stock options',
#                           'Unlimited PTO (but with pressure not to take it '
#                           'lol)',
#                           'Lunch stipend; work travel',
#                           'EXPATRIATION, HOUSEHOLD, DEPENDING CHILD',
#                           'no',
#                           'No',
#                           'flexible holidays',
#                           'none',
#                           'Company Car',
#                           'generous parental leave; health benefit e.g. gym '
#                           'contribution',
#                           'workplace flexibility (remote/hybrid), flexibility '
#                           'to delegate portions of benefits to certain health '
#                           'categories, no limit to sick days',
#                           'Parental leave, work from home flexibility',
#                           "We offer stock options but I'm not high on them",
#                           'Breakfast and lunch provided',
#                           'degree of freedom',
#                           'free EV charging; free lunches; hybrid '
#                           'work/location',
#                           'Growth Opportunity',
#                           'company car',
#                           'Unlimited PTO',
#                           'Flexible home office',
#                           'sport programm, job bike',
#                           'my focus is on job quality not benefits...if the '
#                           'salary is aligned I will think by myself to my life '
#                           'or benefits',
#                           'freedom; flexible work times',
#                           'no',
#                           'HMO, Pension, out station allowance',
#                           '1. LTIP, 2. structured performance related bonuses, '
#                           '3. extra medical care stipend, 4. company '
#                           'retirement plans',
#                           'Parental leave, flexible work environment',
#                           'no',
#                           'Flexibility; Independent',
#                           'Friendly',
#                           'nothing',
#                           'Nil',
#                           'Relocation perk',
#                           '[working environment]; [flexible working hours]; '
#                           '[gym in the factory]]',
#                           'work from home perks, flexible working hours',
#                           'Comprehensive health insurance Flexible working '
#                           'hours Professional development courses',
#                           'Good working atmosphere; Confidence; Profit '
#                           'sharing; Salary increases',
#                           'Car lease salary sacrifice',
#                           'partner and children to move to the US',
#                           'Gifts for kids, Association discounts, subsidies '
#                           'sport/culture/school',
#                           'Unlimited PTO; fully remote',
#                           'work remotely',
#                           'Dependable health insurance, generous paid time off',
#                           '"Health Insurance; Compensation"',
#                           'Remote work',
#                           'Retirement match; health care',
#                           'product discounts',
#                           'Egg freezing',
#                           '401k match, hsa match, meals',
#                           'No',
#                           '1. Role 2. Location 3. Industry',
#                           'Unlimited PTO',
#                           'Equity compensation (RSUs or stock options), hybrid '
#                           'work schedule',
#                           'Work life balance; flexibility',
#                           'company events/celebration, flexibility for unpaid '
#                           'leave for extended international travel',
#                           'courses for personal development, conferences',
#                           'Flexibility with my time; company name recognition',
#                           'a gym at the office',
#                           'No',
#                           'pension contribution',
#                           'No I have no any benefit',
#                           'Remote work, respect weekends, good 401(k) match of '
#                           '4%',
#                           'no',
#                           'Flex Time off ; HSA health plans ; Equity',
#                           'Flexible time off',
#                           'No',
#                           'Meals by kitchen team',
#                           '1. Sports',
#                           'Recognition, next level challenge',
#                           'Continuos education (seminars and conferences), gym',
#                           'Company car , on long haul flight business class',
#                           'wfh',
#                           'Prayer room; flexibility in handling the job; '
#                           'transport and telecommunication coverage',
#                           'ESOPs',
#                           'No',
#                           'I have a lot of freedom',
#                           'Free healthcare plan',
#                           'Work from Home, Health Insurance, Retirement Match',
#                           'lunch meal',
#                           'Unlimited time off',
#                           'no',
#                           'No',
#                           'vehicle scheme',
#                           'No',
#                           'Company car',
#                           'no',
#                           'pension, health care into retirement',
#                           'No']}

# %%
plotter.make_bar_plot_from_dict(
    res_company_benefits['entitlements'],
    title='What benefits does your company entitle you to?',
    saveas='company_benefits_entitlements.png',
    exclusions=['tuition', 'or continued education stipend'],
    replacements={'Educational' : 'Educational, tuition, or continued education stipend'},
    num_elements=10,
    sorted=True
)

plotter.make_bar_plot_from_dict(
    utils.sort_dict(res_company_benefits['parental_leave_weeks'], by='keys', reverse=False),
    title='How many weeks of parental leave are you entitled to?',
    saveas='company_benefits_parental_leave_weeks.png',
    num_elements=16
)

plotter.make_bar_plot_from_dict(
    utils.sort_dict(res_company_benefits['pto_weeks'], by='keys', reverse=False),
    title='How many weeks of paid time off are you entitled to each year?',
    saveas='company_benefits_pto_weeks.png',
    num_elements=16
)

plotter.make_bar_plot_from_dict(
    utils.sort_dict(res_company_benefits['sick_leave_days'], by='keys', reverse=False),
    title='How many days of sick leave are you entitled to?',
    saveas='company_benefits_sick_leave_days.png',
    num_elements=16
)
