# %% [markdown]
# # 5. Demonstrate visualization of sentiment metrics
#
# December 27, 2024
#
# Visualize the sentiment metrics using a few different visualization techniques.
#
# Sentiment metrics refer to "matrix" type questions in TypeForm. For the Census, the rows in the matrix are specific questions about respondent sentiment (e.g., "how are you doing?"). The columns are sentiment ratings from 1 to 5.

# %%
import os

# Set working directory to root of project
current_folder = os.path.basename(os.getcwd())
if current_folder == 'notebooks':
    root_path = os.path.dirname(os.path.abspath(''))
    os.chdir(root_path)

from pprint import pprint
from src.plotter import Plotter
from src.respondent import Respondent
from src.analyst import Analyst
import src.utils as utils

from IPython import get_ipython

# Automatically reload all modules every time a line of code is executed
get_ipython().run_line_magic('load_ext', 'autoreload')
get_ipython().run_line_magic('autoreload', '2')

# %% [markdown]
# # Assemble the relevant data from the Census

# %%
plotter = Plotter()

analyst = Analyst()
analyst.load_data()
analyst.build_respondents_list()

# %%
census_sentiment = {}
census_sentiment['key'] = 'census_sentiment'
census_sentiment['labels'] = ['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree']
census_sentiment['question'] = 'How are you doing?'
census_sentiment['responses'] = analyst.summarize_census_sentiment()

company_satisfaction = {}
company_satisfaction['key'] = 'company_satisfaction'
company_satisfaction['labels'] = ['Strongly Disagree', 'Disagree', 'Neutral or N/A', 'Agree', 'Strongly Agree']
company_satisfaction['question'] = 'To what extent do you agree with the following statements?'
company_satisfaction['responses'] = analyst.summarize_company_satisfaction()

company_skills_preparedness = {}
company_skills_preparedness['key'] = 'company_skills_preparedness'
company_skills_preparedness['labels'] = ['Very Unprepared', 'Unprepared', 'Neutral or N/A', 'Prepared', 'Very prepared']
company_skills_preparedness['question'] = 'When you first started your role, how prepared did you feel?'
company_skills_preparedness['responses'] = analyst.summarize_company_skills()['skills_preparedness_sentiment']

company_retention = {}
company_retention['key'] = 'company_retention'
company_retention['labels'] = ['Strongly Disagree', 'Disagree', 'Neutral or N/A', 'Agree', 'Strongly Agree']
company_retention['question'] = 'To what extent do you agree with the following statements?'
company_retention['responses'] = analyst.summarize_company_retention()['retention_sentiment']

company_benefits = {}
company_benefits['key'] = 'company_benefits'
company_benefits['labels'] = ['Very low', 'Low', 'Neutral', 'High', 'Very high']
company_benefits['question'] = 'To what extent does your company prioritize the following employee well-being solutions?'
company_benefits['responses'] = analyst.summarize_company_benefits()['benefits_priorities']

student_sentiment = {}
student_sentiment['key'] = 'student_sentiment'
student_sentiment['labels'] = ['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree']
student_sentiment['question'] = 'To what extent do you agree with the following statements?'
student_sentiment['responses'] = analyst.summarize_student_sentiment()

# %%
student_sentiment
# Out:
# {'key': 'student_sentiment',
#  'labels': ['Strongly Disagree',
#   'Disagree',
#   'Neutral',
#   'Agree',
#   'Strongly Agree'],
#  'question': 'To what extent do you agree with the following statements?',
#  'responses': {'keys': ['After graduating, I know what role(s) to apply to',
#    'After graduating, I will find a job',
#    'By the time I graduate, I will have learned the skills needed to find a job',
#    'I am optimistic about the future of the battery industry'],
#   'values': array([[ 5.,  3.,  4.,  4.],
#          [ 5.,  4.,  5.,  5.],
#          [ 4.,  5.,  5.,  5.],
#          [ 3.,  3.,  3.,  5.],
#          [ 3.,  2.,  2.,  4.],
#          [ 3.,  3.,  3.,  5.],
#          [ 1.,  2.,  2.,  2.],
#          [ 3.,  3.,  2.,  4.],
#          [ 2.,  4.,  4.,  5.],
#          [ 3.,  2.,  2.,  4.],
#          [ 5.,  5.,  4.,  5.],
#          [ 4.,  2.,  4.,  5.],
#          [ 4.,  5.,  2.,  3.],
#          [ 4.,  5.,  3.,  5.],
#          [ 1.,  2.,  3.,  1.],
#          [ 5.,  4.,  3.,  4.],
#          [ 5.,  3.,  4.,  5.],
#          [ 5.,  3.,  5.,  5.],
#          [ 4.,  4.,  4.,  1.],
#          [ 5.,  5.,  5.,  5.],
#          [ 4.,  3.,  4.,  4.],
#          [ 2.,  4.,  4.,  5.],
#          [ 5.,  5.,  5.,  5.],
#          [ 4.,  3.,  3.,  3.],
#          [ 5.,  5.,  5.,  5.],
#          [ 5.,  2.,  4.,  5.],
#          [ 2.,  2.,  4.,  2.],
#          [ 4.,  4.,  3.,  4.],
#          [ 4.,  5., nan,  5.],
#          [ 5.,  5.,  4.,  5.],
#          [ 4.,  4.,  4.,  4.],
#          [nan, nan, nan, nan],
#          [ 4.,  3.,  4.,  5.],
#          [ 4., nan,  5.,  4.],
#          [ 2.,  2.,  3.,  1.],
#          [ 5.,  3.,  4.,  4.],
#          [ 4.,  4.,  4.,  4.],
#          [ 4.,  4.,  4.,  4.],
#          [ 4.,  4.,  4.,  4.],
#          [ 2.,  1.,  2.,  1.],
#          [ 4.,  3.,  3.,  4.],
#          [ 3.,  3.,  5.,  5.],
#          [ 4.,  3.,  4.,  5.],
#          [ 4.,  4.,  5.,  5.],
#          [nan, nan,  4., nan],
#          [ 3.,  4.,  4.,  3.],
#          [ 2.,  3.,  4.,  5.],
#          [ 4.,  4.,  4.,  4.],
#          [ 3.,  4.,  4.,  4.],
#          [ 4.,  4.,  4.,  4.],
#          [ 3.,  5.,  4.,  4.],
#          [ 4.,  4.,  4.,  5.],
#          [ 3.,  3.,  3.,  5.],
#          [ 3.,  1.,  3.,  1.],
#          [ 3.,  4.,  5.,  5.],
#          [ 4.,  4.,  4.,  4.],
#          [ 2.,  1.,  2.,  3.],
#          [ 3.,  3.,  3.,  4.],
#          [ 2.,  3.,  3.,  3.],
#          [ 4.,  4.,  3.,  4.],
#          [ 4.,  3.,  4.,  4.],
#          [ 3.,  5.,  4.,  5.],
#          [ 4.,  5.,  4.,  5.],
#          [ 4.,  5.,  5.,  3.],
#          [ 3.,  5.,  4.,  5.],
#          [ 5.,  4.,  3.,  3.],
#          [ 2.,  3.,  3.,  4.],
#          [ 5.,  5.,  4.,  4.],
#          [ 3.,  4.,  4.,  4.],
#          [ 2.,  4.,  3.,  4.],
#          [ 3.,  4.,  4.,  4.],
#          [ 2.,  3.,  4.,  5.],
#          [ 3.,  5.,  5.,  4.],
#          [ 4.,  3.,  3.,  4.],
#          [ 5.,  5.,  5.,  5.],
#          [ 4.,  4.,  4.,  5.],
#          [ 4.,  5.,  5.,  5.],
#          [ 3.,  3.,  4.,  4.],
#          [ 3.,  2.,  3.,  3.]]),
#   'submit_time': array([Timestamp('2024-10-04 20:16:20'), Timestamp('2024-10-04 20:09:07'),
#          Timestamp('2024-10-04 19:53:27'), Timestamp('2024-10-04 19:14:26'),
#          Timestamp('2024-10-04 19:02:50'), Timestamp('2024-10-04 18:35:17'),
#          Timestamp('2024-10-04 18:20:16'), Timestamp('2024-10-04 18:16:48'),
#          Timestamp('2024-10-04 17:42:32'), Timestamp('2024-10-04 17:31:42'),
#          Timestamp('2024-10-04 17:08:19'), Timestamp('2024-10-04 16:53:27'),
#          Timestamp('2024-10-04 16:35:29'), Timestamp('2024-10-04 16:33:42'),
#          Timestamp('2024-10-04 16:21:25'), Timestamp('2024-10-04 16:13:38'),
#          Timestamp('2024-10-04 15:56:28'), Timestamp('2024-10-04 15:46:49'),
#          Timestamp('2024-10-04 21:14:39'), Timestamp('2024-10-05 01:04:33'),
#          Timestamp('2024-10-05 04:17:54'), Timestamp('2024-10-05 05:05:12'),
#          Timestamp('2024-10-05 06:48:39'), Timestamp('2024-10-05 11:46:55'),
#          Timestamp('2024-10-05 16:46:12'), Timestamp('2024-10-06 21:43:04'),
#          Timestamp('2024-10-07 08:30:47'), Timestamp('2024-10-07 09:37:39'),
#          Timestamp('2024-10-08 11:32:53'), Timestamp('2024-10-08 15:55:31'),
#          Timestamp('2024-10-08 19:23:33'), Timestamp('2024-10-09 20:30:55'),
#          Timestamp('2024-10-10 18:31:29'), Timestamp('2024-10-10 20:24:14'),
#          Timestamp('2024-10-15 14:54:44'), Timestamp('2024-10-15 14:59:21'),
#          Timestamp('2024-10-15 15:01:11'), Timestamp('2024-10-15 15:06:16'),
#          Timestamp('2024-10-15 18:19:12'), Timestamp('2024-10-15 19:29:53'),
#          Timestamp('2024-10-15 19:53:42'), Timestamp('2024-10-16 02:18:02'),
#          Timestamp('2024-10-16 04:18:40'), Timestamp('2024-10-20 02:34:47'),
#          Timestamp('2024-10-20 09:07:10'), Timestamp('2024-10-22 14:12:12'),
#          Timestamp('2024-10-22 14:14:46'), Timestamp('2024-10-22 14:15:12'),
#          Timestamp('2024-10-22 14:20:46'), Timestamp('2024-10-30 19:31:59'),
#          Timestamp('2024-10-31 08:55:26'), Timestamp('2024-10-31 11:41:57'),
#          Timestamp('2024-10-31 13:35:04'), Timestamp('2024-10-31 18:04:16'),
#          Timestamp('2024-11-04 18:34:53'), Timestamp('2024-11-07 19:14:36'),
#          Timestamp('2024-11-18 18:44:57'), Timestamp('2024-11-19 01:00:04'),
#          Timestamp('2024-11-22 15:43:52'), Timestamp('2024-11-22 21:39:36'),
#          Timestamp('2024-11-23 01:45:58'), Timestamp('2024-11-23 13:17:18'),
#          Timestamp('2024-11-25 23:41:55'), Timestamp('2024-12-02 10:18:50'),
#          Timestamp('2024-12-02 20:49:38'), Timestamp('2024-12-03 06:32:15'),
#          Timestamp('2024-12-03 14:28:33'), Timestamp('2024-12-03 18:19:27'),
#          Timestamp('2024-12-03 18:59:56'), Timestamp('2024-12-03 21:23:15'),
#          Timestamp('2024-12-04 07:09:08'), Timestamp('2024-12-04 11:13:20'),
#          Timestamp('2024-12-04 18:43:53'), Timestamp('2024-12-11 17:45:13'),
#          Timestamp('2024-12-15 12:15:19'), Timestamp('2024-12-15 12:33:56'),
#          Timestamp('2024-12-15 14:11:04'), Timestamp('2024-12-15 19:27:45'),
#          Timestamp('2024-12-16 11:48:28')], dtype=object),
#   'mean': array([3.57142857, 3.59210526, 3.75324675, 4.06493506]),
#   'stdev': array([1.03733639, 1.09036005, 0.85517286, 1.09707595])}}

# %%
plotter.make_sentiment_plot(student_sentiment)
